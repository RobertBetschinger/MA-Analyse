# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cleaned_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009329 entries, 0 to 1009328
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   asin                  1009329 non-null  object
#  1   time                  1009329 non-null  object
#  2   id                    1009329 non-null  float64
#  3   price                 1009329 non-null  float64
#  4   currency              1009329 non-null  object
#  5   crawlTime             1009329 non-null  object
#  6   condition             1009329 non-null  object
#  7   sellerName            1009329 non-null  object
#  8   sellerId              1009329 non-null  object
#  9   sellerbewertung       754862 non-null   float64
#  10  seller_sterne         1009329 non-null  float64
#  11  lieferdatum           973966 non-null   object
#  12  lieferpreis           973966 non-null   float64
#  13  lieferung_durch       1009329 non-null  object
#  14  ranking               1009329 non-null  float64
#  15  buyBoxWinner          1009329 non-null  bool
#  16  numberOfSellers       1009329 non-null  float64
#  17  trigByReactive        1009329 non-null  bool
#  18  time_gap              1009329 non-null  float64
#  19  copyed_cause_missing  1009329 non-null  bool
#  20  Fulfillment_type      1009329 non-null  object
#  21  date_diff             951510 non-null   float64
# dtypes: bool(3), float64(9), object(10)
# memory usage: 149.2+ MB

# %%
# Out:
# Es gibt insgesamt 2060 verschiedene Verkäufer

# %%
## Print Basic Information about Dataframe.
#TimeFrame
df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M:%S")
# Find the max and min values for the 'time' column
max_time = df['time'].max()
min_time = df['time'].min()

print("Max value for the 'time' column:", max_time)
print("Min value for the 'time' column:", min_time)

distinct_values_verkäufer = df['sellerName'].nunique()
print(f"Es gibt insgesamt {distinct_values_verkäufer} verschiedene Verkäufer")
# Out:
# Max value for the 'time' column: 2023-03-25 21:00:00
# Min value for the 'time' column: 2023-03-19 13:00:00
# Es gibt insgesamt 2060 verschiedene Verkäufer

# %% [markdown]
# ## Generating List of asin Seller/Pairs and the Corresponding Price Changes/Observation Time

# %%
import pandas as pd
from datetime import timedelta

# Assuming your DataFrame is called df
df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M:%S")

# First, sort the DataFrame by 'asin', 'sellerName', 'condition', 'time', and 'price'
df = df.sort_values(by=['asin', 'sellerName','condition', 'time','price'])

# Reset the index after sorting
df.reset_index(drop=True, inplace=True)

# Compute the price changes by checking if the price in the current row is different from the previous row,
# and if the sellerName is the same as in the previous row and if the condition is the same as in the previous row
# and if the time difference is exactly one hour and if there is no offer one hour earlier with the same condition and the same price from the same seller
df['price_change'] = (
    (df['price'] != df['price'].shift(1)) &
    (df['condition'] == df['condition'].shift(1)) &
    (df['sellerName'] == df['sellerName'].shift(1)) &
    (df['asin'] == df['asin'].shift(1)) &
    ((df['time'] - df['time'].shift(1)) == timedelta(hours=1)) &
    (~(
        ((df['condition'] == df['condition'].shift(1)) & (df['price'] == df['price'].shift(1)) & ((df['time'] - df['time'].shift(1)) == timedelta(hours=1)) & (df['sellerName'] == df['sellerName'].shift(1))) |
        ((df['condition'] == df['condition'].shift(2)) & (df['price'] == df['price'].shift(2)) & ((df['time'] - df['time'].shift(2)) == timedelta(hours=1)) & (df['sellerName'] == df['sellerName'].shift(2)))
    ))
).astype(int)

# Calculate the observation time for each seller-asin combination
observation_time = df.groupby(['asin', 'sellerName'])['time'].agg(['min', 'max']).reset_index()
observation_time['observation_time'] = observation_time['max'] - observation_time['min']

# Now, group by 'asin' and 'sellerName' and sum the 'price_change' column to get the number of price changes
price_changes = df.groupby(['asin', 'sellerName'])['price_change'].sum().reset_index()

# Merge the price_changes and observation_time DataFrames
result_df = pd.merge(price_changes, observation_time[['asin', 'sellerName', 'observation_time']], on=['asin', 'sellerName'])

# Convert the result to a list of tuples
result = list(result_df.itertuples(index=False, name=None))

# Print the result
for x in result:
    print(x)
# Out:
# ('B00000JD6K', 'Kidia', 17, Timedelta('6 days 08:00:00'))
# ('B00000JD6K', 'STILE IMMAGINE DIGITAL HD', 0, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'Amazon Warehouse ', 3, Timedelta('0 days 20:00:00'))
# ('B00005KIRS', 'Arlambo', 55, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'Bambini Factory Deals', 15, Timedelta('1 days 16:00:00'))
# ('B00005KIRS', 'Cernovia', 0, Timedelta('4 days 21:00:00'))
# ('B00005KIRS', 'Crystal4ever', 29, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'DASTRO ® --- Einfach. Genial. Günstig.', 0, Timedelta('6 days 05:00:00'))
# ('B00005KIRS', 'Electronic XXL Sachsen', 0, Timedelta('1 days 07:00:00'))
# ('B00005KIRS', 'GREINER GROSSHANDEL', 30, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'Kaleido.Shop GmbH', 0, Timedelta('6 days 05:00:00'))
# ('B00005KIRS', 'Technikprimus', 0, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'amazon', 34, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'e-joker', 16, Timedelta('6 days 08:00:00'))
# ('B00005KIRS', 'inandout', 27, Timedelta('6 days 08:00:00'))
# ('B00008K61M', '1A-Elektronik', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'ABC-Schnäppchenmarkt GmbH', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'ARDEBO', 0, Timedelta('3 days 15:00:00'))
# ('B00008K61M', 'AS-Discount', 0, Timedelta('1 days 05:00:00'))
# ('B00008K61M', 'CW-SHOPPING', 14, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Casa Haushalt', 14, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'DaJa-Computer GbR', 13, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Deltatecc GmbH', 2, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'EFI Global Store DE', 0, Timedelta('5 days 00:00:00'))
# ('B00008K61M', 'ETOH24', 0, Timedelta('5 days 22:00:00'))
# ('B00008K61M', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Elektro4000de', 37, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Elektronik-Versand', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'EliXito', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'GREINER GROSSHANDEL', 19, Timedelta('5 days 16:00:00'))
# ('B00008K61M', 'Happy Home Srl', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Kaleido.Shop GmbH', 17, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'KitchenKing24', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Kommerzpunkt', 1, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'MIOGA Warenhandel & Service GmbH', 7, Timedelta('5 days 11:00:00'))
# ('B00008K61M', 'Masskas', 22, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Olano GmbH', 0, Timedelta('2 days 01:00:00'))
# ('B00008K61M', 'Power & Handel Vertriebs-GmbH', 15, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Stortle', 6, Timedelta('2 days 03:00:00'))
# ('B00008K61M', 'Technikprimus', 0, Timedelta('4 days 05:00:00'))
# ('B00008K61M', 'UEBilliger', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'Weichhold GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'Yeppon', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'ZOOM ICI', 1, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'amazon', 32, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'computeruniverse', 43, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'e-joker', 22, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'egenta', 1, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'elektrotresen', 0, Timedelta('5 days 04:00:00'))
# ('B00008K61M', 'inandout', 0, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 30, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'nox divendo', 18, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'priz24', 0, Timedelta('5 days 22:00:00'))
# ('B00008K61M', 'shoppingpoint24', 24, Timedelta('6 days 08:00:00'))
# ('B00008K61M', 'spiessxxl', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61M', 'tecedo', 0, Timedelta('0 days 07:00:00'))
# ('B00008K61N', 'ARDEBO', 4, Timedelta('5 days 22:00:00'))
# ('B00008K61N', 'AS-Discount', 13, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'CW-SHOPPING', 11, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Casa Haushalt', 42, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'DaJa-Computer GbR', 5, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Deltatecc GmbH', 4, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'ETOH24', 0, Timedelta('6 days 05:00:00'))
# ('B00008K61N', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Electronic XXL Sachsen', 0, Timedelta('5 days 10:00:00'))
# ('B00008K61N', 'Elektronik-Versand', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'EliXito', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Fabry GmbH', 0, Timedelta('5 days 10:00:00'))
# ('B00008K61N', 'GREINER GROSSHANDEL', 27, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Happy Home Italia', 0, Timedelta('0 days 00:00:00'))
# ('B00008K61N', 'Happy Home Srl', 4, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'KitchenKing24', 1, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Kommerzpunkt', 0, Timedelta('5 days 10:00:00'))
# ('B00008K61N', 'MIOGA Warenhandel & Service GmbH', 6, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Power & Handel Vertriebs-GmbH', 12, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'Spiele-und-Abenteuer', 0, Timedelta('6 days 05:00:00'))
# ('B00008K61N', 'TECMONDO', 0, Timedelta('1 days 12:00:00'))
# ('B00008K61N', 'UEBilliger', 0, Timedelta('5 days 10:00:00'))
# ('B00008K61N', 'Yeppon', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'ZOOM ICI', 1, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'amazon', 15, Timedelta('6 days 08:00:00'))
# ('B00008K61N', 'computeruniverse', 25, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'e-joker', 11, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'elektrotresen', 0, Timedelta('6 days 05:00:00'))
# ('B00008K61N', 'inandout', 9, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'kaijott', 2, Timedelta('3 days 04:00:00'))
# ('B00008K61N', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 32, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'nox divendo', 21, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B00008K61N', 'priz24', 0, Timedelta('6 days 05:00:00'))
# ('B00008K61N', 'technikgross', 0, Timedelta('5 days 10:00:00'))
# ('B0000C72GD', 'STILE IMMAGINE DIGITAL HD', 0, Timedelta('6 days 08:00:00'))
# ('B0000D85OD', '4Fun sHop', 0, Timedelta('0 days 00:00:00'))
# ('B0000D85OD', 'Happy Home Italia', 0, Timedelta('5 days 12:00:00'))
# ('B0000D85OD', 'Happy Home Srl', 18, Timedelta('6 days 07:00:00'))
# ('B0000D85OD', 'KupZarovky', 2, Timedelta('6 days 07:00:00'))
# ('B0000D85OD', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 2, Timedelta('6 days 07:00:00'))
# ('B0000D85OD', 'amazon', 19, Timedelta('6 days 08:00:00'))
# ('B0000WOK04', 'AS-Discount', 24, Timedelta('5 days 17:00:00'))
# ('B0000WOK04', 'Conrad Electronic SE', 0, Timedelta('5 days 23:00:00'))
# ('B0000WOK04', 'JACOB ⭐⭐⭐⭐⭐', 29, Timedelta('6 days 07:00:00'))
# ('B0000WOK04', 'Modellbau-Braeuer', 0, Timedelta('6 days 02:00:00'))
# ('B0000WOK04', 'Neuesland Preise inkl. MwSt', 29, Timedelta('6 days 07:00:00'))
# ('B0000WOK04', 'Railroad 2000', 0, Timedelta('6 days 07:00:00'))
# ('B0000WOK04', 'SMDV', 0, Timedelta('4 days 23:00:00'))
# ('B0000WOK04', 'amazon', 29, Timedelta('6 days 08:00:00'))
# ('B0000WOK04', 'get goods', 0, Timedelta('5 days 03:00:00'))
# ('B0000WOK04', 'muddukaufen_Sammelwelt', 0, Timedelta('6 days 02:00:00'))
# ('B0000WOK9A', 'AS-Discount', 7, Timedelta('3 days 05:00:00'))
# ('B0000WOK9A', 'BWBahn', 1, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'Happy Home Srl', 9, Timedelta('3 days 05:00:00'))
# ('B0000WOK9A', 'JACOB ⭐⭐⭐⭐⭐', 0, Timedelta('2 days 10:00:00'))
# ('B0000WOK9A', 'Modellauto18', 18, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'Modellbahnshop-Korn', 0, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'Modellbau Fischer', 0, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'Modellbau-Braeuer', 0, Timedelta('3 days 17:00:00'))
# ('B0000WOK9A', 'SMDV', 0, Timedelta('5 days 05:00:00'))
# ('B0000WOK9A', 'Stahlbruck Online ab 50.- keine Versandkosten', 0, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'arstecnica', 18, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'edelsoft', 18, Timedelta('6 days 08:00:00'))
# ('B0000WOK9A', 'get goods', 0, Timedelta('5 days 07:00:00'))
# ('B0000WOK9A', 'muddukaufen_Sammelwelt', 0, Timedelta('5 days 22:00:00'))
# ('B0001GRVJQ', 'Amazon Warehouse ', 2, Timedelta('1 days 08:00:00'))
# ('B0001GRVJQ', 'Eisen-Stenger GmbH Preise inkl. MwSt', 7, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'Gausmann-Technik', 13, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'Maxeda E-Commerce', 0, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'Maxitools', 4, Timedelta('5 days 21:00:00'))
# ('B0001GRVJQ', 'RUBART GmbH', 13, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'Voelkner', 0, Timedelta('5 days 11:00:00'))
# ('B0001GRVJQ', 'amazon', 13, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'baumarktdiscount', 30, Timedelta('6 days 08:00:00'))
# ('B0001GRVJQ', 'trockenbauspezialist', 0, Timedelta('6 days 08:00:00'))
# ('B00022749Q', 'Amazon Warehouse ', 65, Timedelta('6 days 08:00:00'))
# ('B00022749Q', 'amazon', 22, Timedelta('6 days 08:00:00'))
# ('B0002CZU1U', 'City Tienda', 0, Timedelta('5 days 21:00:00'))
# ('B0002CZU1U', 'Musik Center', 1, Timedelta('6 days 08:00:00'))
# ('B0002CZU1U', 'Musikhaus Kirstein GmbH', 21, Timedelta('6 days 08:00:00'))
# ('B0002CZU1U', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B0002CZYW0', 'HeBa - Sound & Music', 0, Timedelta('6 days 04:00:00'))
# ('B0002CZYW0', 'MusicScout', 21, Timedelta('6 days 08:00:00'))
# ('B0002E1O68', 'Amazon Warehouse ', 11, Timedelta('1 days 16:00:00'))
# ('B0002E1O68', 'Boutikazik', 0, Timedelta('6 days 07:00:00'))
# ('B0002E1O68', 'Coloretta', 0, Timedelta('5 days 10:00:00'))
# ('B0002E1O68', 'Fast Media Ships From USA', 0, Timedelta('5 days 10:00:00'))
# ('B0002E1O68', 'MusicScout', 60, Timedelta('6 days 07:00:00'))
# ('B0002E1O68', 'Okmusic-Musikfachgeschäft', 0, Timedelta('6 days 07:00:00'))
# ('B0002E1O68', 'Rig Expert', 0, Timedelta('6 days 07:00:00'))
# ('B0002E1O68', 'US international service', 0, Timedelta('5 days 10:00:00'))
# ('B0002E1O68', 'Zoundhouse - Dresden', 0, Timedelta('6 days 07:00:00'))
# ('B0002E1O68', 'amazon', 21, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', "'OOTB'", 0, Timedelta('6 days 01:00:00'))
# ('B0002HOS7M', '7tronix', 0, Timedelta('6 days 02:00:00'))
# ('B0002HOS7M', 'ABC-Schnäppchenmarkt GmbH', 0, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'ARDEBO', 2, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'Belion-World', 1, Timedelta('6 days 01:00:00'))
# ('B0002HOS7M', 'Casa Haushalt', 36, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'Deltatecc GmbH', 4, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'ETOH24', 0, Timedelta('6 days 04:00:00'))
# ('B0002HOS7M', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'Electro-Center', 27, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'Elektronik-Versand', 5, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'EliXito', 0, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'Fashion-Home-Trend', 63, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'GREINER GROSSHANDEL', 24, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'Happy Home Srl', 0, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'Kaleido.Shop GmbH', 32, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'Kommerzpunkt', 4, Timedelta('6 days 06:00:00'))
# ('B0002HOS7M', 'MIOGA Warenhandel & Service GmbH', 7, Timedelta('5 days 12:00:00'))
# ('B0002HOS7M', 'MassaMarkt B.V.', 2, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'Masskas', 10, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'Power & Handel Vertriebs-GmbH', 10, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'SchönerDaheim', 0, Timedelta('6 days 02:00:00'))
# ('B0002HOS7M', 'Spiele-und-Abenteuer', 0, Timedelta('6 days 02:00:00'))
# ('B0002HOS7M', 'UEBilliger', 0, Timedelta('6 days 06:00:00'))
# ('B0002HOS7M', 'Wohn-Idee24', 1, Timedelta('6 days 06:00:00'))
# ('B0002HOS7M', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'computeruniverse', 42, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'deine-traumfabrik', 0, Timedelta('6 days 06:00:00'))
# ('B0002HOS7M', 'elektrotresen', 0, Timedelta('6 days 06:00:00'))
# ('B0002HOS7M', 'inandout', 7, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'ksw-shop', 0, Timedelta('0 days 20:00:00'))
# ('B0002HOS7M', 'price-guard', 0, Timedelta('6 days 08:00:00'))
# ('B0002HOS7M', 'tecedo', 0, Timedelta('6 days 07:00:00'))
# ('B0002HOS7M', 'technikgross', 0, Timedelta('6 days 06:00:00'))
# ('B0002HP91Q', '1Deins Computer GmbH', 0, Timedelta('4 days 11:00:00'))
# ('B0002HP91Q', 'AS-Discount', 2, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'Casa Haushalt', 26, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'Cernovia', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Culinaris Küchenaccessoires', 4, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'DASTRO ® --- Einfach. Genial. Günstig.', 0, Timedelta('3 days 19:00:00'))
# ('B0002HP91Q', 'DaJa-Computer GbR', 16, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'Deltatecc GmbH', 0, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'ETOH24', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'Elektro4000de', 7, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Elektronik-Versand', 0, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'EliXito', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'GREINER GROSSHANDEL', 2, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'Graphodruck', 7, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Happy Home Srl', 0, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'INVE', 0, Timedelta('1 days 15:00:00'))
# ('B0002HP91Q', 'JACOB ⭐⭐⭐⭐⭐', 2, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'Kaleido.Shop GmbH', 0, Timedelta('4 days 21:00:00'))
# ('B0002HP91Q', 'Kommerzpunkt', 0, Timedelta('4 days 15:00:00'))
# ('B0002HP91Q', 'Kurfurst GmbH', 0, Timedelta('3 days 23:00:00'))
# ('B0002HP91Q', 'MIOGA Warenhandel & Service GmbH', 1, Timedelta('4 days 02:00:00'))
# ('B0002HP91Q', 'Millennium Star', 0, Timedelta('0 days 00:00:00'))
# ('B0002HP91Q', 'Olano GmbH', 1, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Stortle', 1, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Technikprimus', 0, Timedelta('0 days 17:00:00'))
# ('B0002HP91Q', 'Traumpreisfabrik', 0, Timedelta('4 days 15:00:00'))
# ('B0002HP91Q', 'UEBilliger', 0, Timedelta('5 days 22:00:00'))
# ('B0002HP91Q', 'Voelkner', 0, Timedelta('5 days 22:00:00'))
# ('B0002HP91Q', 'Wohn-Idee24', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'Yeppon', 0, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'amazon', 18, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'computeruniverse', 40, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'deine-traumfabrik', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'e-joker', 20, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'get goods', 2, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'hbh24online', 0, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'inandout', 2, Timedelta('4 days 20:00:00'))
# ('B0002HP91Q', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 24, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'nierlecom', 21, Timedelta('5 days 20:00:00'))
# ('B0002HP91Q', 'nox divendo', 13, Timedelta('1 days 20:00:00'))
# ('B0002HP91Q', 'price-guard', 0, Timedelta('6 days 08:00:00'))
# ('B0002HP91Q', 'priz24', 0, Timedelta('5 days 22:00:00'))
# ('B0002HP91Q', 'shoppingpoint24', 4, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'spiessxxl', 0, Timedelta('5 days 22:00:00'))
# ('B0002HP91Q', 'tecedo', 0, Timedelta('4 days 22:00:00'))
# ('B0002HP91Q', 'technikgross', 0, Timedelta('4 days 09:00:00'))
# ('B0002HP91Q', 'vavado', 0, Timedelta('3 days 20:00:00'))
# ('B0002MRCLQ', 'City Tienda', 0, Timedelta('1 days 21:00:00'))
# ('B0002MRCLQ', 'MUSIC STORE Professional', 0, Timedelta('6 days 07:00:00'))
# ('B0002MRCLQ', 'amazon', 21, Timedelta('6 days 08:00:00'))
# ('B0006HXHEI', 'Amazon Warehouse ', 9, Timedelta('3 days 01:00:00'))
# ('B0006HXHEI', 'Buerobedarf-24', 0, Timedelta('4 days 18:00:00'))
# ('B0006HXHEI', 'ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe', 4, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'JuKaMa', 0, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'M & L         aus Deutschland', 0, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'MIOGA Warenhandel & Service GmbH', 10, Timedelta('5 days 11:00:00'))
# ('B0006HXHEI', 'PreisDeal24 "inkl. 19% MwSt."', 0, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'Smart Distribution Technologies', 11, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'TESLA STATION UK', 19, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'TREPKE', 0, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'ZAIDOO - Hier zählst Du!', 34, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'amazon', 26, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'coseon-de', 0, Timedelta('6 days 07:00:00'))
# ('B0006HXHEI', 'diktiergeraetundzubehoer', 0, Timedelta('1 days 11:00:00'))
# ('B0006HXHEI', 'e-joker', 1, Timedelta('0 days 19:00:00'))
# ('B0006HXHEI', 'mcbuero_gmbh', 0, Timedelta('2 days 22:00:00'))
# ('B0006HXHEI', 'nbg-games', 0, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'produktfabrik', 0, Timedelta('5 days 20:00:00'))
# ('B0006HXHEI', 'werte7', 0, Timedelta('6 days 07:00:00'))
# ('B0009NPOL8', 'M & L         aus Deutschland', 0, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'Modellauto Wanner', 0, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'Modellbahn-Voigt', 0, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'Modellbau Fischer', 0, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'RAREWAVES-DE', 12, Timedelta('3 days 05:00:00'))
# ('B0009NPOL8', 'Rasppishop', 22, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'amazon', 16, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'inandout', 16, Timedelta('6 days 08:00:00'))
# ('B0009NPOL8', 'meine-kleine-eisenbahn', 0, Timedelta('5 days 22:00:00'))
# ('B0009NPOL8', 'ms-plueth', 0, Timedelta('6 days 08:00:00'))
# ('B0009V6N1U', 'ABC-Schnäppchenmarkt GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'ARDEBO', 0, Timedelta('5 days 23:00:00'))
# ('B0009V6N1U', 'AS-Discount', 2, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Amazon Warehouse ', 13, Timedelta('4 days 05:00:00'))
# ('B0009V6N1U', 'CW-SHOPPING', 29, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Cernovia', 0, Timedelta('6 days 00:00:00'))
# ('B0009V6N1U', 'DaJa-Computer GbR', 9, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'Danto GmbH', 0, Timedelta('6 days 00:00:00'))
# ('B0009V6N1U', 'ETOH24', 0, Timedelta('5 days 23:00:00'))
# ('B0009V6N1U', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Electropolis_Online', 0, Timedelta('6 days 01:00:00'))
# ('B0009V6N1U', 'Elektronik-Versand', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'EliXito', 0, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'GREINER GROSSHANDEL', 26, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Happy Home Srl', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Kaleido.Shop GmbH', 20, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'KitchenKing24', 1, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Kommerzpunkt', 0, Timedelta('5 days 23:00:00'))
# ('B0009V6N1U', 'MIOGA Warenhandel & Service GmbH', 9, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'Masskas', 26, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Olano GmbH', 0, Timedelta('2 days 01:00:00'))
# ('B0009V6N1U', 'Power & Handel Vertriebs-GmbH', 6, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'Spiele-und-Abenteuer', 0, Timedelta('6 days 00:00:00'))
# ('B0009V6N1U', 'Stortle', 6, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'Technikprimus', 0, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'UEBilliger', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'Yeppon', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'amazon', 22, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'boomstore', 0, Timedelta('4 days 06:00:00'))
# ('B0009V6N1U', 'computeruniverse', 19, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'e-joker', 13, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'elektrotresen', 0, Timedelta('5 days 23:00:00'))
# ('B0009V6N1U', 'inandout', 2, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'kaijott', 0, Timedelta('6 days 06:00:00'))
# ('B0009V6N1U', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 23, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'okluge', 13, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'priz24', 0, Timedelta('5 days 23:00:00'))
# ('B0009V6N1U', 'shop-ar', 0, Timedelta('6 days 07:00:00'))
# ('B0009V6N1U', 'technikgross', 0, Timedelta('5 days 12:00:00'))
# ('B000A89EEU', "'OOTB'", 0, Timedelta('5 days 17:00:00'))
# ('B000A89EEU', '7tronix', 0, Timedelta('6 days 05:00:00'))
# ('B000A89EEU', 'ARDEBO', 4, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'AS-Discount', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Casa Haushalt', 47, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'CoolSound-Superstore', 22, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'DaJa-Computer GbR', 16, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'ETOH24', 0, Timedelta('6 days 01:00:00'))
# ('B000A89EEU', 'Elektronik-Versand', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'EliXito', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Fabry GmbH', 0, Timedelta('5 days 17:00:00'))
# ('B000A89EEU', 'Fashion-Home-Trend', 58, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'GREINER GROSSHANDEL', 16, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Happy Home Srl', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'IT Warehouse EU', 2, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Kaleido.Shop GmbH', 24, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Kommerzpunkt', 0, Timedelta('5 days 17:00:00'))
# ('B000A89EEU', 'LICHT-LAMPEN-LEUCHTMITTEL', 0, Timedelta('6 days 05:00:00'))
# ('B000A89EEU', 'MIOGA Warenhandel & Service GmbH', 10, Timedelta('5 days 11:00:00'))
# ('B000A89EEU', 'Masskas', 8, Timedelta('5 days 03:00:00'))
# ('B000A89EEU', 'Power & Handel Vertriebs-GmbH', 8, Timedelta('6 days 06:00:00'))
# ('B000A89EEU', 'SchönerDaheim', 0, Timedelta('1 days 15:00:00'))
# ('B000A89EEU', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('5 days 05:00:00'))
# ('B000A89EEU', 'Spiele-und-Abenteuer', 0, Timedelta('6 days 05:00:00'))
# ('B000A89EEU', 'Stortle', 11, Timedelta('6 days 06:00:00'))
# ('B000A89EEU', 'Technikprimus', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Traumpreisfabrik', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'Wohn-Idee24', 0, Timedelta('6 days 00:00:00'))
# ('B000A89EEU', 'Yeppon', 0, Timedelta('5 days 05:00:00'))
# ('B000A89EEU', 'ZOOM ICI', 0, Timedelta('5 days 06:00:00'))
# ('B000A89EEU', 'amazon', 20, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'computeruniverse', 29, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'deine-traumfabrik', 0, Timedelta('6 days 05:00:00'))
# ('B000A89EEU', 'e-joker', 16, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'elektricworld24', 0, Timedelta('6 days 05:00:00'))
# ('B000A89EEU', 'elektrotresen', 0, Timedelta('6 days 01:00:00'))
# ('B000A89EEU', 'hbh24online', 2, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'inandout', 0, Timedelta('6 days 06:00:00'))
# ('B000A89EEU', 'kaijott', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 7, Timedelta('4 days 11:00:00'))
# ('B000A89EEU', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B000A89EEU', 'priz24', 0, Timedelta('3 days 20:00:00'))
# ('B000A89EEU', 'spiessxxl', 0, Timedelta('5 days 17:00:00'))
# ('B000B2Q2MC', 'Boutikazik', 0, Timedelta('6 days 07:00:00'))
# ('B000B2Q2MC', 'Coloretta', 0, Timedelta('5 days 23:00:00'))
# ('B000B2Q2MC', 'Fast Media Ships From USA', 0, Timedelta('5 days 23:00:00'))
# ('B000B2Q2MC', 'MUSIC STORE Professional', 0, Timedelta('6 days 07:00:00'))
# ('B000B2Q2MC', 'MusicScout', 64, Timedelta('6 days 07:00:00'))
# ('B000B2Q2MC', 'Zoundhouse - Dresden', 0, Timedelta('6 days 07:00:00'))
# ('B000B2Q2MC', 'amazon', 26, Timedelta('6 days 07:00:00'))
# ('B000CRF7M2', 'A-RCS GmbH', 0, Timedelta('5 days 16:00:00'))
# ('B000CRF7M2', 'Amazon', 3, Timedelta('0 days 20:00:00'))
# ('B000CRF7M2', 'Amazon Warehouse ', 21, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'BEMON', 1, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Check Point Stores', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Ferreira Marques', 29, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Haus der Marken', 1, Timedelta('5 days 12:00:00'))
# ('B000CRF7M2', 'INDIGO SHOP', 1, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Jekoshop', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Keggol srl', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Le SAC Outlet', 0, Timedelta('4 days 19:00:00'))
# ('B000CRF7M2', 'Leder.Milz', 0, Timedelta('4 days 13:00:00'))
# ('B000CRF7M2', 'Marken-Koffer', 1, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Martin Pecksteiner', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Pollivaligeria', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'REGALANDIA', 0, Timedelta('4 days 19:00:00'))
# ('B000CRF7M2', 'RUCKSACK', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'STEFANO TALINI', 0, Timedelta('5 days 21:00:00'))
# ('B000CRF7M2', 'Sapato-it', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Shopping Factory', 22, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Silmà Boutique', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'TradeINN', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'Vexo IT', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'WE LOVE BAGS', 28, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'beimerilin', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'jeanstation', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'modeherz "Alle Preise inkl. Mwst."', 0, Timedelta('6 days 08:00:00'))
# ('B000CRF7M2', 'schulranzenwelt', 0, Timedelta('5 days 16:00:00'))
# ('B000EEJH9C', 'Boutikazik', 0, Timedelta('6 days 08:00:00'))
# ('B000EEJH9C', 'Fast Media Ships From USA', 0, Timedelta('5 days 18:00:00'))
# ('B000EEJH9C', 'MUSIC STORE Professional', 0, Timedelta('6 days 08:00:00'))
# ('B000EEJH9C', 'UME Union Musical', 0, Timedelta('1 days 23:00:00'))
# ('B000EEJH9C', 'amazon', 20, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'Arcobaleno Centro Musicale', 23, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'MUSIC STORE Professional', 0, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'MusicScout', 51, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'Musik Center', 2, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'Musik Produktiv', 23, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B000EELCB8', 'amazon', 23, Timedelta('6 days 08:00:00'))
# ('B000EENFIG', 'Alegree', 22, Timedelta('6 days 08:00:00'))
# ('B000EENFIG', 'Coloretta', 0, Timedelta('5 days 16:00:00'))
# ('B000EENFIG', 'Fast Media Ships From USA', 0, Timedelta('5 days 16:00:00'))
# ('B000EENFIG', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B000EENFIG', 'amazon', 22, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'Body & Fit Nutrition', 45, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'Colosseum-Nutrition', 22, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'Fitness2002', 22, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'Körperwelt24', 1, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'MUSCLEPRIME SL', 0, Timedelta('0 days 08:00:00'))
# ('B000GISU1M', 'Magnolia EU', 0, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'NUTRIFITNESS', 0, Timedelta('5 days 16:00:00'))
# ('B000GISU1M', 'SFD Nutrition', 0, Timedelta('6 days 08:00:00'))
# ('B000GISU1M', 'Sportnahrung-Nutrition1', 0, Timedelta('5 days 16:00:00'))
# ('B000GISU1M', 'prsWORLD', 22, Timedelta('6 days 08:00:00'))
# ('B000IUQRXQ', 'Casa Due pur GmbH', 18, Timedelta('3 days 04:00:00'))
# ('B000IUQRXQ', 'Lothar John', 0, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'Schäffer24', 1, Timedelta('5 days 08:00:00'))
# ('B000IUQRXQ', 'YESEATIS', 0, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'adero Design', 22, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'amazon', 29, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'erkmann - wohnen design geschenke', 6, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'ikarus...design shop', 0, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'inwohn', 0, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'livingtools', 0, Timedelta('5 days 08:00:00'))
# ('B000IUQRXQ', 'newpop', 13, Timedelta('6 days 07:00:00'))
# ('B000IUQRXQ', 'priz24', 0, Timedelta('1 days 09:00:00'))
# ('B000IYEMYI', '"Home-Elektro"', 0, Timedelta('6 days 02:00:00'))
# ('B000IYEMYI', '1Deins Computer GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'ARDEBO', 0, Timedelta('4 days 20:00:00'))
# ('B000IYEMYI', 'AS-Discount', 20, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Amazon Warehouse ', 8, Timedelta('5 days 06:00:00'))
# ('B000IYEMYI', 'Casa Haushalt', 4, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'CoolSound-Superstore', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Cstore.', 26, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Deltatecc GmbH', 2, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'E-Tarastore', 1, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'ETOH24', 0, Timedelta('5 days 21:00:00'))
# ('B000IYEMYI', 'Electronic XXL Sachsen', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'Electropolis_Online', 0, Timedelta('1 days 19:00:00'))
# ('B000IYEMYI', 'Elektro-Shop Köck GmbH', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Elektronik-Versand', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'EliXito', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'GREINER GROSSHANDEL', 0, Timedelta('4 days 18:00:00'))
# ('B000IYEMYI', 'GetMarket', 1, Timedelta('2 days 20:00:00'))
# ('B000IYEMYI', 'Kommerzpunkt', 1, Timedelta('5 days 21:00:00'))
# ('B000IYEMYI', 'LULUBUY S.A.R.L', 0, Timedelta('6 days 02:00:00'))
# ('B000IYEMYI', 'MARMURO EUROPE', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'MEDIACASH', 0, Timedelta('1 days 17:00:00'))
# ('B000IYEMYI', 'MIOGA Warenhandel & Service GmbH', 5, Timedelta('5 days 13:00:00'))
# ('B000IYEMYI', 'Muno_Store', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'NeueKaufleute', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'Omnya Diversity', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'ProComponentes', 12, Timedelta('3 days 05:00:00'))
# ('B000IYEMYI', 'SNOGARD Computer GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 0, Timedelta('1 days 10:00:00'))
# ('B000IYEMYI', 'Spiele-und-Abenteuer', 1, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'Stortle', 24, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Technikprimus', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'Traumpreisfabrik', 0, Timedelta('1 days 11:00:00'))
# ('B000IYEMYI', 'UEBilliger', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'Weichhold GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'ZOOM ICI', 3, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'amazon', 23, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'computeruniverse', 42, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'e-joker', 12, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'elektricworld24', 0, Timedelta('0 days 00:00:00'))
# ('B000IYEMYI', 'elektrotresen', 0, Timedelta('5 days 21:00:00'))
# ('B000IYEMYI', 'inandout', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'nox divendo', 13, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'nrsolutions', 1, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'price-guard', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'priz24', 0, Timedelta('5 days 21:00:00'))
# ('B000IYEMYI', 'shop-ar', 0, Timedelta('6 days 08:00:00'))
# ('B000IYEMYI', 'spiessxxl', 0, Timedelta('6 days 07:00:00'))
# ('B000IYEMYI', 'tecedo', 0, Timedelta('0 days 00:00:00'))
# ('B000KTBF8C', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 08:00:00'))
# ('B000KTBF8C', 'TESLA STATION UK', 18, Timedelta('6 days 08:00:00'))
# ('B000KTBF8C', 'diktiergeraetundzubehoer', 0, Timedelta('6 days 08:00:00'))
# ('B000KTBF8C', 'priz24', 1, Timedelta('5 days 12:00:00'))
# ('B000KTBF8C', 'werte7', 0, Timedelta('6 days 08:00:00'))
# ('B000KZBD4M', 'XXL-Phones', 2, Timedelta('5 days 22:00:00'))
# ('B000LPSNRQ', 'Amazon Warehouse ', 18, Timedelta('2 days 16:00:00'))
# ('B000LPSNRQ', 'City Tienda', 0, Timedelta('5 days 21:00:00'))
# ('B000LPSNRQ', 'Fast Media Ships From USA', 0, Timedelta('5 days 21:00:00'))
# ('B000LPSNRQ', 'amazon', 4, Timedelta('1 days 00:00:00'))
# ('B000MJR8UO', 'Amazon Warehouse ', 12, Timedelta('3 days 05:00:00'))
# ('B000MJR8UO', 'Boutikazik', 0, Timedelta('6 days 08:00:00'))
# ('B000MJR8UO', 'Musik Center', 2, Timedelta('6 days 08:00:00'))
# ('B000MJR8UO', 'amazon', 15, Timedelta('6 days 08:00:00'))
# ('B000MQG3US', 'Buerobedarf-24', 0, Timedelta('5 days 23:00:00'))
# ('B000MQG3US', 'Erdigo', 0, Timedelta('4 days 09:00:00'))
# ('B000MQG3US', 'FS Onlinehandel UG', 16, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'GREINER GROSSHANDEL', 16, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'Happy Home Italia', 0, Timedelta('1 days 11:00:00'))
# ('B000MQG3US', 'Happy Home Srl', 4, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'JACOB ⭐⭐⭐⭐⭐', 6, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'KAUT-BULLINGER Office + Solution GmbH', 0, Timedelta('5 days 23:00:00'))
# ('B000MQG3US', 'Löchel_Industriebedarf', 15, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'Power & Handel Vertriebs-GmbH', 11, Timedelta('6 days 07:00:00'))
# ('B000MQG3US', 'TREPKE', 0, Timedelta('5 days 23:00:00'))
# ('B000MQG3US', 'amazon', 26, Timedelta('6 days 08:00:00'))
# ('B000MQG3US', 'get online GmbH', 0, Timedelta('5 days 23:00:00'))
# ('B000MQG3US', 'mcbuero_gmbh', 0, Timedelta('5 days 23:00:00'))
# ('B000MQG3US', 'priz24', 0, Timedelta('5 days 23:00:00'))
# ('B000NC8ETE', 'Amazon Warehouse ', 56, Timedelta('6 days 08:00:00'))
# ('B000NC8ETE', 'amazon', 27, Timedelta('6 days 08:00:00'))
# ('B000ONLUHA', '1Deins Computer GmbH', 0, Timedelta('5 days 23:00:00'))
# ('B000ONLUHA', 'ARDEBO', 1, Timedelta('6 days 00:00:00'))
# ('B000ONLUHA', 'Bremer Elektrohandel', 0, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'DaJa-Computer GbR', 24, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'ETOH24', 0, Timedelta('5 days 23:00:00'))
# ('B000ONLUHA', 'Elektro4000de', 29, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'Happy Home Italia', 0, Timedelta('6 days 06:00:00'))
# ('B000ONLUHA', 'Happy Home Srl', 32, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'Kommerzpunkt', 1, Timedelta('5 days 23:00:00'))
# ('B000ONLUHA', 'Olano GmbH', 4, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'ROMMELSBACHER Germany', 0, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'Stortle', 10, Timedelta('2 days 03:00:00'))
# ('B000ONLUHA', 'Technikprimus', 0, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'Traumpreisfabrik', 0, Timedelta('1 days 15:00:00'))
# ('B000ONLUHA', 'UNICOBRES', 0, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'Westfalia', 0, Timedelta('5 days 23:00:00'))
# ('B000ONLUHA', 'amazon', 26, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'computeruniverse', 45, Timedelta('6 days 07:00:00'))
# ('B000ONLUHA', 'e-joker', 5, Timedelta('1 days 16:00:00'))
# ('B000ONLUHA', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B000PJBQT0', 'Computerhandlung', 5, Timedelta('2 days 02:00:00'))
# ('B000PJBQT0', 'DaJa-Computer GbR', 17, Timedelta('6 days 07:00:00'))
# ('B000PJBQT0', 'Happy Home Italia', 0, Timedelta('5 days 20:00:00'))
# ('B000PJBQT0', 'Happy Home Srl', 21, Timedelta('6 days 07:00:00'))
# ('B000PJBQT0', 'ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe', 21, Timedelta('6 days 07:00:00'))
# ('B000PJBQT0', 'PC-KING', 1, Timedelta('0 days 21:00:00'))
# ('B000PJBQT0', 'Traumpreisfabrik', 0, Timedelta('0 days 02:00:00'))
# ('B000PJBQT0', 'Yeppon', 0, Timedelta('6 days 07:00:00'))
# ('B000PJBQT0', 'vollfarbdrucker-de Ihre Office Experten', 0, Timedelta('5 days 20:00:00'))
# ('B000RVZU20', 'City Tienda', 0, Timedelta('6 days 02:00:00'))
# ('B000RVZU20', 'HeBa - Sound & Music', 0, Timedelta('6 days 02:00:00'))
# ('B000RVZU20', 'MUSIC STORE Professional', 0, Timedelta('6 days 08:00:00'))
# ('B000RVZU20', 'Musikhaus-Korn', 0, Timedelta('6 days 08:00:00'))
# ('B000RVZU20', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B000RVZU20', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'Bremer Elektrohandel', 0, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'EFI Global Store DE', 16, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'Elektro-Himmel. Preise inkl. MwSt.', 0, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'Elektro4000de', 43, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'Elektronik-Versand', 0, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'InstaSpares', 20, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'MIOGA Warenhandel & Service GmbH', 1, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'Voelkner', 0, Timedelta('4 days 06:00:00'))
# ('B000SIR14M', 'computeruniverse', 0, Timedelta('5 days 18:00:00'))
# ('B000SIR14M', 'hbh24online', 18, Timedelta('6 days 08:00:00'))
# ('B000SIR14M', 'nox divendo', 21, Timedelta('6 days 08:00:00'))
# ('B000T10P6O', 'Eazik', 0, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'Elcotec Electronic', 0, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'FScommerce', 0, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'Happy Home Italia', 0, Timedelta('4 days 09:00:00'))
# ('B000T10P6O', 'Happy Home Srl', 5, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'JACOB ⭐⭐⭐⭐⭐', 2, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'Millennium Star', 0, Timedelta('5 days 03:00:00'))
# ('B000T10P6O', 'Music and More Store', 75, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'Pro Lighting e.K.', 54, Timedelta('6 days 07:00:00'))
# ('B000T10P6O', 'Simply Sound Ltd', 0, Timedelta('5 days 03:00:00'))
# ('B000T10P6O', 'Z-Bombilla', 0, Timedelta('5 days 03:00:00'))
# ('B000T10P6O', 'amazon', 6, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Amazon Warehouse ', 42, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Fast Media Ships From USA', 0, Timedelta('1 days 10:00:00'))
# ('B000TGHVGQ', 'HeBa - Sound & Music', 0, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'MUSIC STORE Professional', 0, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Music and More Store', 0, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'MusicScout', 42, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Musik Center', 2, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Musikhaus Kirstein GmbH', 27, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'UME Union Musical', 0, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'Zoundhouse - Dresden', 0, Timedelta('6 days 07:00:00'))
# ('B000TGHVGQ', 'amazon', 27, Timedelta('6 days 07:00:00'))
# ('B000VDNZ1M', 'Banemo - Rund ums Haus', 0, Timedelta('5 days 20:00:00'))
# ('B000VDNZ1M', 'BlumenbeckerIndustriebedarf GmbH', 20, Timedelta('5 days 05:00:00'))
# ('B000VDNZ1M', 'Dönges', 24, Timedelta('6 days 07:00:00'))
# ('B000VDNZ1M', 'HEPEshop', 0, Timedelta('5 days 20:00:00'))
# ('B000VDNZ1M', 'Mercatus Online', 0, Timedelta('5 days 20:00:00'))
# ('B000VDNZ1M', 'PRAXER', 0, Timedelta('5 days 20:00:00'))
# ('B000VDNZ1M', 'Tooler-de', 0, Timedelta('5 days 20:00:00'))
# ('B000VDNZ1M', 'WerkzeugHERO - Ihr Fachhändler aus Deutschland', 24, Timedelta('6 days 07:00:00'))
# ('B000VDNZ1M', 'amazon', 24, Timedelta('6 days 07:00:00'))
# ('B000VDNZ1M', 'markenbaumarkt24', 1, Timedelta('6 days 07:00:00'))
# ('B000WH2TH8', 'ARCOUFFICIO', 0, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'Buerobedarf-24', 0, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'Büroservice VS', 12, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'Coolibry', 0, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'FS Onlinehandel UG', 14, Timedelta('6 days 07:00:00'))
# ('B000WH2TH8', 'JuKaMa', 0, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'amazon', 14, Timedelta('6 days 07:00:00'))
# ('B000WH2TH8', 'priz24', 0, Timedelta('5 days 23:00:00'))
# ('B000WH2TH8', 'vavado', 0, Timedelta('5 days 23:00:00'))
# ('B000WWHOUK', 'MUSIC STORE Professional', 0, Timedelta('6 days 08:00:00'))
# ('B000WWHOUK', 'Music and More Store', 77, Timedelta('6 days 08:00:00'))
# ('B000WWHOUK', 'Musikhaus Kirstein GmbH', 32, Timedelta('6 days 08:00:00'))
# ('B000WWHOUK', 'Musikhaus-Korn', 0, Timedelta('6 days 08:00:00'))
# ('B000WWHOUK', 'Pro Lighting e.K.', 45, Timedelta('6 days 08:00:00'))
# ('B000WWHOUK', 'deejays GmbH', 0, Timedelta('6 days 04:00:00'))
# ('B000WZ7FT2', 'Musik Center', 2, Timedelta('6 days 07:00:00'))
# ('B000WZ7FT2', 'amazon', 27, Timedelta('6 days 08:00:00'))
# ('B000XFG40W', 'Cristallerie Locatelli', 30, Timedelta('6 days 08:00:00'))
# ('B000XFG40W', 'amazon', 30, Timedelta('6 days 08:00:00'))
# ('B000XFG40W', 'fairmarkt24', 30, Timedelta('6 days 08:00:00'))
# ('B000XZ5XJ0', 'Eazik', 0, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'Elcotec Electronic', 0, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'FScommerce', 0, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'Happy Home Italia', 0, Timedelta('5 days 18:00:00'))
# ('B000XZ5XJ0', 'Happy Home Srl', 25, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'MIDI Centrum Muzyczne', 0, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'Pro Lighting e.K.', 25, Timedelta('6 days 07:00:00'))
# ('B000XZ5XJ0', 'Simply Sound Ltd', 0, Timedelta('5 days 18:00:00'))
# ('B000XZ5XJ0', 'Z-Bombilla', 0, Timedelta('5 days 18:00:00'))
# ('B000XZ5XJ0', 'amazon', 25, Timedelta('6 days 07:00:00'))
# ('B000YK5W18', 'Amazon Warehouse ', 5, Timedelta('0 days 20:00:00'))
# ('B000YK5W18', 'Pet Mate Ltd.', 0, Timedelta('6 days 06:00:00'))
# ('B000YK5W18', 'Ponera', 27, Timedelta('6 days 08:00:00'))
# ('B000YK5W18', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B000Z222L8', 'Boutikazik', 0, Timedelta('6 days 08:00:00'))
# ('B000Z222L8', 'MUSIK-SCHUBERT', 0, Timedelta('1 days 16:00:00'))
# ('B000Z222L8', 'MusicScout', 34, Timedelta('6 days 08:00:00'))
# ('B000Z222L8', 'Notenmühle', 0, Timedelta('1 days 12:00:00'))
# ('B000Z222L8', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B0010M6XBW', 'amazon', 0, Timedelta('6 days 05:00:00'))
# ('B0010M6XBW', 'haupteingang1', 26, Timedelta('6 days 08:00:00'))
# ('B0010M6XBW', 'meine-kleine-eisenbahn', 0, Timedelta('2 days 23:00:00'))
# ('B0011IFT24', 'Bag-Center GbR', 0, Timedelta('4 days 11:00:00'))
# ('B0011IFT24', 'Designhuette Store', 25, Timedelta('6 days 07:00:00'))
# ('B0011IFT24', 'HAUSFELDER accessoires + reise', 0, Timedelta('6 days 07:00:00'))
# ('B0011IFT24', 'Marken-Koffer', 1, Timedelta('6 days 07:00:00'))
# ('B0011IFT24', 'Schuhe24', 0, Timedelta('6 days 07:00:00'))
# ('B0011IFT24', 'WE LOVE BAGS', 31, Timedelta('6 days 07:00:00'))
# ('B0011IFT24', 'modeherz "Alle Preise inkl. Mwst."', 0, Timedelta('6 days 07:00:00'))
# ('B00123DQT6', 'Arcobaleno Centro Musicale', 26, Timedelta('6 days 08:00:00'))
# ('B00123DQT6', 'Musikhaus Hübner', 0, Timedelta('6 days 08:00:00'))
# ('B00123DQT6', 'Musikhaus Kirstein GmbH', 27, Timedelta('4 days 23:00:00'))
# ('B00123DQT6', 'Yeppon', 0, Timedelta('3 days 05:00:00'))
# ('B00123DQT6', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B0012QJZTI', 'Amazon Warehouse ', 85, Timedelta('6 days 07:00:00'))
# ('B0012QJZTI', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B0012QP0P6', 'Amazon Warehouse ', 24, Timedelta('6 days 08:00:00'))
# ('B0012QP0P6', 'RedZilla (Preise inkl. MwSt.) Impressum und AGB finden Sie unter Verkäufer-Hilfe', 20, Timedelta('6 days 08:00:00'))
# ('B0012QP0P6', 'Sport-Thieme GmbH', 0, Timedelta('5 days 19:00:00'))
# ('B0012QP0P6', 'amazon', 12, Timedelta('6 days 08:00:00'))
# ('B0012QP0P6', 'sporttrend24', 0, Timedelta('6 days 08:00:00'))
# ('B0013NSJT2', 'Amazon Warehouse ', 60, Timedelta('6 days 07:00:00'))
# ('B0013NSJT2', 'City Kaufhaus Gaggenau', 0, Timedelta('5 days 23:00:00'))
# ('B0013NSJT2', 'HöberOnline', 2, Timedelta('4 days 20:00:00'))
# ('B0013NSJT2', 'Lederoase', 38, Timedelta('6 days 07:00:00'))
# ('B0013NSJT2', 'Lederwaren Littmann', 2, Timedelta('5 days 23:00:00'))
# ('B0013NSJT2', 'Loupas', 30, Timedelta('6 days 07:00:00'))
# ('B0013NSJT2', 'Mode Steffen', 0, Timedelta('5 days 23:00:00'))
# ('B0013NSJT2', 'Schuhe24', 16, Timedelta('6 days 07:00:00'))
# ('B0013NSJT2', 'amazon', 35, Timedelta('6 days 08:00:00'))
# ('B00144EEBM', 'Fast Media Ships From USA', 0, Timedelta('6 days 03:00:00'))
# ('B00144EEBM', 'amazon', 20, Timedelta('6 days 07:00:00'))
# ('B00144EEBM', 'inandout', 20, Timedelta('6 days 07:00:00'))
# ('B00144EEBM', 'meine-kleine-eisenbahn', 0, Timedelta('6 days 03:00:00'))
# ('B00144EEBM', 'ms-plueth', 0, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'ARDEBO', 1, Timedelta('5 days 21:00:00'))
# ('B0014DPPH0', 'Bremer Elektrohandel', 0, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'Casa Haushalt', 46, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'Conrad Electronic SE', 0, Timedelta('6 days 05:00:00'))
# ('B0014DPPH0', 'E-Mistero', 0, Timedelta('6 days 05:00:00'))
# ('B0014DPPH0', 'E-stock Electronics', 4, Timedelta('3 days 11:00:00'))
# ('B0014DPPH0', 'E-trading-click', 0, Timedelta('5 days 10:00:00'))
# ('B0014DPPH0', 'EFI Global Store DE', 8, Timedelta('6 days 06:00:00'))
# ('B0014DPPH0', 'Elektronik-Versand', 0, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'GREINER GROSSHANDEL', 13, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'HOLTI', 0, Timedelta('3 days 22:00:00'))
# ('B0014DPPH0', 'INVE', 0, Timedelta('1 days 02:00:00'))
# ('B0014DPPH0', 'InstaSpares', 35, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'Kurfurst GmbH', 8, Timedelta('6 days 06:00:00'))
# ('B0014DPPH0', 'MIOGA Warenhandel & Service GmbH', 5, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'PROSO', 8, Timedelta('3 days 22:00:00'))
# ('B0014DPPH0', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 0, Timedelta('6 days 06:00:00'))
# ('B0014DPPH0', 'Spiele-und-Abenteuer', 0, Timedelta('6 days 05:00:00'))
# ('B0014DPPH0', 'Star +', 0, Timedelta('6 days 05:00:00'))
# ('B0014DPPH0', 'Technikprimus', 0, Timedelta('6 days 07:00:00'))
# ('B0014DPPH0', 'Voelkner', 0, Timedelta('6 days 05:00:00'))
# ('B0014DPPH0', 'elektricworld24', 0, Timedelta('1 days 09:00:00'))
# ('B0014DPPH0', 'hbh24online', 12, Timedelta('6 days 07:00:00'))
# ('B0019DACQY', 'City Tienda', 0, Timedelta('5 days 15:00:00'))
# ('B0019DACQY', 'HeBa - Sound & Music', 0, Timedelta('5 days 15:00:00'))
# ('B0019DACQY', 'Music and More Store', 27, Timedelta('6 days 07:00:00'))
# ('B0019DACQY', 'Zoundhouse - Dresden', 0, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', '1Deins Computer GmbH', 0, Timedelta('5 days 21:00:00'))
# ('B001AZH3B8', 'AS-Discount', 12, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'Amazon Warehouse ', 40, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'Casa Haushalt', 9, Timedelta('1 days 04:00:00'))
# ('B001AZH3B8', 'DaJa-Computer GbR', 18, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'EURONICS XXL Vilshofen', 0, Timedelta('6 days 06:00:00'))
# ('B001AZH3B8', 'EliXito', 0, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'GREINER GROSSHANDEL', 34, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'Gastro & Office', 0, Timedelta('4 days 16:00:00'))
# ('B001AZH3B8', 'GetMarket', 14, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'Haase Shopping e. K.', 0, Timedelta('2 days 07:00:00'))
# ('B001AZH3B8', 'INVE', 0, Timedelta('3 days 23:00:00'))
# ('B001AZH3B8', 'Kurfurst GmbH', 4, Timedelta('4 days 03:00:00'))
# ('B001AZH3B8', 'MIOGA Warenhandel & Service GmbH', 1, Timedelta('5 days 12:00:00'))
# ('B001AZH3B8', 'Power & Handel Vertriebs-GmbH', 24, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'SNOGARD Computer GmbH', 0, Timedelta('5 days 21:00:00'))
# ('B001AZH3B8', 'SchönerDaheim', 0, Timedelta('5 days 17:00:00'))
# ('B001AZH3B8', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 06:00:00'))
# ('B001AZH3B8', 'Stortle', 16, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'Technikprimus', 0, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'UEBilliger', 0, Timedelta('6 days 01:00:00'))
# ('B001AZH3B8', 'Yeppon', 0, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'amazon', 24, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'boomstore', 0, Timedelta('5 days 21:00:00'))
# ('B001AZH3B8', 'computeruniverse', 30, Timedelta('6 days 06:00:00'))
# ('B001AZH3B8', 'e-joker', 15, Timedelta('6 days 07:00:00'))
# ('B001AZH3B8', 'inandout', 12, Timedelta('6 days 07:00:00'))
# ...
# ('B0B9GJLV2D', 'ZOXS  GmbH', 23, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'amazon', 28, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'boomstore', 0, Timedelta('6 days 05:00:00'))
# ('B0B9GJLV2D', 'computeruniverse', 21, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'cyberport', 0, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'e-joker', 11, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'kaijott', 0, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'medialand4you. Händler & Versand aus Deutschland', 0, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 5, Timedelta('6 days 07:00:00'))
# ('B0B9GJLV2D', 'officeservicesrl', 2, Timedelta('6 days 07:00:00'))
# ('B0B9GJLV2D', 'priz24', 0, Timedelta('6 days 05:00:00'))
# ('B0B9GJLV2D', 'rankauf', 0, Timedelta('4 days 14:00:00'))
# ('B0B9GJLV2D', 'technikbilliger', 0, Timedelta('3 days 04:00:00'))
# ('B0B9GJLV2D', 'technikgross', 0, Timedelta('6 days 05:00:00'))
# ('B0B9GJLV2D', 'tiendainformatica-de', 9, Timedelta('6 days 07:00:00'))
# ('B0B9GJLV2D', 'x-kom', 0, Timedelta('6 days 08:00:00'))
# ('B0B9GJLV2D', 'yoused  GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B0B9XXTN28', 'Amazon Warehouse ', 50, Timedelta('6 days 07:00:00'))
# ('B0B9XXTN28', 'amazon', 25, Timedelta('6 days 07:00:00'))
# ('B0BBWDDV95', 'AS-Discount', 23, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'DaJa-Computer GbR', 15, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'Happy Home Italia', 0, Timedelta('5 days 16:00:00'))
# ('B0BBWDDV95', 'Happy Home Srl', 15, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'IntechTrade', 1, Timedelta('1 days 20:00:00'))
# ('B0BBWDDV95', 'LessPaid ✅', 23, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'Solution 4YOU', 0, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'Stortle', 16, Timedelta('4 days 12:00:00'))
# ('B0BBWDDV95', 'TechnologyONE Germany', 2, Timedelta('0 days 14:00:00'))
# ('B0BBWDDV95', 'Traumpreisfabrik', 0, Timedelta('5 days 20:00:00'))
# ('B0BBWDDV95', 'amazon', 54, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'e-joker', 54, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'price-guard', 0, Timedelta('6 days 08:00:00'))
# ('B0BBWDDV95', 'vollfarbdrucker-de Ihre Office Experten', 2, Timedelta('5 days 20:00:00'))
# ('B0BC8L2D29', 'Panini Deutschland Marketplace', 23, Timedelta('6 days 07:00:00'))
# ('B0BC8L2D29', 'Sticker-und-co-de', 6, Timedelta('0 days 22:00:00'))
# ('B0BC8L2D29', 'Stickerdealz', 0, Timedelta('6 days 07:00:00'))
# ('B0BC8L2D29', 'Verflixt & Zugespielt', 0, Timedelta('5 days 23:00:00'))
# ('B0BC8L2D29', 'collect-it-de VEDES-Spielwaren', 0, Timedelta('6 days 07:00:00'))
# ('B0BC8L2D29', 'sl-auktion', 10, Timedelta('1 days 05:00:00'))
# ('B0BCG7437G', 'Amazon US', 1, Timedelta('6 days 07:00:00'))
# ('B0BCG7437G', 'Terra Master', 19, Timedelta('6 days 07:00:00'))
# ('B0BD5Z5T8C', 'Amazon Warehouse ', 7, Timedelta('2 days 22:00:00'))
# ('B0BD8ZZLYC', 'Amazon Warehouse ', 51, Timedelta('6 days 07:00:00'))
# ('B0BD8ZZLYC', 'amazon', 25, Timedelta('6 days 07:00:00'))
# ('B0BDJJY92W', 'Amazon Warehouse ', 66, Timedelta('6 days 07:00:00'))
# ('B0BDJJY92W', 'COMSPOT GmbH', 0, Timedelta('3 days 06:00:00'))
# ('B0BDJJY92W', 'Flanco Retail', 0, Timedelta('5 days 20:00:00'))
# ('B0BDJJY92W', 'GRAVIS - Computervertriebsgesellschaft mbH', 0, Timedelta('5 days 20:00:00'))
# ('B0BDJJY92W', 'amazon', 16, Timedelta('6 days 07:00:00'))
# ('B0BDJJY92W', 'cyberport', 0, Timedelta('5 days 20:00:00'))
# ('B0BF5V62K2', 'Amazon US', 0, Timedelta('6 days 07:00:00'))
# ('B0BF5V62K2', 'SPORT AND TREND', 9, Timedelta('2 days 06:00:00'))
# ('B0BF5V62K2', 'Takemore', 1, Timedelta('6 days 07:00:00'))
# ('B0BF5V62K2', 'dlSPORTs  EU', 9, Timedelta('6 days 07:00:00'))
# ('B0BF5V62K2', 'racket-sports', 18, Timedelta('6 days 07:00:00'))
# ('B0BFRWGQ1K', 'BagsOnline', 16, Timedelta('2 days 19:00:00'))
# ('B0BFRWGQ1K', 'DER BREU', 0, Timedelta('6 days 07:00:00'))
# ('B0BFRWGQ1K', 'Grünhagel', 0, Timedelta('6 days 07:00:00'))
# ('B0BFRWGQ1K', 'HAUSFELDER accessoires + reise', 1, Timedelta('6 days 07:00:00'))
# ('B0BFRWGQ1K', 'Ideen von A - Z', 0, Timedelta('1 days 05:00:00'))
# ('B0BFRWGQ1K', 'Leder.Milz', 0, Timedelta('0 days 00:00:00'))
# ('B0BFRWGQ1K', 'Lieblingstasche', 30, Timedelta('6 days 07:00:00'))
# ('B0BFRWGQ1K', 'Mode Steffen', 0, Timedelta('6 days 05:00:00'))
# ('B0BFRWGQ1K', 'Nils Traumfabrik', 25, Timedelta('6 days 06:00:00'))
# ('B0BFRWGQ1K', 'Schreibdesign', 0, Timedelta('1 days 14:00:00'))
# ('B0BFRWGQ1K', 'Schuhe24', 2, Timedelta('1 days 03:00:00'))
# ('B0BFRWGQ1K', 'Spielzeugmax', 0, Timedelta('5 days 20:00:00'))
# ('B0BFRWGQ1K', 'Taschenjuwel', 0, Timedelta('2 days 01:00:00'))
# ('B0BFRWGQ1K', 'Wachter Büro AG', 0, Timedelta('5 days 02:00:00'))
# ('B0BFRWGQ1K', 'bestbrand', 2, Timedelta('1 days 03:00:00'))
# ('B0BFRWGQ1K', 'modeherz "Alle Preise inkl. Mwst."', 0, Timedelta('6 days 07:00:00'))
# ('B0BGYGJHQD', 'Doctor Brandt', 0, Timedelta('5 days 22:00:00'))
# ('B0BGYGJHQD', 'Happy Home Srl', 17, Timedelta('6 days 07:00:00'))
# ('B0BGYGJHQD', 'TradeINN', 0, Timedelta('6 days 07:00:00'))
# ('B0BGYGJHQD', 'amazon', 17, Timedelta('6 days 07:00:00'))
# ('B0BJ78YCH1', 'Duckdik', 18, Timedelta('5 days 07:00:00'))
# ('B0BJMC5DBV', 'Amazon Warehouse ', 0, Timedelta('0 days 00:00:00'))
# ('B0BJMC5DBV', 'COMSPOT GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B0BJMC5DBV', 'GRAVIS - Computervertriebsgesellschaft mbH', 1, Timedelta('6 days 07:00:00'))
# ('B0BJMC5DBV', 'amazon', 21, Timedelta('6 days 08:00:00'))
# ('B0BJMKYX88', 'Amazon Warehouse ', 29, Timedelta('6 days 07:00:00'))
# ('B0BJMKYX88', 'NBB Deutschland', 0, Timedelta('5 days 13:00:00'))
# ('B0BJMKYX88', 'amazon', 22, Timedelta('6 days 07:00:00'))
# ('B0BJMVB4ND', 'Amazon Warehouse ', 10, Timedelta('5 days 12:00:00'))
# ('B0BJMVB4ND', 'amazon', 5, Timedelta('5 days 16:00:00'))
# ('B0BJMVB4ND', 'cyberport', 0, Timedelta('6 days 02:00:00'))
# ('B0BJMZSGM7', 'Amazon Warehouse ', 7, Timedelta('4 days 22:00:00'))
# ('B0BJMZSGM7', 'COMSPOT GmbH', 0, Timedelta('6 days 01:00:00'))
# ('B0BJMZSGM7', 'GRAVIS - Computervertriebsgesellschaft mbH', 0, Timedelta('0 days 06:00:00'))
# ('B0BJMZSGM7', 'amazon', 24, Timedelta('6 days 07:00:00'))
# ('B0BJMZSGM7', 'cyberport', 0, Timedelta('2 days 07:00:00'))
# ('B0BJN4T6NJ', '"notebook.de"', 0, Timedelta('5 days 05:00:00'))
# ('B0BJN4T6NJ', 'Amazon Warehouse ', 32, Timedelta('6 days 07:00:00'))
# ('B0BJN4T6NJ', 'COMSPOT GmbH', 0, Timedelta('1 days 22:00:00'))
# ('B0BJN4T6NJ', 'GRAVIS - Computervertriebsgesellschaft mbH', 0, Timedelta('6 days 01:00:00'))
# ('B0BJN4T6NJ', 'Office Partner GmbH', 0, Timedelta('2 days 10:00:00'))
# ('B0BJN4T6NJ', 'amazon', 20, Timedelta('6 days 07:00:00'))
# ('B0BJN4T6NJ', 'cyberport', 0, Timedelta('6 days 01:00:00'))
# ('B0BKGZZP2P', '1Deins Computer GmbH', 0, Timedelta('3 days 21:00:00'))
# ('B0BKGZZP2P', 'AS-Discount', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'Amazon Warehouse ', 16, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'Best of Electronic', 11, Timedelta('2 days 01:00:00'))
# ('B0BKGZZP2P', 'CW-SHOPPING', 14, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'Casa Haushalt', 4, Timedelta('1 days 02:00:00'))
# ('B0BKGZZP2P', 'CheapSell', 0, Timedelta('6 days 02:00:00'))
# ('B0BKGZZP2P', 'DASTRO ® --- Einfach. Genial. Günstig.', 0, Timedelta('6 days 04:00:00'))
# ('B0BKGZZP2P', 'DaJa-Computer GbR', 18, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'ELECTRONIS', 0, Timedelta('5 days 01:00:00'))
# ('B0BKGZZP2P', 'Elektro Sonderposten', 10, Timedelta('2 days 01:00:00'))
# ('B0BKGZZP2P', 'Happy Home Srl', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'JACOB ⭐⭐⭐⭐⭐', 1, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'Kommerzpunkt', 0, Timedelta('0 days 13:00:00'))
# ('B0BKGZZP2P', 'LULUBUY S.A.R.L', 1, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'MIOGA Warenhandel & Service GmbH', 4, Timedelta('5 days 11:00:00'))
# ('B0BKGZZP2P', 'NBB Deutschland', 0, Timedelta('5 days 01:00:00'))
# ('B0BKGZZP2P', 'NaturSchatulle', 2, Timedelta('0 days 06:00:00'))
# ('B0BKGZZP2P', 'Nicotel-DE - Internet & Festnetz', 0, Timedelta('5 days 01:00:00'))
# ('B0BKGZZP2P', 'PC-KING', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'SNOGARD Computer GmbH', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'Schwanthaler Computer', 0, Timedelta('5 days 01:00:00'))
# ('B0BKGZZP2P', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'TRIPPODO EU', 1, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'TechPoint1111', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'Traumpreisfabrik', 0, Timedelta('6 days 04:00:00'))
# ('B0BKGZZP2P', 'Voelkner', 0, Timedelta('5 days 01:00:00'))
# ('B0BKGZZP2P', 'Whooki GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'ZOOM ICI', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'amazon', 23, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'computeruniverse', 27, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'cw-mobile', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'cyberport', 0, Timedelta('4 days 04:00:00'))
# ('B0BKGZZP2P', 'get goods', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'inandout', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'kaijott', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'medialand4you. Händler & Versand aus Deutschland', 2, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'mobilblitz', 0, Timedelta('6 days 06:00:00'))
# ('B0BKGZZP2P', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 35, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'nrsolutions', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'okluge', 17, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'price-guard', 0, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'priz24', 0, Timedelta('6 days 04:00:00'))
# ('B0BKGZZP2P', 'tecedo', 1, Timedelta('6 days 07:00:00'))
# ('B0BKGZZP2P', 'technikbilliger', 0, Timedelta('3 days 01:00:00'))
# ('B0BKGZZP2P', 'vavado', 1, Timedelta('6 days 04:00:00'))
# ('B0BKGZZP2P', 'vollfarbdrucker-de Ihre Office Experten', 0, Timedelta('6 days 05:00:00'))
# ('B0BKQYYMLH', 'STILORD Leder', 28, Timedelta('6 days 08:00:00'))
# ('B0BKXT1X16', 'Boutikazik', 0, Timedelta('6 days 08:00:00'))
# ('B0BKXT1X16', 'Musikhaus-Korn', 0, Timedelta('6 days 08:00:00'))
# ('B0BKXT1X16', 'Zoundhouse - Dresden', 0, Timedelta('6 days 08:00:00'))
# ('B0BKXT1X16', 'amazon', 17, Timedelta('5 days 04:00:00'))
# ('B0BKXT1X16', 'keepdrum', 22, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'Be sCool Gmbh.', 0, Timedelta('6 days 01:00:00'))
# ('B0BL85J1JP', 'Fuer-Haus-und-Hof', 0, Timedelta('6 days 01:00:00'))
# ('B0BL85J1JP', 'Garcia Webshop', 0, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'Ordnung und mehr', 0, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'Schulranzen4Kids', 0, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'Southbag - Schulranzen | Rucksäcke | Koffer', 0, Timedelta('6 days 01:00:00'))
# ('B0BL85J1JP', 'TRENDYKids', 0, Timedelta('6 days 01:00:00'))
# ('B0BL85J1JP', 'Tintenklecksversand', 0, Timedelta('3 days 11:00:00'))
# ('B0BL85J1JP', 'WEIBO Weimar', 4, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'Wegmann 1855', 8, Timedelta('6 days 05:00:00'))
# ('B0BL85J1JP', 'koffer24 de', 0, Timedelta('6 days 01:00:00'))
# ('B0BL85J1JP', 'meinReisekoffer', 12, Timedelta('6 days 08:00:00'))
# ('B0BL85J1JP', 'schulranzenwelt', 0, Timedelta('0 days 00:00:00'))
# ('B0BLC5SFDH', 'BagsOnline', 26, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'DER BREU', 1, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'FOND OF', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC5SFDH', 'HAUSFELDER accessoires + reise', 2, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'Ideen von A - Z', 0, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'K-Line Taschendesign', 0, Timedelta('5 days 03:00:00'))
# ('B0BLC5SFDH', 'Koffer-to-go', 44, Timedelta('2 days 22:00:00'))
# ('B0BLC5SFDH', 'Kofferworld', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC5SFDH', 'Leder Heinz', 25, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'Lieblingstasche', 13, Timedelta('6 days 07:00:00'))
# ('B0BLC5SFDH', 'Marken-Koffer', 1, Timedelta('4 days 19:00:00'))
# ('B0BLC5SFDH', 'Pippi-Lotta-Kinderschuhe', 0, Timedelta('5 days 06:00:00'))
# ('B0BLC5SFDH', 'Ranzenfee & Koffertroll GmbH', 0, Timedelta('6 days 05:00:00'))
# ('B0BLC5SFDH', 'Ranzenlager', 0, Timedelta('0 days 05:00:00'))
# ('B0BLC5SFDH', 'Schreibdesign', 0, Timedelta('6 days 05:00:00'))
# ('B0BLC5SFDH', 'Schuhe24', 1, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'Southbag - Schulranzen | Rucksäcke | Koffer', 0, Timedelta('4 days 20:00:00'))
# ('B0BLC5SFDH', 'TOP TWO GmbH', 0, Timedelta('0 days 05:00:00'))
# ('B0BLC5SFDH', 'Taschenfreund Werl', 0, Timedelta('6 days 05:00:00'))
# ('B0BLC5SFDH', 'Taschenjuwel', 26, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'Toys for Fun GmbH', 5, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'WE LOVE BAGS', 57, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'Zierleyn GmbH & Co. KG', 0, Timedelta('5 days 08:00:00'))
# ('B0BLC5SFDH', 'duo schreib & spiel Markenshop', 0, Timedelta('6 days 06:00:00'))
# ('B0BLC5SFDH', 'flac Shop', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC5SFDH', 'kiddy-hits', 16, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'kieskemper1928', 0, Timedelta('5 days 08:00:00'))
# ('B0BLC5SFDH', 'modeherz "Alle Preise inkl. Mwst."', 1, Timedelta('6 days 08:00:00'))
# ('B0BLC5SFDH', 'schulranzenwelt', 0, Timedelta('0 days 00:00:00'))
# ('B0BLC72XV3', 'BagsOnline', 8, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'City Kauf GmbH', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'DER BREU', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'FOND OF', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'HAUSFELDER accessoires + reise', 2, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'Ideen von A - Z', 0, Timedelta('0 days 22:00:00'))
# ('B0BLC72XV3', 'K-Line Taschendesign', 0, Timedelta('3 days 00:00:00'))
# ('B0BLC72XV3', 'Kofferworld', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'Leder Heinz', 12, Timedelta('3 days 04:00:00'))
# ('B0BLC72XV3', 'Lieblingstasche', 17, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'Marken-Koffer', 0, Timedelta('3 days 13:00:00'))
# ('B0BLC72XV3', 'RUCKSACK', 0, Timedelta('5 days 22:00:00'))
# ('B0BLC72XV3', 'Ranzenfee & Koffertroll GmbH', 0, Timedelta('6 days 00:00:00'))
# ('B0BLC72XV3', 'Ranzenlager', 0, Timedelta('4 days 20:00:00'))
# ('B0BLC72XV3', 'Schreibdesign', 0, Timedelta('5 days 11:00:00'))
# ('B0BLC72XV3', 'Schuhe24', 0, Timedelta('6 days 07:00:00'))
# ('B0BLC72XV3', 'Southbag - Schulranzen | Rucksäcke | Koffer', 0, Timedelta('4 days 00:00:00'))
# ('B0BLC72XV3', 'TOP TWO GmbH', 0, Timedelta('6 days 00:00:00'))
# ('B0BLC72XV3', 'WE LOVE BAGS', 14, Timedelta('1 days 07:00:00'))
# ('B0BLC72XV3', 'Zierleyn GmbH & Co. KG', 0, Timedelta('3 days 13:00:00'))
# ('B0BLC72XV3', 'modeherz "Alle Preise inkl. Mwst."', 0, Timedelta('4 days 23:00:00'))
# ('B0BLC72XV3', 'toboshop', 0, Timedelta('3 days 04:00:00'))
# ('B0BLN6G66C', 'MUSIC STORE Professional', 0, Timedelta('6 days 08:00:00'))
# ('B0BLN6G66C', 'Music and More Store', 15, Timedelta('1 days 16:00:00'))
# ('B0BLN6G66C', 'Musikhaus-Korn', 0, Timedelta('6 days 08:00:00'))
# ('B0BLN6G66C', 'amazon', 10, Timedelta('2 days 05:00:00'))
# ('B0BLN6G66C', 'keepdrum', 22, Timedelta('6 days 08:00:00'))
# ('B0BN5BP683', 'BIBCASA', 27, Timedelta('6 days 07:00:00'))
# ('B0BN5BP683', 'CALENDA', 26, Timedelta('6 days 07:00:00'))
# ('B0BN5BP683', 'WEIZHI-DE', 6, Timedelta('0 days 16:00:00'))
# ('B0BNC8RXH1', 'BERSERK MEDIA', 0, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'BlueBrixx-Shop', 0, Timedelta('5 days 05:00:00'))
# ('B0BNC8RXH1', 'Brickcomplete - Rasche Lieferung!', 0, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'KsiegarniaInternetowa-de :: Spielzeug & Bücher', 14, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'Renax Toys - Schnelle Lieferung', 0, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'Studio Platinum', 0, Timedelta('5 days 05:00:00'))
# ('B0BNC8RXH1', 'Taschengelddieb', 28, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'amazon', 12, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'e-joker', 13, Timedelta('5 days 05:00:00'))
# ('B0BNC8RXH1', 'ms-plueth', 0, Timedelta('6 days 08:00:00'))
# ('B0BNC8RXH1', 'trendmile', 11, Timedelta('3 days 05:00:00'))

# %% [markdown]
# ## Actual Calculation if a seller is algorithmic

# %%
# Convert the result list to a DataFrame
result_df = pd.DataFrame(result, columns=['asin', 'sellerName', 'num_price_changes', 'observation_time'])

# Calculate the observation time in hours
result_df['observation_time'] = result_df['observation_time'].apply(lambda x: x.total_seconds() / 3600)

# Calculate the price changes per hour
result_df['price_changes_per_hour'] = result_df['num_price_changes'] / result_df['observation_time']

# Replace infinite values with NaN
result_df['price_changes_per_hour'] = result_df['price_changes_per_hour'].replace([np.inf, -np.inf], np.nan)

# Calculate the median of non-infinite and non-missing values
median_price_changes = result_df['price_changes_per_hour'].dropna().median()

# Replace missing and infinite values with the median
result_df['price_changes_per_hour'] = result_df['price_changes_per_hour'].fillna(median_price_changes)

# Calculate the mean and standard deviation
mean_price_changes = result_df['price_changes_per_hour'].mean()
std_price_changes = result_df['price_changes_per_hour'].std()

print("Mean price changes per hour:", mean_price_changes)
print("Standard deviation of price changes per hour:", std_price_changes)

# Set a threshold for classifying sellers as algorithmic
# For example, we can set the threshold as mean + 2 * std, which will classify approximately 2.5% of sellers as algorithmic
threshold = mean_price_changes + 1 * std_price_changes
print("Threshold:", threshold)

# Add a column to the result DataFrame indicating whether the seller is algorithmic
result_df['is_algorithmic'] = result_df['price_changes_per_hour'] > threshold

# Sort the algorithmic seller pairs by price changes per hour
algorithmic_seller_pairs = result_df[result_df['is_algorithmic']].sort_values(by='price_changes_per_hour', ascending=False)

# Get the names of algorithmic sellers
algorithmic_seller_names = algorithmic_seller_pairs['sellerName'].unique()

# Filter the result DataFrame to include only non-algorithmic sellers
non_algorithmic_seller_pairs = result_df[~result_df['sellerName'].isin(algorithmic_seller_names)]

# Combine the algorithmic and non-algorithmic seller pairs
final_result = pd.concat([algorithmic_seller_pairs, non_algorithmic_seller_pairs], ignore_index=True)
# Out:
# Mean price changes per hour: 0.057616970936698694
# Standard deviation of price changes per hour: 0.09299302152677888
# Threshold: 0.15060999246347756

# %%
# Filter the DataFrame to include only the algorithmic sellers
algorithmic_sellers = final_result[final_result['is_algorithmic']]

# Get the unique seller names
unique_algorithmic_sellers = algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_algorithmic_sellers = len(unique_algorithmic_sellers)

# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers)
print("Unique algorithmic seller names:")
for seller_name in unique_algorithmic_sellers:
    print(seller_name)
# Out:
# Number of unique algorithmic sellers: 473
# Unique algorithmic seller names:
# ZOXS  GmbH
# lobigo
# Hardware-Best
# Amazon Warehouse
# Solution 4YOU
# Koffer-to-go
# computeruniverse
# Electronic_System
# ACE-Deutschland
# BULUTTECH
# Happy Home Srl
# CALCANEUS
# To B To C
# Bauschmeisser
# MusicScout
# MegaMobile
# Music and More Store
# CW-SHOPPING
# yoused  GmbH
# Topbaer
# BagsOnline
# Kommerzpunkt
# amazon
# Rad & Sportkönig
# REDIALING
# shop-lang
# Online-Versand-Grafenau GmbH
# Toynova
# WE LOVE BAGS
# moebel-und-lifestyle
# ddplus GmbH
# Musikhaus Kirstein GmbH
# Casa Haushalt
# PodiumProdej
# cw-mobile
# Spiele-und-Abenteuer
# Fashion-Home-Trend
# FINEST OF BEAUTY
# Home Automation EU
# Sasaf IT
# BestArtikel GmbH
# Modefreund
# nox divendo
# DIGITLIFE SRLS
# DuronicEU
# Amazon
# baumarktdiscount
# WEIZHI-DE
# Bambini Factory Deals
# SIA Solution
# REITSPORT24
# TechnologyONE Germany
# HOH GmbH IHR FACHGESCHÄFT seit 1894 - Gratis Versand ab 29 € Deutschland
# Arlambo
# Expert AGD
# Pro Lighting e.K.
# Reitsport Iris Schwarz
# e-joker
# myHobby24 | Ihr Freizeitspezialist für Deutschland
# Preiswert&Gut
# BOSSPRODUCTS
# GETIC
# Dragon Kite UG
# YESEATIS
# sl-auktion
# GlobalHair
# jomodo
# Elektro4000de
# AS-Discount
# GetMarket
# All-4-Baby
# nice-price-webshop
# okluge
# TAROMIO
# Tradomi
# NaturSchatulle
# Modellauto18
# price-guard
# Grancei
# 4yourcar
# Wohnkult Deko
# SportFits
# LULUBUY S.A.R.L
# Arcobaleno Centro Musicale
# velora-shop
# SCHREIBER + WEINERT GmbH
# T&T NORTH
# TOPNET
# RICOO-Medientechnik. Preise inkl. MwSt.
# Medpets
# CORTEXPOWER
# LOTT-AUTOTEILE
# LEICKE - Leipzig
# LessPaid ✅
# ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe
# Groß / Einzelhändler Rafal Otto
# Miller Rock
# Dealzonu
# Fexyshop
# aquaristicnet Babenhausen
# Body & Fit Nutrition
# Modo La e.K
# nicePriceIT
# Genialpix
# SIDCO GmbH
# docsmagic
# nierlecom
# GoodSupps
# Musik Produktiv
# Breezy Returns
# BIT-electronix
# extenso24
# Meiguoduizhang
# ricambi auto
# inandout
# Kaleido.Shop GmbH
# Tierzubehör Cordes
# FOTO KOESTER MUENSTER
# Thats Shopping GmbH
# RaiffeisenBAUMARKT24
# Computerhandlung
# Sporting-Gifts
# Felex Lederwaren Gmbh  (inkl. hauseig. Reparaturservice)
# apohealth - Gesundheit aus der Apotheke
# DIGITLIFE SRL
# Sticker-und-co-de
# MIOGA Warenhandel & Service GmbH
# Cstore.
# Bambelaa!
# ivy-electro
# Cartvil
# Neuert's
# GREINER GROSSHANDEL
# Cycletronic
# LUBA GmbH
# TechPoint1111
# KsiegarniaInternetowa-de :: Spielzeug & Bücher
# RHEINSTEIN
# amzbitrage
# uShoppy
# D2C ReCommerce GmbH
# Elcom Online
# Trekking Star
# ZOOM ICI
# weqsavcsdjuyh
# Lederoase
# Bilvary
# Ephesus Juwelier Demirel
# SKYLINE MEDIA
# Bekureta mobile
# Computerxtreme
# Stortle
# -uniqueplace-de-
# RUBART GmbH
# Dittmeier
# shanxifanjiank
# UV-Fashions. Protectstore & JUJA
# gomazing - bis 14:00 Versand am gleichen Tag!
# Inateck
# Culinaris Küchenaccessoires
# Leuchten-Trends
# Amitaly
# ZAR Systems
# Leder Heinz
# Masskas
# TINKERER
# Casa Due pur GmbH
# DIES&DAS
# MMF ENTERPRISE LTD
# X1 Shop
# CHENGCHUANGA
# Looping-Lu
# Teile-Online24
# CSL-Computer
# InstaSpares
# SCHMUCK SOTOGRANDE
# CUETO SCHMUCK (Offizieller händler)
# BRAUN BÜFFEL
# druckdichaus
# Organic Bargains EU
# Heimtierbedarf Online
# ZAIDOO - Hier zählst Du!
# Caffè Musetti
# Teddy Toys Kinderwelt
# Future-X DE
# Kurfurst GmbH
# E-stock Electronics
# nrsolutions
# MYL Milano Prime 🥇
# geniuzcom
# Best of Electronic
# my mosaik
# Batna_24
# Toys for Fun GmbH
# VOS-CONSOMMABLES 🥇🥇
# arstecnica
# Recordcase
# trendmile
# ProComponentes
# Mipuu
# ecanis.shop
# wlan-discount24
# Willer-Schuhe
# KADAX
# ProTrade Home&Office
# wolfonlineshop
# cybernerds
# allesfurprofide
# Oehlbach Kabel GmbH - Hersteller-Shop
# gama-bhp
# big-mike
# MiS Toys - Preise inkl. Mwst. -
# Bedsure EU
# KW-Commerce
# CPU Global Sales
# Lieblingstasche
# avantrado.shop
# Merkkur
# naturzeit - kostbare Momente unter freiem Himmel. Preise inkl. MwSt.
# FUNN-EU
# GOK GROUPE
# TIBERION-SHOP
# Technik-Zirkus
# Rasppishop
# alyou
# fanszone
# GozinFur
# Elektro Sonderposten
# Boulevard Online
# Mezken GmbH DE
# Bilutza Shop
# STILORD Leder
# CheapSell
# Franken-Best-Shop
# ComputerPirates DE
# megaprime
# shop-tiptop
# apominga - Die Online Apotheke in München
# Loupas
# La dolce vita & World of coffee
# RedZilla (Preise inkl. MwSt.) Impressum und AGB finden Sie unter Verkäufer-Hilfe
# Shopping Factory
# Metall Depot
# GG Geschenke-Galerie GmbH
# teleropa
# GreenCellPro
# Dönges
# ATP Autoteile
# QParts24
# fairmarkt24
# Cristallerie Locatelli
# Totaldiscount
# EFI Global Store DE
# Zyxel Networks ®
# Musikbaum "Preise inkl. Mwst."
# JTC Computer Store
# Music-Town
# Graphodruck
# Mediashoponline
# Splendid Time
# BauChemie24
# Trend Sportiv
# Gotec Service
# DOMO EXPERT
# Bärendeals
# JACOB ⭐⭐⭐⭐⭐
# Neuesland Preise inkl. MwSt
# TierXXL
# music world brilon_
# favorio
# SD-Werkzeug
# Löchel_Industriebedarf
# WIMBA
# MARKETTIAMO
# Design Stoodio
# haupteingang1
# Neuhaus Brillen + Hörgeräte
# WSK-Internetservice
# bzoptical
# Ferreira Marques
# hbh24online
# Crystal4ever
# ebg
# Joola Tischtennis GmbH
# Songmics
# Lens2Lens
# Plutosport
# Globsport 24
#
#
# DirectfromStarTech
# LSE Commerce
# KAQITEY
# Smart7 Europe
# Trinity ecom
# Nesatec
# Kinderwelt Weber
# uhrcenter
# DaJa-Computer GbR
# Macway
# suntask
# Teknoraks GmbH
# schulranzenwelt
# BranMic Products
# Taschengelddieb
# Alegree
# spexact
# At-Memory
# BRAVOTEC
# Racketworld
# PROSO
# YOURGAMES
# M&A EU Shop
# RAREWAVES-DE
# TREE SHADOW-EU
# CALENDA
# madfireshop
# Schnellversand DHL / GLS
# kfzteile24
# Autoteile Gocht
# E-SERVIZI
# limuno
# LUcKQuEllA
# Fuchs seit 1895
# H A U P T L A G E R
# Mai Lifestyle
# Wiki-Naturwaren
# Lapi Retail
# BIBCASA
# Go De
# VISO TRADE
# 1-Klick-Versand (Preise inkl. MwSt)
# Blue Flamingo Trade CLG
# cnyolee
# llccenysp
# Ponera
# V-Toolstore
# Spielwaren Eichelkraut
# Electro-Center
# inkcompany
# Red Tech GmbH
# TOPOS
# TT-Shop Ostalb
# ai-Trading24
# SHAYAHA
# Cybertec24
# Smart Distribution Technologies
# Jabiru
# Wacaco
# Pressstart
# HGJDKSJ·de
# D-SPORT
# WirliebenHUNTER
# BEZAUBERND
# Shop Günstig ER GmbH
# KIIP BV
# Haarstand
# City Juwelier
# Outdoor_Paradise
# MARBEL FOX LTD
# Starlabels
# MACSERVICE COMERCIO PRODUTOS INFORMATICOS LDA
# Naqua
# BlumenbeckerIndustriebedarf GmbH
# myGorilla
# Xinyizhining-store
# xinxiamibu
# World Trader's
# CocoLand
# Sciencey
# Babyprofi-Onlineshop
# DAMEDIS
# NNMNN COOFANIN
# FotoBravo
# Kreativity-World
# vbghfeuyrgjf
# ZHIPENG
# tiendainformatica-de
# Poppy Larkin
# Oberland Group GmbH
# VendiloOra
# racket-sports
# Paragon Star
# Taschenjuwel
# Deltatecc GmbH
# koestner-shop-de
# SPORT AND TREND
# Ivomaa
# Nils Traumfabrik
# Happy Electronics Sales
# Amor Group
# TZS First E Commerce
# DOMO SHOP
# idee+spiel Große
# Toms-Spielzeug
# DSBO
# Capodagli 1937 DE
# Tegrace Eur
# W.I.R Handels-GmbH
# ergonomicoffice-de
# WALI K LTD
# Werkstatt-Produkte
# PMI Trading
# Herso Papeterie
# Vus Highlife
# GoPoschte
# Cartridge King Jersey Ltd
# Designhuette Store
# Babypower24
# spassamdrucken
# BeautyHo
# Prezzipazzi-eu
# D-Edition e.K. (Alle Preise inkl. Mwst.)
# Easysell2020
# WanGLOBLE
# uhren4you
# Jewels & Watches Company
# ebr01
# MiniPrice Express SL
# Notebook-Profis
# LuYinShop
# Preiswert24. Preise inkl. MwSt
# BioTextilien-Allgäu
# arbra.store
# keepdrum
# Neu Gadgets
# Li-start
# Graf Bauzentrum GmbH & Co. KG Calwer str. 119. 72202 Nagold
# WerkzeugHERO - Ihr Fachhändler aus Deutschland
# Power & Handel Vertriebs-GmbH
# G.E.Consumables
# Hossi's Wholesale ⭐⭐⭐⭐⭐ 100% positiv
# IMAGEN FOTOCOLOR
# planetextra
# PROTEINARENA
# BrandSport24
# Change for sport
# IM-Trading GmbH " Preis inkl. Mwst."
# ER Online Shop
# CEDIS
# shoppingpoint24
# Das älteste Spielwarengeschäft Deutschlands gegr. 1685
# Spielwaren Schmied GmbH
# getyourseazy
# Koberger GmbH
# EMAKO
# Abenteuer 4x4
# Janado
# Vermegreen
# illezt
# Dahlmann GmbH
# WestCom
# Schuhhaus Schreiber
# 24 x 7 Verkäufer
# Panini Deutschland Marketplace
# schmuckshopping
# Semplidea Srl
# GREEN & STEEL
# Gluecksshop
# DerWellnessshop
# Fa.BEST4FORST-EUROPE
# yuyte
# FS Onlinehandel UG
# Ravensburger Verlag
# PrintFeed Limited
# lanius_trading
# edelsoft
# MERULA TRADE
# WEIBO Weimar
# HiKun
# SpecialRecreationRoom
# DL-accessories
# nasenfahrrad24
# füllermaus-  büchermaus

# %%
# Filter the DataFrame to include only the non-algorithmic sellers
non_algorithmic_sellers = final_result[~final_result['is_algorithmic']]

# Get the unique seller names
unique_non_algorithmic_sellers = non_algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_non_algorithmic_sellers = len(unique_non_algorithmic_sellers)
# Print the result
print("Number of unique non algorithmic sellers:", num_non_algorithmic_sellers)
# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers,"of a total of ",distinct_values_verkäufer)
# Out:
# Number of unique non algorithmic sellers: 1587
# Number of unique algorithmic sellers: 473 of a total of  2060

# %% [markdown]
# # Calucalte Algorithmic Sellers by Total Price Changes over All Products

# %%
import pandas as pd

# Assuming your DataFrame is called df

# Convert the 'time' column to a 'datetime' type
df['time'] = pd.to_datetime(df['time'])

# First, sort the DataFrame by 'asin', 'sellerName', and 'time'
df = df.sort_values(by=['asin', 'sellerName', 'time'])

# Reset the index after sorting
df.reset_index(drop=True, inplace=True)

# Compute the price changes by checking if the price in the current row is different from the previous row, and if the sellerName is the same as in the previous row
df['price_change'] = (df['price'] != df['price'].shift(1)) & (df['sellerName'] == df['sellerName'].shift(1)) & (df['asin'] == df['asin'].shift(1))

# Now, group by 'sellerName' and sum the 'price_change' column to get the number of price changes
seller_price_changes = df.groupby('sellerName')['price_change'].sum().reset_index()

# Calculate the number of different products for each seller
unique_products = df.groupby('sellerName')['asin'].nunique().reset_index()

# Merge the seller_price_changes and unique_products DataFrames
seller_summary = pd.merge(seller_price_changes, unique_products, on='sellerName')

# Sort the results by the number of price changes in descending order
seller_summary = seller_summary.sort_values(by='price_change', ascending=False)

# Convert the result to a list of tuples
result_by_seller = [(row.sellerName, row.price_change, row.asin) for row in seller_summary.itertuples(index=False)]

# Print the result
for x in result_by_seller:
    print(x)
# Out:
# ('Amazon Warehouse ', 44475, 387)
# ('amazon', 16607, 636)
# ('Happy Home Srl', 11203, 132)
# ('computeruniverse', 5423, 121)
# ('DaJa-Computer GbR', 3216, 145)
# ('GREINER GROSSHANDEL', 2919, 36)
# ('okluge', 2707, 73)
# ('Solution 4YOU', 2697, 55)
# ('MusicScout', 2465, 34)
# ('AS-Discount', 2366, 138)
# ('e-joker', 1921, 119)
# ('Casa Haushalt', 1778, 40)
# ('Stortle', 1681, 75)
# ('TechPoint1111', 1600, 33)
# ('Musikhaus Kirstein GmbH', 1592, 31)
# ('To B To C', 1471, 14)
# ('CW-SHOPPING', 1449, 42)
# ('Expert AGD', 1254, 44)
# ('ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe', 1218, 44)
# ('nierlecom', 1214, 36)
# ('SIA Solution', 1189, 33)
# ('GETIC', 1159, 7)
# ('myHobby24 | Ihr Freizeitspezialist für Deutschland', 1115, 62)
# ('nrsolutions', 1100, 76)
# ('cw-mobile', 1028, 66)
# ('inandout', 975, 72)
# ('ProComponentes', 947, 51)
# ('GetMarket', 946, 48)
# ('Computerhandlung', 895, 47)
# ('Fexyshop', 800, 27)
# ('Computerxtreme', 792, 38)
# ('Spiele-und-Abenteuer', 790, 31)
# ('nox divendo', 773, 25)
# ('LULUBUY S.A.R.L', 738, 44)
# ('Masskas', 732, 31)
# ('Happy Home Italia', 720, 99)
# ('Smart Distribution Technologies', 709, 37)
# ('MIOGA Warenhandel & Service GmbH', 707, 105)
# ('LessPaid ✅', 680, 36)
# ('Power & Handel Vertriebs-GmbH', 623, 26)
# ('Amitaly', 607, 11)
# ('tiendainformatica-de', 605, 31)
# ('BIBCASA', 604, 4)
# ('Kommerzpunkt', 599, 29)
# ('geniuzcom', 571, 36)
# ('Elektronik-Versand', 562, 30)
# ('Toys for Fun GmbH', 539, 20)
# ('Home Automation EU', 531, 2)
# ('Breezy Returns', 524, 22)
# ('Amazon', 512, 32)
# ('X1 Shop', 509, 6)
# ('Future-X DE', 467, 21)
# ('Elektro Sonderposten', 467, 22)
# ('Best of Electronic', 447, 20)
# ('Batna_24', 447, 17)
# ('ZOOM ICI', 436, 82)
# ('Bittner Warenhandel - Preise inkl. Mwst.', 434, 2)
# ('sporttrend24', 430, 3)
# ('TM Safety Zone', 430, 2)
# ('Bambelaa!', 430, 2)
# ('DuronicEU', 428, 1)
# ('HOH GmbH IHR FACHGESCHÄFT seit 1894 - Gratis Versand ab 29 € Deutschland', 427, 9)
# ("Hossi's Wholesale ⭐⭐⭐⭐⭐ 100% positiv", 427, 2)
# ('Lederoase', 421, 9)
# ('BlumenbeckerIndustriebedarf GmbH', 421, 9)
# ('arstecnica', 417, 16)
# ('Electronic_System', 411, 8)
# ('RICOO-Medientechnik. Preise inkl. MwSt.', 410, 1)
# ('PEARL Versandhaus', 402, 2)
# ('Cstore.', 396, 33)
# ('Elektro4000de', 392, 15)
# ('JACOB ⭐⭐⭐⭐⭐', 392, 36)
# ('price-guard', 389, 139)
# ('Toynova', 386, 12)
# ('MegaMobile', 385, 26)
# ('trendmile', 382, 23)
# ('BestArtikel GmbH', 377, 2)
# ('FOTO KOESTER MUENSTER', 374, 14)
# ('WE LOVE BAGS', 362, 19)
# ('Kaleido.Shop GmbH', 362, 17)
# ('uShoppy', 356, 2)
# ('STILE IMMAGINE DIGITAL HD', 356, 3)
# ('Sagenta GmbH', 353, 2)
# ('Music and More Store', 335, 13)
# ('JTC Computer Store', 331, 21)
# ('Bauschmeisser', 325, 1)
# ('Klarstein Deutschland', 320, 2)
# ('LEICKE - Leipzig', 320, 1)
# ('TIBERION-SHOP', 320, 3)
# ('edelsoft', 310, 5)
# ('Musik Produktiv', 302, 13)
# ('Das älteste Spielwarengeschäft Deutschlands gegr. 1685', 298, 17)
# ('Ralf Hummel GmbH & Co. KG', 296, 2)
# ('ACE-Deutschland', 292, 2)
# ('hbh24online', 287, 16)
# ("Neuert's", 287, 7)
# ('YOURGAMES', 281, 17)
# ('Fashion-Home-Trend', 268, 4)
# ('Teknoraks GmbH', 261, 3)
# ('SKYLINE MEDIA', 258, 5)
# ('mobilblitz', 258, 54)
# ('La dolce vita & World of coffee', 257, 3)
# ('FUNN-EU', 252, 1)
# ('Modellauto18', 252, 17)
# ('Tradomi', 251, 12)
# ('Felex Lederwaren Gmbh  (inkl. hauseig. Reparaturservice)', 249, 2)
# ('Design Stoodio', 247, 3)
# ('MiS Toys - Preise inkl. Mwst. -', 245, 14)
# ('music world brilon_', 244, 10)
# ('Reiterladen24', 242, 4)
# ('Sotel (AGB und Garantiebestimmungen siehe hier)', 241, 133)
# ('nasenfahrrad24', 241, 2)
# ('DIGITLIFE SRLS', 235, 1)
# ('RaiffeisenBAUMARKT24', 231, 1)
# ('CheapSell', 226, 48)
# ('Arcobaleno Centro Musicale', 224, 9)
# ('Kurfurst GmbH', 224, 17)
# ('Sciencey', 217, 1)
# ('DIES&DAS', 217, 1)
# ('StonKraft EU', 217, 1)
# ('Körperwelt24', 215, 1)
# ('Marken-Kaufhaus Preise inkl. MwSt.', 215, 2)
# ('Baby-max', 215, 1)
# ('FA.MA', 215, 1)
# ('DoremiStore', 215, 3)
# ('ixeo', 215, 1)
# ('Selva Technik GmbH', 215, 1)
# ('KAQITEY', 215, 1)
# ('Akasya Handels GmbH', 215, 1)
# ('Culinaris Küchenaccessoires', 215, 7)
# ('RENPHO LIMITED', 212, 1)
# ('RAREWAVES-DE', 212, 16)
# ('Friseurbedarf-Peters', 211, 2)
# ('MERULA TRADE', 209, 1)
# ('Service_Windhorn', 209, 2)
# ('füllermaus-  büchermaus', 208, 4)
# ('Zoebikes', 208, 1)
# ('Ferreira Marques', 207, 1)
# ('TierXXL', 207, 3)
# ('Rad & Sportkönig', 206, 1)
# ('Modefreund', 206, 5)
# ('TINKERER', 206, 8)
# ('GoodMiller', 205, 1)
# ('HKShop24', 205, 2)
# ('Deltatecc GmbH', 204, 63)
# ('keepdrum', 203, 9)
# ('velora-shop', 202, 5)
# ('vollfarbdrucker-de Ihre Office Experten', 201, 60)
# ('RHEINSTEIN', 200, 5)
# ('Whooki GmbH', 200, 44)
# ('Electropolis_Online', 198, 16)
# ('4yourcar', 198, 4)
# ('kustom-kult', 197, 3)
# ('Shopping Factory', 195, 7)
# ('STILORD Leder', 195, 6)
# ('PCSPEZIALIST-BONN (AGB/Widerruf)', 194, 10)
# ('apominga - Die Online Apotheke in München', 194, 1)
# ('FS Onlinehandel UG', 193, 16)
# ('Genialpix', 192, 5)
# ('MACSERVICE COMERCIO PRODUTOS INFORMATICOS LDA', 189, 12)
# ('LOTT-AUTOTEILE', 189, 6)
# ('Bilvary', 186, 8)
# ('FINEST OF BEAUTY', 186, 2)
# ('WEIBO Weimar', 186, 2)
# ('Pro Lighting e.K.', 185, 4)
# ('Löchel_Industriebedarf', 184, 6)
# ('UEBilliger', 178, 62)
# ('Lieblingstasche', 176, 6)
# ('CSL-Computer', 174, 5)
# ('Boulevard Online', 174, 6)
# ('WanGLOBLE', 174, 1)
# ('ATP Autoteile', 173, 9)
# ('Blue Flamingo Trade CLG', 172, 2)
# ('Biffidì', 171, 7)
# ('tecmedia', 170, 1)
# ('Miller Rock', 169, 5)
# ('REITSPORT24', 168, 3)
# ('Arlambo', 160, 4)
# ('Technik-Trends', 154, 2)
# ('SCHREIBER + WEINERT GmbH', 150, 3)
# ('moebel-und-lifestyle', 149, 2)
# ('EFI Global Store DE', 148, 12)
# ('E-stock Electronics', 147, 12)
# ('Graphodruck', 147, 8)
# ('Schwanthaler Computer', 145, 51)
# ('Olano GmbH', 143, 70)
# ('ZAR Systems', 142, 11)
# ('wlan-discount24', 141, 4)
# ('Vermegreen', 140, 22)
# ('jugf', 140, 1)
# ('SVH Handels-GmbH', 139, 11)
# ('jomodo', 137, 3)
# ('Rasppishop', 137, 7)
# ('Koberger GmbH', 135, 7)
# ('Montearenas', 134, 3)
# ('Dönges', 133, 5)
# ('kfzteile24', 132, 5)
# ('FotoBravo', 132, 5)
# ('Alegree', 131, 5)
# ('kiddy-hits', 131, 17)
# ('Sasaf IT', 130, 2)
# ('1Deins Computer GmbH', 129, 77)
# ('Bambini Factory Deals', 129, 5)
# ('technikbilliger', 127, 60)
# ('Mai Lifestyle', 127, 5)
# ('shop-lang', 126, 6)
# ('Voelkner', 126, 58)
# ('officeservicesrl', 126, 17)
# ('MiniPrice Express SL', 126, 21)
# ('SD-Werkzeug', 125, 4)
# ('Metall Depot', 125, 5)
# ('TZS First E Commerce', 125, 4)
# ('InstaSpares', 125, 4)
# ('SNOGARD Computer GmbH', 124, 44)
# ('Nils Traumfabrik', 124, 5)
# ('VISO TRADE', 122, 11)
# ('ddplus GmbH', 122, 4)
# ('Koffer-to-go', 122, 8)
# ('IMAGEN FOTOCOLOR', 122, 5)
# ('City Juwelier', 122, 5)
# ('TOPOS', 121, 5)
# ('Brand Chain GmbH', 120, 1)
# ('Thats Shopping GmbH', 120, 3)
# ('druckdichaus', 119, 5)
# ('Music-Town', 119, 4)
# ('Electro-Center', 117, 4)
# ('Lapi Retail', 117, 4)
# ('nice-price-webshop', 115, 2)
# ('apohealth - Gesundheit aus der Apotheke', 115, 2)
# ('aquaristicnet Babenhausen', 114, 4)
# ('fanszone', 113, 4)
# ('Trekking Star', 113, 4)
# ('schulranzenwelt', 112, 12)
# ('alyou', 112, 4)
# ('GozinFur', 112, 4)
# ('Ponera', 111, 5)
# ('inkcompany', 111, 5)
# ('BREAKITDOWN', 111, 9)
# ('baumarktdiscount', 109, 2)
# ('bzoptical', 109, 4)
# ('Fitness2002', 108, 2)
# ('Red Tech GmbH', 108, 3)
# ('spassamdrucken', 107, 5)
# ('Store-Jet Elektrohandel', 107, 4)
# ('CALENDA', 107, 4)
# ('GlobalHair', 106, 2)
# ('egenta', 105, 33)
# ('Musikbaum "Preise inkl. Mwst."', 105, 4)
# ('Cartridge King Jersey Ltd', 104, 4)
# ('All-4-Baby', 104, 2)
# ('spexact', 103, 4)
# ('Spielwaren Schmied GmbH', 103, 7)
# ('Starlabels', 103, 4)
# ('Foto Erhardt GmbH', 102, 13)
# ('my mosaik', 102, 4)
# ('Teddy Toys Kinderwelt', 101, 3)
# ('GoodSupps', 100, 3)
# ('LCD & Plasma Service GmbH', 99, 9)
# ('SPIELZEUGRIESE', 99, 7)
# ('racket-sports', 99, 4)
# ('D-Edition e.K. (Alle Preise inkl. Mwst.)', 98, 8)
# ('priz24', 98, 99)
# ('BIT-electronix', 97, 4)
# ('ai-Trading24', 97, 10)
# ('game-and-fun GmbH', 96, 1)
# ('CORTEXPOWER', 96, 2)
# ('Acacia One London', 96, 1)
# ('Dittmeier', 95, 5)
# ('Reitsport Iris Schwarz', 95, 2)
# ('QParts24', 95, 3)
# ('Tintenwunsch', 94, 5)
# ('Monster-Bid', 93, 4)
# ('DASTRO ® --- Einfach. Genial. Günstig.', 93, 83)
# ('SIDCO GmbH', 92, 2)
# ('diktiergeraetundzubehoer', 92, 3)
# ('Leder Heinz', 91, 5)
# ('Neuesland Preise inkl. MwSt', 91, 3)
# ('Heimtierbedarf Online', 91, 3)
# ('Songmics', 90, 3)
# ('Paragon Star', 90, 4)
# ('RedZilla (Preise inkl. MwSt.) Impressum und AGB finden Sie unter Verkäufer-Hilfe', 90, 3)
# ('KsiegarniaInternetowa-de :: Spielzeug & Bücher', 89, 12)
# ('D2C ReCommerce GmbH', 89, 4)
# ('Nicotel-DE - Internet & Festnetz', 88, 9)
# ('Mickslädchen " Preis inkl. MwSt. "', 88, 5)
# ('Vus Highlife', 88, 3)
# ('Kraina Zabawy', 88, 12)
# ('Tierzubehör Cordes', 88, 2)
# ('Papiertiger-Berlin', 87, 4)
# ('Plutosport', 87, 3)
# ('GG Geschenke-Galerie GmbH', 87, 3)
# ('Musik Center', 87, 29)
# ('Pressstart', 86, 12)
# ('Easysell2020', 85, 3)
# ('Online-Versand-Grafenau GmbH', 84, 1)
# ('GALADOR', 84, 13)
# ('Wohnkult Deko', 84, 3)
# ('LUBA GmbH', 84, 2)
# ('Warenhaus Ebeling', 84, 12)
# ('Leuchten-Trends', 83, 2)
# ('tecedo', 83, 41)
# ('Taschengelddieb', 82, 10)
# ('ELECTRONIS', 82, 61)
# ('WestCom', 81, 4)
# ('toystoystoys', 81, 8)
# ('ecanis.shop', 80, 2)
# ('Bilutza Shop', 80, 3)
# ('nicePriceIT', 79, 3)
# ('shop-tiptop', 79, 4)
# ('PodiumProdej', 79, 1)
# ('Technik-Zirkus', 79, 4)
# ('Cycletronic', 79, 6)
# ('CoKa-MaLa', 78, 3)
# ('Babypower24', 78, 6)
# ('koestner-shop-de', 78, 4)
# ('Peyrouse Hair Shop', 78, 3)
# ('Preiswert24. Preise inkl. MwSt', 78, 3)
# ('avantrado.shop', 77, 2)
# ('BagsOnline', 74, 5)
# ('Macway', 74, 3)
# ('BOSSPRODUCTS', 74, 2)
# ('get goods', 74, 72)
# ('MARKETTIAMO', 72, 8)
# ('GoPoschte', 72, 3)
# ('ZOXS  GmbH', 72, 8)
# ('WALI K LTD', 72, 4)
# ('Duckdik', 71, 1)
# ('GREEN & STEEL', 71, 3)
# ('IT-Daheim', 70, 1)
# ('BioTextilien-Allgäu', 70, 3)
# ('GreenCellPro', 70, 1)
# ('Fast Game', 69, 2)
# ('SCHMUCK SOTOGRANDE', 69, 2)
# ('Traumpreisfabrik', 69, 104)
# ('cybernerds', 69, 2)
# ('ComputerPirates DE', 69, 8)
# ('Mipuu', 69, 5)
# ('Designhuette Store', 68, 2)
# ('OnlyStoresk', 68, 13)
# ('Amazon UK', 68, 28)
# ('Preiswert&Gut', 68, 1)
# ('shoppingpoint24', 67, 3)
# ('SELECT ELITE', 67, 3)
# ('REDIALING', 67, 3)
# ('Trend Sportiv', 67, 2)
# ('uhrcenter', 66, 2)
# ('ZAIDOO - Hier zählst Du!', 66, 2)
# ('SportFits', 65, 2)
# ('Inateck', 65, 2)
# ('Mezken GmbH DE', 64, 2)
# ('big-mike', 64, 2)
# ('DIGITLIFE SRL', 64, 1)
# ('luckyshopping', 63, 2)
# ('Haarstand', 63, 2)
# ('Modo La e.K', 63, 2)
# ('HomeHome by A', 63, 1)
# ('Ephesus Juwelier Demirel', 63, 2)
# ('Powerline24 (ehemals DLAN-500)', 63, 1)
# ('rarebrix', 62, 5)
# ('ProTrade Home&Office', 62, 2)
# ('Hardware-Best', 62, 7)
# ('ElectroSmartEU', 62, 2)
# ('haupteingang1', 62, 2)
# ('KADAX', 62, 2)
# ('allesfurprofide', 62, 2)
# ('gama-bhp', 62, 2)
# ('Sporting-Gifts', 62, 3)
# ('NETZON', 61, 4)
# ('24 x 7 Verkäufer', 61, 3)
# ('Totaldiscount', 61, 2)
# ('Telefon Profi', 60, 3)
# ('Vipdomo', 60, 3)
# ('fairmarkt24', 60, 2)
# ('Nesatec', 60, 2)
# ('Lens2Lens', 60, 7)
# ('docsmagic', 60, 1)
# ('yoused  GmbH', 60, 7)
# ('wolfonlineshop', 59, 2)
# ('Schnellversand DHL / GLS', 59, 3)
# ('Wacaco', 58, 2)
# ('Outdoor_Paradise', 58, 2)
# ('GOK GROUPE', 58, 2)
# ('Babyprofi-Onlineshop', 58, 2)
# ('BULUTTECH', 58, 1)
# ('DSBO', 58, 3)
# ('Amor Group', 58, 3)
# ('XXL-Phones', 57, 5)
# ('TESLA STATION UK', 57, 2)
# ('Schuhbidu24', 57, 3)
# ('Rhino-Technical', 57, 1)
# ('T&T NORTH', 57, 1)
# ('Werkstatt-Produkte', 56, 2)
# ('AGEM CZ', 55, 22)
# ('Dragon Kite UG', 55, 1)
# ('Go De', 55, 2)
# ('IM-Trading GmbH " Preis inkl. Mwst."', 55, 3)
# ('DAMEDIS', 55, 2)
# ('Jewels & Watches Company', 54, 2)
# ('CALCANEUS', 54, 1)
# ('group24 AG', 54, 2)
# ('DirectfromStarTech', 54, 2)
# ('PrintFeed Limited', 54, 2)
# ('baumgarten-büromarkt', 54, 5)
# ('Kreativity-World', 54, 2)
# ('ARDEBO', 54, 19)
# ('uhren4you', 53, 2)
# ('PC Hardware Store', 53, 2)
# ('DOMO SHOP', 53, 2)
# ('BRAVOTEC', 53, 4)
# ('favorio', 53, 4)
# ('ivy-electro', 53, 1)
# ('Body & Fit Nutrition', 52, 1)
# ('Papillote Haarshop GmbH', 52, 2)
# ('gomazing - bis 14:00 Versand am gleichen Tag!', 52, 1)
# ('schmuckshopping', 51, 2)
# ('SENETIC EU', 49, 12)
# ('Herso Papeterie', 48, 2)
# ('\n                 ', 48, 2)
# ('vavado', 48, 29)
# ('Poppy Larkin', 48, 2)
# ('Cartvil', 48, 1)
# ('ilando24-Shop', 48, 6)
# ('weqsavcsdjuyh', 48, 1)
# ('SpecialRecreationRoom', 47, 1)
# ('Mediashoponline', 47, 2)
# ('llccenysp', 47, 1)
# ('United Brands Online GmbH', 47, 2)
# ('Fashionstaritaly', 46, 2)
# ('GlobalNetOnline', 46, 2)
# ('ESUS IT', 46, 10)
# ('amzbitrage', 46, 3)
# ('TAROMIO', 46, 3)
# ('Bergzeit', 46, 2)
# ('extremebit', 46, 5)
# ('UV-Fashions. Protectstore & JUJA', 45, 1)
# ('Team-Foto Etting', 45, 1)
# ('TEKRA', 44, 20)
# ('Stock Bureau Home Office Wellness', 44, 7)
# ('Shake&Shop', 44, 2)
# ('Odiporo de', 44, 1)
# ('Cybertec24', 43, 2)
# ('DerWellnessshop', 43, 2)
# ('twoGe', 43, 1)
# ('Heldenwerk® Einkaufswelt', 43, 1)
# ('E-SERVIZI', 42, 3)
# ('Willer-Schuhe', 42, 2)
# ('PROSO', 42, 2)
# ('AffariShop', 42, 3)
# ('Looping-Lu', 41, 1)
# ('Univers Club', 41, 1)
# ('Juwelier Allecro GmbH', 40, 1)
# ('ibonero', 40, 2)
# ('CHENGCHUANGA', 40, 1)
# ('Schuhe24', 40, 27)
# ('belli-shop', 40, 4)
# ('get-next', 39, 2)
# ('RUBART GmbH', 39, 2)
# ('JAMBO SUPPLIES', 39, 1)
# ('cyberport', 39, 55)
# ('Teile-Online24', 39, 1)
# ('Gege24', 39, 2)
# ('CUETO SCHMUCK (Offizieller händler)', 39, 1)
# ('get online GmbH', 38, 5)
# ('Crystal4ever', 38, 1)
# ('BRAUN BÜFFEL', 38, 1)
# ('Lederwaren Littmann', 38, 6)
# ('KLS-DISTRIBUTION', 37, 3)
# ('kaijott', 37, 47)
# ('YESEATIS', 37, 6)
# ('Bedsure EU', 37, 1)
# ('GEST POINT GSM S.L', 37, 1)
# ('Wohn-Idee24', 37, 9)
# ('Caffè Musetti', 37, 1)
# ('SCHARF metall design GmbH', 37, 1)
# ('Millennium Star', 37, 37)
# ('naturzeit - kostbare Momente unter freiem Himmel. Preise inkl. MwSt.', 36, 1)
# ('WERKZEUGPROFI', 36, 7)
# ('KW-Commerce', 36, 1)
# ('Spielwaren Eichelkraut', 36, 8)
# ('Zyxel Networks ®', 36, 1)
# ('AL Telekommunikation', 36, 1)
# ('Oehlbach Kabel GmbH - Hersteller-Shop', 36, 1)
# ('Recordcase', 36, 1)
# ('meinReisekoffer', 36, 3)
# ('1-Klick-Versand (Preise inkl. MwSt)', 36, 1)
# ('Joola Tischtennis GmbH', 36, 1)
# ('E-Mistero', 36, 18)
# ('--HVS--', 36, 1)
# ('AS Sell', 36, 2)
# ('Gretamarlene', 36, 1)
# ('ricambi auto', 35, 2)
# ('AMGV', 35, 3)
# ('TechLead DE', 35, 6)
# ('Merkkur', 35, 1)
# ('x-kom', 35, 37)
# ('KITSTORE', 35, 10)
# ('limuno', 35, 2)
# ('teleropa', 35, 1)
# ('Loupas', 34, 1)
# ('Schuhhaus Schreiber', 34, 2)
# ('SportMarken24', 34, 4)
# ('HAI-END GmbH', 34, 1)
# ('Inkadoo Shop', 34, 1)
# ('ALTAUDIA', 34, 1)
# ('CRTREND', 34, 1)
# ('idee+spiel Große', 34, 4)
# ('Jabiru', 34, 3)
# ('megaprime', 33, 1)
# ('ubbc', 33, 1)
# ('Kinderwelt Weber', 33, 1)
# ('3-2-1-schnaps-deer', 33, 4)
# ('Grancei', 33, 1)
# ('rankauf', 33, 1)
# ('LSE Commerce', 33, 1)
# ('VersandLager', 33, 1)
# ('WSK-Internetservice', 33, 1)
# ('Taschenjuwel', 33, 3)
# ('D-SPORT', 33, 1)
# ('Trinity ecom', 33, 1)
# ('Cristallerie Locatelli', 33, 1)
# ('Smart7 Europe', 33, 1)
# ('BauChemie24', 33, 1)
# ('ebg', 33, 1)
# ('myGorilla', 32, 1)
# ('KIIP BV', 32, 1)
# ('Neuburger', 32, 1)
# ('Bärendeals', 32, 1)
# ('Shop Günstig ER GmbH', 32, 1)
# ('CABLEMATIC', 32, 2)
# ('KLH Handelsgesellschaft mbH', 32, 14)
# ('Wiki-Naturwaren', 32, 1)
# ('Capodagli 1937 DE', 32, 1)
# ('ebr01', 32, 1)
# ('VendiloOra', 32, 1)
# ('BeautyHo', 32, 1)
# ('GRAVIS - Computervertriebsgesellschaft mbH', 32, 14)
# ('prindo', 31, 1)
# ('V-Toolstore', 31, 1)
# ('Schuhhaus Theobald KG', 31, 1)
# ('Tigicams', 31, 2)
# ('Change for sport', 31, 1)
# ('suntask', 31, 1)
# ('TOPNET', 31, 5)
# ('MROAUTO Autoparts', 31, 4)
# ('fabian0w', 31, 1)
# ('Schmuck & Uhrenhaus Kunze', 31, 1)
# ('G.E.Consumables', 31, 1)
# ('H A U P T L A G E R', 31, 1)
# ('BrandSport24', 31, 1)
# ('At-Memory', 31, 1)
# ('BranMic Products', 31, 1)
# ('LUcKQuEllA', 31, 1)
# ('Prezzipazzi-eu', 31, 1)
# ('Piggyriches Kft.', 31, 1)
# ('Neu Gadgets', 31, 1)
# ('HGJDKSJ·de', 30, 1)
# ('vbghfeuyrgjf', 30, 1)
# ('NNMNN COOFANIN', 30, 1)
# ('Neuhaus Brillen + Hörgeräte', 30, 1)
# ('yuyte', 30, 1)
# ('MARBEL FOX LTD', 30, 1)
# ('TT-Shop Ostalb', 30, 1)
# ('Tegrace Eur', 30, 1)
# ('prsWORLD', 30, 1)
# ('Toms-Spielzeug', 30, 3)
# ('IT Warehouse EU', 30, 11)
# ('medialand4you. Händler & Versand aus Deutschland', 30, 54)
# ('We Will Shop You', 30, 1)
# ('WirliebenHUNTER', 30, 1)
# ('WoW Markt!', 30, 4)
# ('getyourseazy', 30, 1)
# ("World Trader's", 30, 2)
# ('Yeppon', 30, 59)
# ('ZHIPENG', 30, 1)
# ('friscojeans', 30, 1)
# ('Graf Bauzentrum GmbH & Co. KG Calwer str. 119. 72202 Nagold', 30, 1)
# ('Oberland Group GmbH', 30, 1)
# ('Gotec Service', 30, 3)
# ('Autoteile Gocht', 30, 2)
# ('DOMO EXPERT', 30, 1)
# ('Fuchs seit 1895', 30, 1)
# ('Globsport 24', 30, 1)
# ('Gluecksshop', 30, 1)
# ('Colosseum-Nutrition', 30, 1)
# ('Fa.BEST4FORST-EUROPE', 29, 1)
# ('Black Dragon Distribution', 29, 1)
# ('PROTEINARENA', 29, 1)
# ('ER Online Shop', 29, 2)
# ('Bag-Center GbR', 29, 15)
# ('livingston', 29, 2)
# ('madfireshop', 29, 1)
# ('W.I.R Handels-GmbH', 29, 1)
# ('EXXATRON', 29, 1)
# ('averdo24', 29, 1)
# ('Happy Electronics Sales', 29, 1)
# ('Naqua', 29, 1)
# ('iks-direct', 29, 2)
# ('cnyolee', 29, 1)
# ('CocoLand', 29, 1)
# ('Groß / Einzelhändler Rafal Otto', 29, 1)
# ('Coffee Lyrics', 29, 1)
# ('CoolSound-Superstore', 29, 6)
# ('JMT-Direct Store', 28, 1)
# ('himmelweit Preise inkl. Mwst', 28, 1)
# ('M&A EU Shop', 28, 1)
# ('EUROUPE FAVORİS', 28, 2)
# ('EMAKO', 28, 1)
# ('woS', 28, 1)
# ('adero Design', 28, 1)
# ('Dahlmann GmbH', 28, 1)
# ('WerkzeugHERO - Ihr Fachhändler aus Deutschland', 28, 2)
# ('yupiPL', 28, 1)
# ('Fanceio', 28, 1)
# ('TuttoTondo Shop', 28, 1)
# ('IGLM STORE DE', 28, 5)
# ('Xinyizhining-store', 28, 1)
# ('PMI Trading', 28, 1)
# ('Taschenklub', 28, 1)
# ('xinxiamibu', 28, 1)
# ('alles-meine GmbH', 28, 1)
# ('Redcar Service', 28, 1)
# ('A-RCS GmbH', 28, 8)
# ('CEDIS', 28, 2)
# ('planetextra', 28, 1)
# ('Mister Linse', 28, 5)
# ('Abenteuer 4x4', 28, 1)
# ('TREE SHADOW-EU', 28, 1)
# ('TechInn', 27, 40)
# ('BEZAUBERND', 27, 1)
# ('setpoint', 27, 1)
# ('CPU Global Sales', 27, 3)
# ('dietz-internethandel', 27, 1)
# ('LUQIANGWANGLUO', 27, 1)
# ('HiKun', 27, 1)
# ('Li-start', 27, 1)
# ('Notebook-Profis', 27, 1)
# ('yingzhiyi', 27, 2)
# ('ShenStar', 27, 1)
# ('Asge', 26, 1)
# ('Tieroase', 26, 2)
# ('Martilla store', 26, 1)
# ('Ravensburger Verlag', 26, 1)
# ('JUND', 26, 1)
# ('HOMECARE CUTO', 26, 1)
# ('M&E Online GmbH', 26, 1)
# ('DIYUCAR', 26, 1)
# ('Instyle Juweliere', 26, 1)
# ('BoraComputer', 26, 39)
# ('Enjoy Home Shop', 26, 1)
# ('lenaslesestoff', 26, 1)
# ('Nutracom', 26, 2)
# ('Firma Nienaber', 26, 2)
# ('123 KTK Handel. Preise inkl. MwSt.', 26, 1)
# ('arbra.store', 26, 1)
# ('ergonomicoffice-de', 26, 1)
# ('HeBa - Sound & Music', 26, 16)
# ('Digitdream', 25, 2)
# ('RS-Versand', 25, 3)
# ('formbench GmbH', 25, 1)
# ('Spielzeugwelten (alle Preise inkl. gesetzlicher MwSt. und zzgl.Versandkosten - Impressum & Widerrufsbelehrung in der Verkäuferinfo)', 25, 7)
# ('apotheke4you - vitaplusgesundheit', 25, 1)
# ('WMF Direkt', 25, 4)
# ('Nine Ju', 25, 1)
# ('HypoStore', 25, 2)
# ('Arbeitswelt24', 25, 1)
# ('Markenschuhe-de', 25, 1)
# ('H.Plus+', 25, 1)
# ('PC-KING', 25, 48)
# ('Bright-Yu', 25, 1)
# ('PAFEN', 25, 1)
# ('Liekumm', 25, 1)
# ('Semplidea Srl', 25, 1)
# ('OUTFITTERS . io GmbH - Dein Outdoor Spezialist', 25, 1)
# ('Terra Master', 25, 1)
# ('CBär', 25, 1)
# ('Retoura', 24, 4)
# ('Kjells', 24, 1)
# ('UvV-Shop (ES-Team Consult GmbH)', 24, 1)
# ('DL-accessories', 24, 1)
# ('Smoki Räuchertechnik', 24, 1)
# ('Westinghouse Homeware', 24, 1)
# ('RoyalRapture', 24, 1)
# ('TheInkPeople', 24, 2)
# ('dlSPORTs  EU', 24, 1)
# ('Monster Group', 24, 1)
# ('rotex-italia', 24, 1)
# ('EuroAsia Trade', 24, 1)
# ('langeu', 24, 1)
# ('MK TRADE SIA', 24, 32)
# ('All4living', 24, 1)
# ('zeitlounge', 24, 1)
# ('PFU (EMEA) LIMITED', 24, 1)
# ('opensupplies', 24, 1)
# ('lanius_trading', 24, 3)
# ('44BoardShop', 24, 1)
# ('ETA Hausgeräte', 24, 1)
# ('ÖKO Planet GmbH', 24, 1)
# ('Panini Deutschland Marketplace', 24, 1)
# ('AMBIT LINE LTD', 24, 1)
# ('toys-more24', 24, 2)
# ('Morelenet', 24, 10)
# ('Powerplatform', 24, 1)
# ('Masala Wala', 24, 1)
# ('Electronic Shop Luxemburg', 24, 4)
# ('BEAUT-DE', 24, 1)
# ('Stay Safe DE', 23, 1)
# ('Sportsmadison', 23, 1)
# ('ucoolele', 23, 2)
# ('dv-warenhandel', 23, 1)
# ('Fast Media Ships From USA', 23, 17)
# ('V SHOOP', 23, 1)
# ('Riemax GmbH & Co. KG', 23, 2)
# ('MARMURO EUROPE', 23, 3)
# ('Leven GmbH', 23, 1)
# ('Root Trade', 23, 1)
# ('illezt', 23, 1)
# ('Timetrends24 - Schnellversand aus Deutschland', 23, 1)
# ('Masters Traditional Games', 23, 1)
# ('Karat24', 22, 1)
# ('Musikhaus Freising', 22, 1)
# ('UNIVERSAL TIME', 22, 1)
# ('OfficeCom Solutions', 22, 1)
# ('Tierzucht24', 22, 1)
# ('mz-esolutions', 22, 1)
# ('Teichpoint-Shop', 22, 1)
# ('Sam Mills Inc', 22, 1)
# ('Knobelbox', 22, 1)
# ('ANKUL', 22, 1)
# ('Doppi Saldi', 22, 1)
# ('Lecxins', 22, 1)
# ('YBT Home', 22, 1)
# ('elektro-plus', 22, 8)
# ('Plauere', 22, 1)
# ('Racketworld', 22, 1)
# ('BWBahn', 22, 18)
# ('Pickloud', 22, 1)
# ('BEGUM KARADAG STYLE', 22, 1)
# ('BetterDay®', 22, 1)
# ('Fahrradhoch3', 22, 2)
# ('Bijourama', 22, 2)
# ('heute-kaufen', 22, 3)
# ('TMK Handel GmbH', 22, 1)
# ('Atomstack Workshop', 22, 1)
# ('Wohi', 22, 1)
# ('FURBIFY', 22, 3)
# ('Annova (UK) Ltd_1', 22, 1)
# ('Folanda', 22, 1)
# ('Juwelier SCHWAHN', 22, 1)
# ('Tanxiaoyan', 22, 1)
# ('TRIPPODO EU', 22, 12)
# ('werkzeugbilligercom', 21, 7)
# ('Skylake Medical', 21, 1)
# ('Think Med', 21, 1)
# ('Casa Due pur GmbH', 21, 1)
# ('Groupe Dragon', 21, 1)
# ('MercadoActual', 21, 6)
# ('Amazon US', 21, 11)
# ('COMPUTERS PARTS SRL', 21, 1)
# ('MMF ENTERPRISE LTD', 21, 3)
# ('Deggelbam Company', 21, 1)
# ('Wessels24-de', 21, 5)
# ('Niclous', 21, 1)
# ('Computer Milano', 21, 13)
# ('ROYALBOX LLC', 21, 1)
# ('Office Partner GmbH', 21, 20)
# ('limonds', 20, 7)
# ('Brandfield', 20, 1)
# ('Dream-Shoes-Store', 20, 1)
# ('Istituto Ottico ISOLANI srl', 20, 2)
# ('B2B OPTICAL', 20, 1)
# ('Axana', 20, 1)
# ('Conrad Electronic SE', 20, 36)
# ('Rotenburger Schmuckcenter', 20, 1)
# ('OUTDOOR-WORKS\xad\xad\xad\xad', 20, 1)
# ('Fusselkopf', 20, 1)
# ('SHIOUCY', 20, 1)
# ('DSSBYGO', 20, 1)
# ('WeLoveLenses', 20, 1)
# ('TUC ONLINE', 20, 1)
# ('SMDV', 19, 27)
# ('Danto GmbH', 19, 4)
# ('L-Parts', 19, 1)
# ('Kidia', 19, 1)
# ('Ivomaa', 19, 2)
# ('Trusty-Sales-Shop', 19, 1)
# ('Francy Pelletterie', 19, 1)
# ('VOS-CONSOMMABLES 🥇🥇', 19, 1)
# ('Travel in Style', 18, 1)
# ('Medpets', 18, 2)
# ('EUROPEAN TOOLS', 18, 1)
# ('iSunFun', 18, 1)
# ('Buerobedarf-24', 18, 22)
# ('STVmedAppo', 18, 1)
# ('BoTuMaoYi', 18, 1)
# ('Eisen-Stenger GmbH Preise inkl. MwSt', 18, 1)
# ('TLAMA games', 18, 16)
# ('Würfelkrieger', 18, 2)
# ('Online Handel Deutschland - Preise inkl. MwSt. - Impressum und Widerrufsbelehrung finden Sie unter Verkäufer-Hilfe', 18, 4)
# ('syswork', 18, 9)
# ('Gausmann-Technik', 17, 1)
# ('YangQuanJingJiJiShuKaiFaQuFeiQiShangMaoZhongXin', 17, 1)
# ('smallbug_shop', 17, 3)
# ('my-powertools', 17, 1)
# ('Pippi-Lotta-Kinderschuhe', 17, 4)
# ('frugalino - shop', 17, 1)
# ('IntechTrade', 17, 10)
# ('Homoeopathiefuchs Versand-Apotheke', 16, 1)
# ('Freizeit mit vier Pfoten UG (haftungsbeschränkt)', 16, 3)
# ('2Chilly', 16, 1)
# ('Zizzoo', 16, 5)
# ("Opa Willi's", 16, 1)
# ('LEOKA', 16, 1)
# ('HöberOnline', 16, 3)
# ('PTH TH/CK', 16, 2)
# ('Ira`s Shop', 16, 6)
# ('HOLTI', 16, 7)
# ('Motostacja', 16, 4)
# ('Fluid_Onlinehandel', 15, 1)
# ('tonies®', 15, 1)
# ('shanxifanjiank', 15, 1)
# ('Red Cat GmbH', 15, 8)
# ('Animal Mood. SL', 15, 1)
# ('Glückskiste', 15, 1)
# ('etree GmbH', 15, 3)
# ('Ragazzi Bags', 14, 1)
# ('JOYERIA TURMALINA', 14, 1)
# ('Autoteile-Lagerversand', 14, 3)
# ('Meiguoduizhang', 14, 2)
# ('Hair Gallery', 14, 3)
# ('Wegmann 1855', 14, 1)
# ('steinchenwelt', 14, 12)
# ('Büroservice VS', 14, 4)
# ('Dein Buster', 14, 3)
# ('Casatec', 14, 14)
# ('SPORT INNOVATIONS', 14, 1)
# ('INVE', 14, 18)
# ('rebuy recommerce GmbH', 14, 2)
# ('TechnologyONE Germany', 14, 4)
# ('Werrashop', 14, 1)
# ('newpop', 14, 1)
# ('Monis Kinderstube', 14, 2)
# ('Sport Hübner', 14, 1)
# ('Envirel', 14, 1)
# ('Shopfair GmbH', 14, 1)
# ('Modellbau-Quelle - ab 20.-€ Schnellversand', 13, 3)
# ('DS Trading GmbH', 13, 5)
# ('myToys-de GmbH', 13, 50)
# ('Janado', 13, 1)
# ('momomaus2014', 13, 3)
# ('HorSeven GmbH', 12, 1)
# ('sl-auktion', 12, 1)
# ('markenbaumarkt24', 12, 5)
# ('MemoryC', 12, 13)
# ('Hawatode - stationärer Fachhändler für Haushaltswaren und Tischkultur', 12, 1)
# ('Svanas', 12, 2)
# ('StarPlanet', 12, 1)
# ('TRENDYKids', 12, 5)
# ('Bergfreunde GmbH', 12, 4)
# ('Werkzeugdiscount24', 12, 1)
# ('Dealzonu', 12, 1)
# ('MYL Milano Prime 🥇', 11, 1)
# ('Wolffstore_GmbH', 11, 1)
# ('TECH STORE 99P', 11, 1)
# ('Good Brands Store', 11, 2)
# ('CameraTools', 11, 7)
# ('TradeINN', 11, 35)
# ('NEXOC. STORE', 11, 6)
# ('G.S Informática', 11, 1)
# ('esando', 11, 2)
# ('Wiesloch', 11, 1)
# ('Bekureta mobile', 11, 1)
# ('Belion-World', 11, 1)
# ('TAKETHAT', 11, 1)
# ('Gastro & Office', 11, 8)
# ('SPORT AND TREND', 10, 1)
# ('Time-Pieces by Juwelier Braun', 10, 1)
# ('toys DE', 10, 2)
# ('Splendid Time', 10, 1)
# ('WIMBA', 10, 1)
# ('Runmarkt', 10, 1)
# ('HAUSFELDER accessoires + reise', 10, 13)
# ('Waita', 10, 5)
# ('schuhschachtel24', 10, 1)
# ('buchtec', 10, 2)
# ('Luckyberg', 10, 2)
# ('Yaoaodianzi', 10, 1)
# ('multitrader', 10, 1)
# ('handelshaus-buerg', 10, 1)
# ('Zierleyn GmbH & Co. KG', 10, 7)
# ('petotal', 10, 5)
# ('PRIVIX® (Preise inkl. MwSt.)', 9, 3)
# ('"Home-Elektro"', 9, 4)
# ('OCASIONIA', 9, 5)
# ('Stabilo-Fachmarkt', 9, 5)
# ('Marken-Koffer', 9, 23)
# ('Bodfeld-Apotheke', 9, 1)
# ('hausratplus', 8, 1)
# ('Barnawatches', 8, 1)
# ('GoodTires', 8, 3)
# ('cw foto', 8, 1)
# ('Wollbody', 8, 1)
# ('NBB Deutschland', 8, 40)
# ('Tienda Siglo XXI', 8, 21)
# ('DER BREU', 8, 19)
# ('spiel-geschenke', 8, 1)
# ('Schuh-Lounge24', 8, 1)
# ('siegshop', 8, 4)
# ('Elcom Online', 8, 1)
# ('SHAYAHA', 8, 1)
# ('S7 Store', 8, 2)
# ('foto24', 8, 5)
# ('Conseil & Négoce Européen', 8, 1)
# ('Franken-Best-Shop', 8, 1)
# ('Horse Shop', 8, 1)
# ('Lamos4u', 8, 1)
# ('MassaMarkt B.V.', 8, 1)
# ('LogShield', 7, 1)
# ('Muno_Store', 7, 14)
# ('Yachew LTD', 7, 1)
# ('PAPETERIE - Mit uns macht Schule Spaß!', 7, 6)
# ('elektricworld24', 7, 10)
# ('I4YOU-SHOP', 7, 3)
# ('etrodo', 7, 1)
# ('Azerty NL', 7, 19)
# ('Southbag - Schulranzen | Rucksäcke | Koffer', 7, 13)
# ('CharliDiscount', 7, 10)
# ('2-flowerpower', 7, 3)
# ('EZTYGA UK', 7, 1)
# ('lobigo', 7, 4)
# ('Clicktime.', 6, 1)
# ('KuHandel24', 6, 1)
# ('MADEXX', 6, 1)
# ('INNPRO', 6, 2)
# ('FotoKoch-de', 6, 13)
# ('K-Line Taschendesign', 6, 4)
# ('Kinderhaus Blaubaer GmbH & Co. KG', 6, 2)
# ('McZoo', 6, 1)
# ('Topbaer', 6, 4)
# ('huguanxianrixuriyongbaihuodian', 6, 1)
# ('Haus der Marken', 6, 1)
# ('WEIZHI-DE', 6, 1)
# ('Autodoc Shop', 6, 7)
# ('Horse-Equipe', 6, 1)
# ('Astradis Elektronik', 6, 2)
# ('boomstore', 6, 15)
# ('Organic Bargains EU', 6, 1)
# ('sls_profishop', 6, 1)
# ('Erdigo', 6, 6)
# ('Schäffer24', 6, 3)
# ('Maxitools', 6, 1)
# ('EuroElectronics DE', 6, 3)
# ('erkmann - wohnen design geschenke', 6, 1)
# ('Schuhe Clever Kaufen', 6, 1)
# ('SWISS-WATCHES', 6, 1)
# ('Easynotebooks', 6, 5)
# ('S&T Onlinehandel', 6, 18)
# ('Sticker-und-co-de', 6, 1)
# ('LuYinShop', 6, 1)
# ('bettenscout', 5, 1)
# ('Kingmodels Plastikmodellbau', 5, 12)
# ('meinhausshop', 5, 1)
# ('mhw24-Shop', 5, 2)
# ('zooundgarten-de', 5, 6)
# ('dieTechnik', 5, 23)
# ('Aquaristik_Langer', 5, 2)
# ('HK-Schuhe Hillebrand GmbH', 5, 1)
# ('BIGPHONE', 5, 2)
# ('RCWELT', 5, 5)
# ('WIMMER AUTOTEILE.  Preise inkl. MwSt.', 5, 3)
# ('pepegi eu', 5, 1)
# ('TECHNOINF SRLS', 5, 2)
# ('Estermann Warenhandels GmbH', 5, 1)
# ('KAMERACLUB (prof. Händler)', 5, 2)
# ('BlueBrixx-Shop', 5, 1)
# ('GSERVICESHOP', 4, 3)
# ('Nodium Gruppe', 4, 2)
# ('Westfalia', 4, 5)
# ('abel-shop-de', 4, 3)
# ('Red Maven Technologies', 4, 1)
# ('Mobility in Harmony', 4, 1)
# ('TOP TWO GmbH', 4, 7)
# ('Sportartikel Joos GmbH', 4, 1)
# ('E-trading-click', 4, 3)
# ('koffer_direkt', 4, 1)
# ('technikgross', 4, 36)
# ('KupZarovky', 4, 2)
# ('Habitas Online', 4, 2)
# ('Accesoralia', 4, 3)
# ('Schuhhaus20', 4, 1)
# ('casa&design', 4, 1)
# ('vidaXL DE', 4, 5)
# ('FastTech Solutions', 4, 3)
# ('Carta Mondo. Preise inkl. MwSt.', 4, 1)
# ('KitchenKing24', 4, 4)
# ('GokayPato', 4, 1)
# ('Spielzeugladen Neusser', 4, 1)
# ('Schuh-Helden', 3, 1)
# ('Blackcup', 3, 1)
# ('babywalz', 3, 7)
# ('ZICPLACE', 3, 1)
# ('You Get - Innovation & Technology', 3, 11)
# ('RAREWAVES USA', 3, 1)
# ('LSB24', 3, 5)
# ('KinderMax', 3, 2)
# ('Conquest GmbH', 3, 21)
# ('E-Tarastore', 3, 6)
# ('SuperShoes.store', 3, 1)
# ('Supermart USA', 3, 1)
# ('Pollin Electronic GmbH', 3, 20)
# ('ELOLT', 3, 2)
# ('THEPOSAL', 3, 4)
# ('Taschen Paradies', 3, 3)
# ('Cernovia', 3, 7)
# ('Unique Jewelry Design', 3, 3)
# ('CentroStefanisrl', 3, 5)
# ('CHRIST Juweliere und Uhrmacher', 3, 9)
# ('Taschenkaufhaus', 3, 7)
# ('Kettenbertl', 3, 1)
# ('collect-it-de VEDES-Spielwaren', 3, 21)
# ('MondoTop', 3, 9)
# ('NIBIUZI', 3, 1)
# ('Minfo lda', 3, 8)
# ('Maucher', 3, 1)
# ('4DAVE', 3, 2)
# ('eCommerceBaltic', 3, 3)
# ('INDIGO SHOP', 3, 3)
# ('Max&Luna', 3, 2)
# ('MeinTierdiscount', 3, 2)
# ('shoppaqui-it', 3, 2)
# ('deine-traumfabrik', 3, 9)
# ('Heymen-Tech', 3, 2)
# ('Bauportal24H', 3, 2)
# ('Hausrat-Online', 2, 1)
# ('schuhwelt24', 2, 1)
# ('Tonerversum', 2, 1)
# ('shop_moll', 2, 3)
# ('shop-ar', 2, 12)
# ('Haase Shopping e. K.', 2, 2)
# ('COMSPOT GmbH', 2, 12)
# ('ESSEBI SHOP', 2, 2)
# ('lagoonos', 2, 4)
# ('schmunzelland', 2, 4)
# ('TECshop24', 2, 1)
# ('Kleene Steene', 2, 2)
# ('HW_Shop', 2, 1)
# ('my_tommis', 2, 1)
# ('modeherz "Alle Preise inkl. Mwst."', 2, 38)
# ('TRAD€RS', 2, 1)
# ('Spielquelle. Preise inkl. MwSt.', 2, 4)
# ('Colortoner', 2, 6)
# ('LA BOITE A MUSIQUE 57', 2, 1)
# ('SCHNELL & GÜNSTIG', 2, 3)
# ('SEM-Shop', 2, 2)
# ('-uniqueplace-de-', 2, 1)
# ('viggoone', 2, 1)
# ('DVDMAXXX', 2, 5)
# ('Luzern', 2, 17)
# ('Sanitäts-Online', 2, 1)
# ('Lasetzky-Shop', 2, 7)
# ('M & L         aus Deutschland', 2, 49)
# ('Diveland', 2, 1)
# ('3 BRICKS', 2, 2)
# ('Schulranzen4Kids', 2, 4)
# ('tjarksen music-shop', 2, 2)
# ('Securia Pro', 2, 1)
# ('Flanco Retail', 2, 9)
# ('Cover Music', 2, 1)
# ('it-versand•com', 2, 1)
# ('Apotheke Online', 2, 1)
# ('Koi-und Bonsaipark Herdecke GmbH', 2, 1)
# ('Easytoys', 2, 1)
# ('WElektrO', 2, 4)
# ('BEMON', 2, 4)
# ('GRANDIN GROUP', 2, 2)
# ('K&L-Topshop GbR-inkl-MwSt-Widerrufsbelehrung-AGB-unter-Verkaeufer-Hilfe', 2, 1)
# ('Gaiacom_1', 2, 1)
# ('eastend', 2, 1)
# ('Berlet', 2, 1)
# ('Orange Hare', 2, 5)
# ('autoteilebox-com', 2, 3)
# ('MUSIC STORE Professional', 2, 39)
# ('Bodfeld Apotheke', 2, 2)
# ('Weip', 2, 6)
# ('Bio Factur GmbH', 2, 1)
# ('ICHANGEPRO LDA', 2, 8)
# ('Musikhaus Hübner', 2, 3)
# ('NaturSchatulle', 2, 1)
# ('inwohn', 2, 1)
# ('InnovativeWeb', 2, 5)
# ('bestbrand', 2, 1)
# ('Verkaufsplatz', 2, 1)
# ('extenso24', 2, 1)
# ('WEBSTER IT', 2, 9)
# ('druckmittel', 2, 2)
# ('A-M-A-Z-O-N-A-S GmbH', 1, 1)
# ('Shopping-Stop - Ingo Meyer', 1, 2)
# ('Shopping4u-24', 1, 2)
# ('eshop-wagner', 1, 3)
# ('D&G deine Lieblingshändler', 1, 1)
# ('Cosse GmbH', 1, 4)
# ('Cornilleau', 1, 1)
# ('Selley.', 1, 1)
# ('sternapo', 1, 1)
# ('Spechtshop', 1, 1)
# ('HD4L International', 1, 1)
# ('Bikeparts-de (Preise inkl. MwSt. Impressum. AGB. Widerrufsbelehrung finden Sie unter Verkäufer-Hilfe)', 1, 1)
# ('1A-Elektronik', 1, 7)
# ('Di Rosa', 1, 1)
# ('Relusch', 1, 1)
# ('www.cochesdemetal.es', 1, 1)
# ('SCHIPRO', 1, 1)
# ('blue-e', 1, 1)
# ('De Boer Drachten', 1, 1)
# ('Beautic.Shop', 1, 1)
# ('bastidasrl', 1, 1)
# ('Zoo Galaxie', 1, 4)
# ('IndiaStore-de', 1, 1)
# ('Samsumg galaxy', 1, 1)
# ('Sapato-it', 1, 3)
# ('Schreibdesign', 1, 9)
# ('ambiente & object online GmbH', 1, 2)
# ('evergreen computer', 1, 1)
# ('Zoundhouse - Dresden', 1, 43)
# ('LS Trading UG', 1, 3)
# ('Toyshop Mittelrhein', 1, 8)
# ('A-Z Hoffmann', 1, 1)
# ('modellbau.härtle', 1, 5)
# ('Kotryna', 1, 2)
# ('Korbmayer', 1, 4)
# ('TT Recycling GmbH', 1, 2)
# ('Ingane', 1, 2)
# ('Takemore', 1, 1)
# ('AutoteileDirekt', 1, 8)
# ('Chip Componentes', 1, 8)
# ('Breros', 1, 3)
# ('Tek4life', 1, 1)
# ('Sport-Riegel', 1, 1)
# ('Fritz Berger GmbH', 1, 1)
# ('Versandapotheke Sparmed', 1, 1)
# ('AnkerDirect DE', 1, 1)
# ('konsolen-spiele', 1, 1)
# ('VTN-GmbH', 1, 1)
# ('kieskemper1928', 1, 6)
# ('Humbi Toys', 1, 1)
# ('Treat stores', 1, 6)
# ('Albenisa GmbH', 1, 2)
# ('Bremer Elektrohandel', 1, 9)
# ('Albaeleshop', 1, 4)
# ('TM-Shop24', 1, 1)
# ('JUWELIER Pfeiffer', 1, 1)
# ('spiessxxl', 1, 24)
# ('sorgers-bags-and-more', 1, 3)
# ('softconn24', 1, 1)
# ('Kinder-Regenbogenland', 1, 1)
# ('Concept Network', 1, 2)
# ('sneakerstudio', 1, 1)
# ('Stock-Fachmann', 1, 1)
# ('Kärcher EU', 1, 1)
# ('BLIGHTY', 1, 2)
# ('Boutikazik', 1, 34)
# ('INSTYLIO', 1, 1)
# ('Juwelier-Bektas', 1, 2)
# ('AVATO Technic Deals', 1, 1)
# ('preis-schock-eu', 1, 1)
# ('preigu', 1, 3)
# ('pieknyprofil', 1, 1)
# ('Star +', 1, 5)
# ('Maxmovil', 1, 3)
# ('RELAX MOMA', 1, 8)
# ('PHD_Shop', 1, 1)
# ('Masha Elektrotechnik', 1, 2)
# ('Modellbahnshop-Korn', 1, 17)
# ('MpgSports', 1, 1)
# ('M Versandhandel', 1, 1)
# ('Onlineshop-HBL', 1, 2)
# ('EDV-Service Stadlauer', 1, 4)
# ('Musikhaus-Korn', 1, 32)
# ('EASY CARAVANING', 1, 1)
# ('Modellauto Wanner', 1, 1)
# ('Duftzwillinge Zwickau by Sawasdee Thai Massage', 1, 1)
# ('PRIME ITALIA', 1, 2)
# ('Möbel Jack', 1, 1)
# ('MB 2 Broliai', 1, 1)
# ('MasterToy', 1, 2)
# ('MOLUNA', 1, 3)
# ('Electronic XXL Sachsen', 1, 28)
# ('E-COMMERCE EUROPE', 1, 18)
# ('Pesci Camping Store', 1, 1)
# ('Photo Porst Memmingen', 1, 1)
# ('Okulus', 1, 1)
# ('Omnya Diversity', 1, 4)
# ('Musik Boulevard GmbH', 1, 1)
# ('MeCom e.K.', 1, 4)
# ('MTG Factories', 1, 2)
# ('ElectroBrand', 1, 2)
# ('fahrzeugtechnik-rester', 0, 3)
# ('euro-print', 0, 1)
# ('NONSOLO-INFORMATICA', 0, 1)
# ('Electroactiva', 0, 2)
# ('Baby-Direkt', 0, 4)
# ('IT PARTNER', 0, 1)
# ('edinger', 0, 1)
# ('NUTRIFITNESS', 0, 1)
# ('BS GIOCATTOLI', 0, 1)
# ('farmers-shop', 0, 1)
# ('BRICALIA', 0, 1)
# ('eCenterShop', 0, 2)
# ('firmaleder', 0, 2)
# ('flac Shop', 0, 5)
# ('foreplay', 0, 1)
# ('INTERSPORT Schoell', 0, 1)
# ('foto-tip', 0, 5)
# ('BULLASTEC', 0, 1)
# ('espace-bricolage', 0, 2)
# ('Game World', 0, 1)
# ('IbericaVIP', 0, 1)
# ('edinger Lampertheim', 0, 1)
# ('Babyshop_Hunstig', 0, 1)
# ('Ideen von A - Z', 0, 8)
# ('Bahn + Hobby Günsel', 0, 2)
# ('Banemo - Rund ums Haus', 0, 3)
# ('easybellgmbh', 0, 1)
# ('BabyValue Deutschland', 0, 1)
# ('eibmarkt', 0, 4)
# ('Nejhracka', 0, 7)
# ('elektrooutletde', 0, 6)
# ('FOND OF', 0, 8)
# ('elektrotresen', 0, 7)
# ('enalox GmbH', 0, 1)
# ('INTERSPORT MEIER', 0, 1)
# ('enven e-Commerce', 0, 1)
# ('eM-shop', 0, 1)
# ('Elcotec Electronic', 0, 2)
# ('Galegory', 0, 3)
# ('Nastis Spiele Shop', 0, 2)
# ('Gallenca spa', 0, 1)
# ('Die-Bücherschwester', 0, 2)
# ('Electronic Lichtenau', 0, 14)
# ('fotole', 0, 1)
# ('fotomeister24', 0, 1)
# ('Huntera Europe', 0, 1)
# ('hometronics24', 0, 1)
# ('hugendubel-de', 0, 2)
# ('Marios Dogshop', 0, 1)
# ('hundeshop', 0, 1)
# ('i-sell_2010', 0, 5)
# ('Hunter Max', 0, 1)
# ('Hundenfavoriet', 0, 1)
# ('FLGB24', 0, 1)
# ('idee+spiel THOMAS', 0, 1)
# ('ikarus...design shop', 0, 1)
# ('iko.shop GmbH', 0, 1)
# ('AutoMotor Accessori', 0, 1)
# ('Musika Abele', 0, 1)
# ('imm-professional', 0, 1)
# ('in und outdoor', 0, 1)
# ('Augenwelt24 GmbH', 0, 1)
# ('MusikMarkt - Plauen GmbH', 0, 1)
# ('Elektro Pelkmann', 0, 2)
# ('isfort-shop', 0, 1)
# ('Elektro-Himmel. Preise inkl. MwSt.', 0, 2)
# ('itenga GmbH', 0, 1)
# ('Hoppala Spielwaren und mehr', 0, 5)
# ('hibuy', 0, 1)
# ('Mutter und Glück', 0, 2)
# ('ILION PROJECT', 0, 2)
# ('gardexx', 0, 1)
# ('fotoversand24', 0, 3)
# ('frankonia_shop', 0, 1)
# ('Maison-Blanche', 0, 1)
# ('frisliv', 0, 1)
# ('e lentillas', 0, 1)
# ('funkelstein', 0, 1)
# ('MaquimSom', 0, 1)
# ('NATIONAL INFORMATIQUE', 0, 2)
# ('BERSERK MEDIA', 0, 1)
# ('gameland-alzey', 0, 1)
# ('Mádori Soluciones', 0, 1)
# ('MyBrand Italia', 0, 1)
# ('IMMAY', 0, 1)
# ('IMJ Global', 0, 1)
# ('MyFit24', 0, 1)
# ('gherigherardishop', 0, 1)
# ('Games2Game', 0, 13)
# ('AvenuedesJeux', 0, 1)
# ('guanyunxianzhangbohaoriyongbaihuoxiaoshoudian1', 0, 2)
# ('hagelshop', 0, 4)
# ('hairstyle24 Preise inkl. MwSt.', 0, 1)
# ('Garcia Webshop', 0, 1)
# ('Bargainmax Ltd', 0, 1)
# ('Bartolucci S.r.l.', 0, 6)
# ('dynamic24', 0, 1)
# ('MUSCLEPRIME SL', 0, 1)
# ('antonversand', 0, 2)
# ('Intersport Grosse', 0, 1)
# ('Berauer Sport und Mode GmbH', 0, 1)
# ('Internethandel-Oberwetter', 0, 2)
# ('aqua-e', 0, 1)
# ('Ben & Ben', 0, 1)
# ('arbeitsbedarf24', 0, 1)
# ('Internethandel und Büroservice', 0, 2)
# ('Belomax', 0, 1)
# ('Oberland', 0, 3)
# ('Bell IT GmbH', 0, 1)
# ('babyartikel-de', 0, 1)
# ('MULTI-LITE GmbH', 0, 1)
# ('OLShop AG', 0, 1)
# ('OHD_GmbH', 0, 1)
# ('Inovtel', 0, 5)
# ('OFICuenca S.L.', 0, 1)
# ('bc-company', 0, 1)
# ('beimerilin', 0, 1)
# ('MUSIK-SCHUBERT', 0, 1)
# ('bellytime', 0, 1)
# ('bereket24', 0, 1)
# ('besamex Versandapotheke (DE)', 0, 1)
# ('MW-Sonderposten', 0, 1)
# ('anndora_', 0, 2)
# ('Eci Elettroforniture', 0, 2)
# ('Ihr Brillenspezialist Reinhardt GmbH', 0, 1)
# ('ZooHerz', 0, 1)
# ('Okmusic-Musikfachgeschäft', 0, 4)
# ('JOYLEE', 0, 1)
# ('ZK Online-Vertrieb', 0, 1)
# ('Big-Buy-de . Preise inkl. MwSt.', 0, 1)
# ('Big Lens', 0, 1)
# ('Zierfischtreff Pappenheim.', 0, 3)
# ('JOYERIA MILENIO  Offizieller Distributor', 0, 1)
# ('Zimmermann-Verkauf', 0, 1)
# ('GPerduMesAiguilles', 0, 1)
# ('Office24_7', 0, 1)
# ('MUBUTEL', 0, 2)
# ('ZooMonster', 0, 1)
# ('Bernds Spielzeug Laden', 0, 4)
# ('Ofenseite by EnergieWerk Ost GmbH', 0, 1)
# ('Better Kitchen', 0, 1)
# ('Eazik', 0, 2)
# ('abs-spielwaren', 0, 2)
# ('Intersport Stähle', 0, 1)
# ('BestBuy-DE', 0, 3)
# ('allTech', 0, 3)
# ('Intersport Meier (Schuh Meier Sport GmbH)', 0, 1)
# ('Best-Body-Nutrition', 0, 1)
# ('allmedia-dinslaken', 0, 4)
# ('Bernhard Klatt (kein Ausweis MwSt möglich)', 0, 2)
# ('Notenmühle', 0, 1)
# ('Beach11 | Viennawear', 0, 1)
# ('bl-systems Preis inkl. MwSt', 0, 1)
# ('derspielzeugladen2', 0, 2)
# ('Be sCool Gmbh.', 0, 1)
# ('Bazoom-Shops', 0, 3)
# ('Bauzaunwelt', 0, 1)
# ('dascleverespielzeug', 0, 1)
# ('dc-musicshop', 0, 1)
# ('Bautenbacher', 0, 9)
# ('deejays GmbH', 0, 2)
# ('Newlevel-Marketing', 0, 1)
# ('deliverO', 0, 2)
# ('der-spielzeugladen', 0, 2)
# ('der_buechermann', 0, 2)
# ('die flora - Seit 40 Jahren Ihr Gartenprofi!', 0, 2)
# ('MYRUDOO', 0, 1)
# ('Magic Toys Italia', 0, 4)
# ('Eitzenhöfer Gmbh & Co KG', 0, 1)
# ('ElcoTeam', 0, 3)
# ('diman-warenhandel', 0, 3)
# ('dj_tom', 0, 1)
# ('Incremental_', 0, 1)
# ('jarotoys', 0, 1)
# ('NeueKaufleute', 0, 16)
# ('Magnolia EU', 0, 1)
# ('druide123', 0, 2)
# ('duo schreib & spiel Markenshop', 0, 13)
# ('FOTONIA', 0, 1)
# ('cundl-store', 0, 1)
# ('crazytrade', 0, 1)
# ('counterapo', 0, 1)
# ('Mabö', 0, 1)
# ('buchbaer', 0, 1)
# ('buchgeheimnis', 0, 1)
# ('buchrakete', 0, 2)
# ('Inkovideo GmbH & Co. KG. alle Preise inkl. MwSt.', 0, 1)
# ('buecheroase_muenchen', 0, 2)
# ('bueroschulze', 0, 1)
# ('buyhair', 0, 2)
# ('bv.versand2012', 0, 3)
# ('BeOnTime', 0, 1)
# ('bücher-de', 0, 4)
# ('campmarkt24', 0, 1)
# ('Ecomika Store', 0, 1)
# ('casadelrasoio', 0, 3)
# ('cleverdeals-de', 0, 1)
# ('clockhouse', 0, 1)
# ('GUCONSHOP di Guglielmo Conte', 0, 1)
# ('Eighteen Shop', 0, 1)
# ('colludo Preis inkl. Mwst', 0, 2)
# ('BeMyGame', 0, 10)
# ('cook-shop24', 0, 1)
# ('corona-net (alle Preise incl. MwSt.)', 0, 2)
# ('coseon-de', 0, 8)
# ('japanpassion.it', 0, 2)
# ('Elektro-Shop Köck GmbH', 0, 26)
# ('jeanstation', 0, 1)
# ('Eultgen-toys', 0, 1)
# ('Miraweb Shopping', 0, 1)
# ('AHR001', 0, 1)
# ('ABC-Schnäppchenmarkt GmbH', 0, 5)
# ('spiel-boebie (alle Preise inkl. MwSt.)', 0, 1)
# ('HR KOM', 0, 1)
# ('spielwaren-express / rohling-express', 0, 20)
# ('sportbiene', 0, 1)
# ('sporteck2000', 0, 1)
# ('sportfabrik', 0, 1)
# ('sportmueller', 0, 1)
# ('sportsonly1 "Preise inkl. MwSt."', 0, 1)
# ('starmobile GmbH', 0, 1)
# ('theOnlyMarket', 0, 1)
# ('HORSE PET ITALIA', 0, 1)
# ('Milibra', 0, 1)
# ('HOMECARE ZONE', 0, 1)
# ('suonostore', 0, 2)
# ('HOMECARE FR', 0, 1)
# ('ExB Videogames', 0, 1)
# ('7tronix', 0, 10)
# ('Excluso luxury', 0, 1)
# ('4deal_digitouch', 0, 1)
# ('teich24eu', 0, 1)
# ('4Fun sHop', 0, 1)
# ('Mires Elettrodomestici', 0, 2)
# ('FB-Versand', 0, 1)
# ('smartgoods-de', 0, 1)
# ('HUGO BOSS AG', 0, 1)
# ('reifenmontagezubehör-de (DHL+Post! /inkl. MwSt.!)', 0, 2)
# ('AMZ WEB srls', 0, 1)
# ('rickertmanfred', 0, 1)
# ('Hair Discount', 0, 2)
# ('rudi79268. Das Fachgeschäft e.K.', 0, 1)
# ('schafi-shop', 0, 1)
# ('Modellbahn-Voigt', 0, 1)
# ('schneeschuhe de - Manfred Clarck', 0, 2)
# ('schuhede', 0, 3)
# ('Haase online', 0, 3)
# ('Modellbahn-Ecke Essen', 0, 14)
# ('AMA - SHOP', 0, 1)
# ('Modellbahn Raschka', 0, 1)
# ('Global Ape', 0, 4)
# ('sharan2005', 0, 1)
# ('Endreß KG', 0, 1)
# ('ALLETASCHEN Bartelsmeier', 0, 3)
# ('ALLES FFO KG', 0, 2)
# ('Modehaus Heinze Online-Shop', 0, 1)
# ('ALCUBE GMBH', 0, 1)
# ('Haarboutique', 0, 1)
# ('Mode Steffen', 0, 3)
# ('Modashop247', 0, 1)
# ('tevirp', 0, 1)
# ('Exquisit Direkt', 0, 1)
# ('Hans Jürgensen GmbH & Co. KG', 0, 1)
# ('*Party_Factory_Ladenburg*', 0, 1)
# ('1001jouets', 0, 7)
# ('00kindel', 0, 1)
# ('HANEU GmbH', 0, 2)
# ('werte7', 0, 2)
# ('whybee-ltd', 0, 1)
# ('Medi Partners', 0, 1)
# ('Glücks-Spielzeugkiste Preise inkl.MwSt.', 0, 1)
# ('- Atlantis -', 0, 1)
# ('world-netshop', 0, 1)
# ('worldofsport', 0, 1)
# ('Mechatronics-Pro', 0, 2)
# ('Gutbrod Modehaus', 0, 1)
# ('time4wellness', 0, 3)
# ('Grünhagel', 0, 2)
# ("'OOTB'", 0, 2)
# ('Mecamedia', 0, 1)
# ('"notebook.de"', 0, 3)
# ('Golden-Group', 0, 2)
# ('zemre-shopping', 0, 1)
# ('zoo-shop (Preise inkl. Mwst.)', 0, 1)
# ('zumBleistift-bali', 0, 2)
# ('zuni.shop', 0, 2)
# ('Goldixa', 0, 1)
# ('✅ NETNBUY ✔️', 0, 1)
# ('FAFMUSICA', 0, 2)
# ('vidro24', 0, 1)
# ('videorayman', 0, 1)
# ('Mega dealings', 0, 1)
# ('Mercatus Online', 0, 5)
# ('toboshop', 0, 5)
# ('toennes24', 0, 1)
# ('Global Dream ⭐⭐⭐⭐⭐ KOSTENLOSE RÜCKGABE', 0, 1)
# ('HOBBY AKKURA', 0, 1)
# ('Maxeda E-Commerce', 0, 1)
# ('HEPEshop', 0, 4)
# ('3M Musica di Mura Luisa Raimonda SAS', 0, 1)
# ('trockenbauspezialist', 0, 2)
# ('tuningschnellversand   (Alle Preise inkl. Mwst)', 0, 1)
# ('Meinl-Shop', 0, 2)
# ('Meinhardt - Wir verschicken direkt!', 0, 1)
# ('2020 SRL', 0, 1)
# ('HB-Handel', 0, 2)
# ('uhr24', 0, 5)
# ('MaxiLand | Rechnungen inklusive MwSt.', 0, 1)
# ('F.lli Pertoso SNC', 0, 1)
# ('ultra-pharm', 0, 1)
# ('180kmh - Sporternährung', 0, 1)
# ('123-Gold-Straubing', 0, 1)
# ('vegaonline', 0, 1)
# ('HARDLOOP', 0, 1)
# ('venDue', 0, 1)
# ('redealer', 0, 1)
# ('raumbox (Preise inkl. MwSt.)', 0, 1)
# ('jm.store', 0, 1)
# ('microprecios', 0, 1)
# ('Martin Pecksteiner', 0, 1)
# ('Herzberger Modellwelt', 0, 3)
# ('Geben tut gut Gmbh', 0, 1)
# ('mcbuero_gmbh', 0, 4)
# ('An tAonach Retail', 0, 1)
# ('AmerigoStore', 0, 1)
# ('mein-elektro24-com', 0, 1)
# ('Ameliastella Fashion', 0, 1)
# ('meine-kleine-eisenbahn', 0, 4)
# ('Monteprato', 0, 2)
# ('EliXito', 0, 26)
# ('mimpf2000', 0, 1)
# ('Alpine Trading Mittenwald', 0, 1)
# ('Ambitemp', 0, 10)
# ('Elipo®', 0, 1)
# ('Martons', 0, 1)
# ('Gebraucht-land', 0, 1)
# ('moebelplus', 0, 3)
# ('Giardino dei Balocchi', 0, 2)
# ('monPARFUM | Markenparfüme für Sie & Ihn', 0, 3)
# ('motointegrator', 0, 2)
# ('ms-plueth', 0, 4)
# ('muddukaufen_Sammelwelt', 0, 5)
# ('multimedia-guenstiger', 0, 1)
# ('lu-wave-shop', 0, 1)
# ('Morso', 0, 1)
# ('AnimalZ-Online', 0, 1)
# ('livingtools', 0, 1)
# ('Aricitec', 0, 2)
# ('Hommel GbR - Preise inkl. MwSt', 0, 1)
# ('jusigo Juwelier-Silber-Gold', 0, 1)
# ('Billo-Schuhe', 0, 1)
# ('Aqua-Saar GmbH', 0, 2)
# ('Elektronik-Star-DE', 0, 1)
# ('Apollo store', 0, 1)
# ('Elektropower GmbH', 0, 1)
# ('GateOne', 0, 1)
# ('koffer24 de', 0, 3)
# ('Mrbricksandmore', 0, 1)
# ('MrPackage', 0, 5)
# ('kova', 0, 1)
# ('ksw-shop', 0, 3)
# ('Ankermann Computer', 0, 1)
# ('laGRU SRL', 0, 1)
# ('HolzInnsel - Preise inkl. MwSt.', 0, 4)
# ('Holahora', 0, 1)
# ('HoT - House of Tools', 0, 1)
# ('Him & I', 0, 2)
# ('Marle-shop', 0, 1)
# ('lindaxx Spielwaren', 0, 2)
# ('Hildebrandt_Basar', 0, 1)
# ('Maschinen Stockert', 0, 2)
# ('AlmaMed', 0, 1)
# ('Hansekontor-SJ', 0, 1)
# ('preiswerter-koffer', 0, 1)
# ('online-moebel-shop', 0, 1)
# ('Happy- Petshop', 0, 2)
# ('outdoortrends GmbH & Co. KG', 0, 1)
# ('peffeshop', 0, 1)
# ('Modellbaucenter-Bochum', 0, 1)
# ('Gioielleria Nadir', 0, 1)
# ('Giordano Innovations SRL', 0, 2)
# ('play & watch', 0, 1)
# ('pptrade94', 0, 3)
# ('Modellbau-Braeuer', 0, 3)
# ('Modellbau Fischer', 0, 16)
# ('premium-trade', 0, 7)
# ('Haus-& Gartenwelt', 0, 2)
# ('Happy Baby Hamm', 0, 1)
# ('Modellbahnwelt 24 . Preise inkl. MwSt.', 0, 4)
# ('printer-it', 0, 1)
# ('ASIMsrl', 0, 1)
# ('produktfabrik', 0, 1)
# ('profi-electro', 0, 2)
# ('profi-shop-expresss', 0, 2)
# ('ARCOUFFICIO', 0, 3)
# ('pup24', 0, 3)
# ('AP autoparts', 0, 2)
# ('AOOBYSH', 0, 1)
# ('online-gartencenter', 0, 1)
# ('oneufficio', 0, 1)
# ('Modischen Schmuck', 0, 1)
# ('Acquatic Life SRL', 0, 2)
# ('Mondo Barista', 0, 1)
# ('Alexandre Figueiredo lda', 0, 1)
# ('mySWOOOP® GmbH', 0, 5)
# ('HardwareVersand', 0, 1)
# ('Monbeck GmbH & Co. KG', 0, 2)
# ('mylittledog2018', 0, 1)
# ('mysigikid', 0, 1)
# ('Hardware-Galaxy', 0, 1)
# ('nagamil', 0, 1)
# ('nardonirag', 0, 1)
# ('Mojekolo', 0, 1)
# ('Elternstolz', 0, 3)
# ('nbg-games', 0, 1)
# ('nero electronics', 0, 1)
# ('Gioielleria Casavola Noci', 0, 1)
# ('AiT Safety Zone', 0, 2)
# ('Ahrens-Shop', 0, 5)
# ('Agrarking DE', 0, 1)
# ('niewiera', 0, 1)
# ('nonsologiochiweb', 0, 7)
# ('novaStore', 0, 1)
# ('AeroMoov', 0, 2)
# ('Adognicosto', 0, 1)
# ('ZAPATERÍAS MARÍN', 0, 1)
# ('JUGUETES FANCY', 0, 2)
# ('Z-Bombilla', 0, 11)
# ('Spielwarendepot24', 0, 2)
# ('Sparland 24', 0, 1)
# ('Druck- und Handelsshop', 0, 3)
# ('Coolibry', 0, 1)
# ('Spicydeals', 0, 1)
# ('Spiel & Modellbau', 0, 9)
# ('Drucker de IT-Handelsgesellschaft mbH', 0, 1)
# ('Dudelpudel Heimtierbedarf', 0, 1)
# ('Contact Lenses', 0, 4)
# ('Spielwaren Hanke', 0, 4)
# ('LOGAN MALL', 0, 1)
# ('Spielwaren-Barth „Preise inkl. MwSt.“', 0, 1)
# ('Spielwarenhandel (alle Preise Inkl. Mwst', 0, 3)
# ('Sport-Thieme GmbH', 0, 2)
# ('Spielzeughit', 0, 1)
# ('Spielzeugmax', 0, 8)
# ('Spielzeugwelt Ahlten', 0, 1)
# ('LICHT-LAMPEN-LEUCHTMITTEL', 0, 2)
# ('LDD QualityToys', 0, 2)
# ('Sport Frank 1920', 0, 1)
# ('Foster-natur', 0, 4)
# ('Sport Peter', 0, 1)
# ('Sport Schuster', 0, 1)
# ('Sport Treff', 0, 1)
# ('Sport&Spiel Compact', 0, 1)
# ('Spar-Versand @ Plogoo', 0, 1)
# ('Procamping Accesorios', 0, 1)
# ('Profimarkt Nürnberg 24', 0, 1)
# ('Sonnenmeer15', 0, 1)
# ('Shoes&Fun', 0, 1)
# ('Cucinaria Kitchen-Equipment Handels-GmbH', 0, 1)
# ('Shop-Hartmann', 0, 2)
# ('Shop-Partner', 0, 1)
# ('ShopHier', 0, 1)
# ('Fiyo - Ersatzteile. Zubehör und mehr...', 0, 1)
# ('Cucina in Casa', 0, 1)
# ('Quickjewels', 0, 1)
# ('M-S-Shop', 0, 1)
# ('Silmà Boutique', 0, 1)
# ('Simply Sound Ltd', 0, 2)
# ('Sixone', 0, 2)
# ('Q4 MEDIA SRL', 0, 2)
# ('SlowCoffee - Preise inkl MwSt.', 0, 1)
# ('CrystalHome24', 0, 1)
# ('CrazyKangaroo', 0, 5)
# ('SmartFunk', 0, 1)
# ('Puzzles. Tools & More', 0, 1)
# ('Sneakers Trend', 0, 1)
# ('SofTech Preise inkl. MwSt.', 0, 1)
# ('Puzzle4u', 0, 1)
# ('Progress Choice', 0, 1)
# ('Sonnenbrillenladen', 0, 1)
# ('Primor Schuhe', 0, 1)
# ('LAREDO', 0, 2)
# ('CuraVendi - Die Bonus-Apotheke', 0, 1)
# ('MAFCOM-Marc-Anthony Flechtner', 0, 2)
# ('Studioarch', 0, 1)
# ('StunningTechStore', 0, 1)
# ('ECOMMERC3', 0, 1)
# ('Supernova calzature di Annamaria Ricciardi', 0, 1)
# ('Pollivaligeria', 0, 1)
# ('Kubtec-Performance', 0, 1)
# ('Cocooncenter', 0, 1)
# ('TAURO-Shop', 0, 1)
# ('TAWAGO', 0, 8)
# ('TDTprofesional', 0, 1)
# ('ELV Elektronik AG', 0, 1)
# ('TECMONDO', 0, 2)
# ('Primegarden', 0, 1)
# ('Pinokids', 0, 1)
# ('Kruse Spiel & Fun', 0, 1)
# ('TEP Trade GmbH', 0, 1)
# ('MAIWORLD', 0, 1)
# ('MANDROPS AG', 0, 25)
# ('Clamadie', 0, 1)
# ('City Tienda', 0, 27)
# ('Krinke2011', 0, 1)
# ('City Sport Görlitz', 0, 1)
# ('Picher Spiel und Sport', 0, 14)
# ('Frankberg Autoteile', 0, 1)
# ('Studio Platinum', 0, 3)
# ('Strongvision-Videogames', 0, 2)
# ('Coloretta', 0, 4)
# ('StoreDea', 0, 1)
# ('Sportartikel und Spielwaren Shop', 0, 6)
# ('Sporthaus Rolff', 0, 1)
# ('Concept Store Photo', 0, 1)
# ('Sportnahrung-Nutrition1', 0, 1)
# ('Sportolino . Sporthaus Höss GmbH', 0, 1)
# ('LADYBUGS', 0, 1)
# ('Sportsplace', 0, 1)
# ('LADUEMILA Concept Store', 0, 1)
# ('Stahlbruck Online ab 50.- keine Versandkosten', 0, 6)
# ('E. & G. Groß GmbH (Preise inkl. MwSt. Impressum. AGB. Widerrufsbelehrung finden Sie unter Verkäufer-Hilfe)', 0, 1)
# ('LACKNER & URNITSCH GMBH', 0, 2)
# ('Preisjubel', 0, 1)
# ('PreisDeal24 "inkl. 19% MwSt."', 0, 1)
# ('Stein-Garage-de', 0, 3)
# ('Steinelädle - der Fachhändler mit LEGO® Produkten', 0, 8)
# ('Faboplay', 0, 1)
# ('Stickerdealz', 0, 1)
# ('Stilbruch Handels GmbH', 0, 1)
# ('FotoDiego', 0, 1)
# ('E. Fleischer', 0, 3)
# ('Stock4less EU', 0, 1)
# ('PowerTools Germany', 0, 1)
# ('Power Muscle Online-Shop', 0, 1)
# ('LUCCASAS', 0, 1)
# ('Drachenstube-Spielwaren', 0, 1)
# ('Youdoit', 0, 1)
# ('Ranner', 0, 1)
# ('Les Boutiques de Catena', 0, 2)
# ('SALDI SPORT SRL S', 0, 1)
# ('SAS JARDINDECO', 0, 1)
# ('Leonzi Sport', 0, 1)
# ('SCHEUFLERSHOP Versandkosten werden nur einmalig pro Lieferung berechnet', 0, 2)
# ('Ranzenlager', 0, 5)
# ('Dehner. Ihr Garten- und Heimtier-Profi', 0, 1)
# ('Ranzenfee & Koffertroll GmbH', 0, 8)
# ('Leonetti Giocattoli', 0, 3)
# ('Lemodo_GmbH', 0, 1)
# ('De Marco Shop', 0, 1)
# ('Digital-versand-de-Online-GmbH', 0, 1)
# ('Leder2000', 0, 1)
# ('SEVERIN', 0, 1)
# ('SFD Nutrition', 0, 1)
# ('Leffers', 0, 1)
# ('SHD Handels GmbH', 0, 1)
# ('Ledger', 0, 1)
# ('DbLine', 0, 7)
# ('Das heilige Überbyte', 0, 1)
# ('SIMATSHOP', 0, 1)
# ("SIMPLETEK-L'elettronica-low-cost", 0, 1)
# ('Darsagiocattoli', 0, 1)
# ('Railroad 2000', 0, 3)
# ('Rappelkiste Spielwaren', 0, 2)
# ('Falc S.p.A.', 0, 2)
# ('Fairfinity Pferdesport', 0, 1)
# ('Rott OHG', 0, 1)
# ('Die kleine Möhre -Baby- & Kinderbedarf-', 0, 1)
# ('Locust auto', 0, 7)
# ('Reidelshöfer Das Bettenhaus', 0, 1)
# ('Lothar John', 0, 1)
# ('Deva-Natur', 0, 6)
# ('DiePatrone', 0, 1)
# ('Renax Toys - Schnelle Lieferung', 0, 2)
# ('Resaris', 0, 1)
# ('Retail Success', 0, 1)
# ('Linsencenter 24', 0, 2)
# ('Rheinberg-Buch', 0, 2)
# ('Denra-Onlinehandel', 0, 1)
# ('Richard Schahl GmbH', 0, 1)
# ('Ridewill', 0, 1)
# ('LifeHaaks', 0, 1)
# ('Rig Expert', 0, 7)
# ('Robert Mirzoyan', 0, 1)
# ('Robo294', 0, 2)
# ('Fahrzeugteile Hoffmann Preise inkl. MwSt', 0, 1)
# ('RoskoMarket', 0, 1)
# ('Librolandia giocheria', 0, 2)
# ('Rotfunk GmbH', 0, 1)
# ('Rotho Kunststoff GmbH', 0, 1)
# ('SMG-Deutschland', 0, 1)
# ('Daniel_Dealz', 0, 1)
# ('Sertronics-Hannover', 0, 1)
# ('Fidando GmbH & Co. KG (Mwst. Ausweis)', 0, 1)
# ('SchlossApothekeVersand', 0, 1)
# ('Schmuck & Uhren', 0, 2)
# ('Schmuck & Uhren Lounge', 0, 1)
# ('Dilya Shop', 0, 1)
# ("Fessler's Spielkiste", 0, 7)
# ('Fabry GmbH', 0, 9)
# ('ROMMELSBACHER Germany', 0, 4)
# ('RODON', 0, 1)
# ('Lally_store', 0, 1)
# ('Dobmeier Haushaltswaren GmbH (alle Preise inkl. MwSt.', 0, 1)
# ('Lacoste Ecommerce', 0, 1)
# ('La Pianola', 0, 1)
# ('SPORT & SPORT', 0, 1)
# ('Doctor Brandt', 0, 8)
# ('Schulsachen-de', 0, 1)
# ('Schulte-Ufer Onlineshop', 0, 1)
# ('DEPICE Kampfsportartikel', 0, 1)
# ('Doppenberg meer dan keukens', 0, 2)
# ('SchönerDaheim', 0, 8)
# ('DELALIOS', 0, 1)
# ('REGALANDIA', 0, 1)
# ('Sellixx. Preise inkl. MwSt', 0, 1)
# ('DECIBEL', 0, 1)
# ('Fixversand', 0, 4)
# ('Schleibaum & Stangenberg GbR', 0, 1)
# ('Schildkröt-Shop', 0, 3)
# ('Schiele. Preise inkl. MwSt', 0, 1)
# ('Savanna Toys', 0, 2)
# ('Leder.Milz', 0, 3)
# ('Feiner Stein', 0, 1)
# ('SR EVO', 0, 2)
# ('STEFANO TALINI', 0, 1)
# ('DanGuitar', 0, 1)
# ('LeMi E-shop', 0, 1)
# ('Le SAC Outlet', 0, 2)
# ('SUPDOC', 0, 2)
# ('SUPwave®', 0, 1)
# ('Daddelshop', 0, 2)
# ('Fachhandel-Discount', 0, 1)
# ('Safawi Trading & Consulting', 0, 1)
# ('Diktierportal', 0, 1)
# ('Salamander Deutschland GmbH & Co. KG', 0, 1)
# ('Lauf-Centro24 (Preise inkl. MwSt.)', 0, 1)
# ('RVshop', 0, 1)
# ('Sanitaria Riva', 0, 1)
# ('RUGBY HEAVEN', 0, 2)
# ('RUCKSACK', 0, 10)
# ('Sarmai_Forniture', 0, 2)
# ('DURAN TOYS', 0, 1)
# ('Sascha Becker', 0, 1)
# ('Satullo', 0, 1)
# ('Photostock', 0, 1)
# ('City Kaufhaus Gaggenau', 0, 8)
# ('City Kauf GmbH', 0, 2)
# ('WITTCHEN', 0, 1)
# ('WEBELEC', 0, 2)
# ('EURONICS XXL Vilshofen', 0, 34)
# ('Brickcomplete - Rasche Lieferung!', 0, 18)
# ('MILANIKA®', 0, 1)
# ('WENKO-WENSELAAR', 0, 1)
# ('BrickPop', 0, 2)
# ('WERNER CHRIST GmbH', 0, 1)
# ('MKS Autoteile', 0, 2)
# ('WIKMAR', 0, 2)
# ('WIM JEWERLY', 0, 1)
# ('KGAC Sports', 0, 1)
# ('KFZ Held', 0, 1)
# ('Brand Distribution GmbH', 0, 4)
# ('WS-Autoteile', 0, 1)
# ('Brick by Fritz', 0, 3)
# ('PB-Shop90', 0, 1)
# ('Wachter Büro AG', 0, 5)
# ('KAUT-BULLINGER Office + Solution GmbH', 0, 3)
# ('Waldi', 0, 1)
# ('Walwes Europe', 0, 3)
# ('PAM-TECH', 0, 1)
# ('Warehousesupply', 0, 1)
# ('Warenhandel Teubner', 0, 1)
# ('Futugarden', 0, 1)
# ('Bricks & Co', 0, 3)
# ('WARENDIREKT', 0, 2)
# ('WARDOW', 0, 3)
# ('WALSER - nur das Beste für Ihr Auto', 0, 1)
# ('VV Computer Vertriebs  GmbH', 0, 2)
# ('VW360', 0, 1)
# ('Vadecompras', 0, 1)
# ('Vairema', 0, 1)
# ('Vedio-Tech', 0, 1)
# ('Veecom One', 0, 2)
# ('Buchwelt-Online', 0, 1)
# ('Verflixt & Zugespielt', 0, 1)
# ('Verlag an der ESTE GmbH', 0, 1)
# ('Buchbutler', 0, 4)
# ('Versand-Richter. Katja Richter. Preise inkl. MwSt.', 0, 1)
# ('Buch & Spiel', 0, 2)
# ('Versandapotheke Fliegende-Pillen', 0, 1)
# ('MIDI Centrum Muzyczne', 0, 9)
# ('Vexo IT', 0, 2)
# ('Vikimotion', 0, 1)
# ('Brünte Leipzig', 0, 2)
# ('Vision-Contact', 0, 2)
# ('Viva Musica', 0, 1)
# ('Bristol Fashion', 0, 1)
# ('Fulfillment Center Europe', 0, 1)
# ('FunSport', 0, 1)
# ('Brickwinkel', 0, 1)
# ('Watch Shop', 0, 1)
# ('MPH MULTIMEDIA', 0, 1)
# ('TPP TECHNOLOGY SRL', 0, 1)
# ('Blitz-Versand-Deutschland', 0, 1)
# ('MST-Versand "Preise inkl. MwSt"', 0, 2)
# ('GIGA PLAN sro', 0, 1)
# ('GIGANTECH', 0, 1)
# ('Wohnraum - Dekoration & Accessoires', 0, 2)
# ('WokiToo', 0, 1)
# ('Jekoshop', 0, 3)
# ('Wolkdirekt', 0, 1)
# ('Japankoi Holzhauer', 0, 1)
# ('Blue-Aqua-Zoode', 0, 2)
# ('Wünsch dir was', 0, 1)
# ('Jamonshop', 0, 2)
# ('Blinksale. alle Preise inkl. MwSt.', 0, 2)
# ('Web-sport', 0, 1)
# ('GIOIAPURA', 0, 4)
# ('Xonus', 0, 1)
# ('Xt Supply GmbH', 0, 4)
# ('Onlinediscount24 eSales', 0, 1)
# ('MSalesFr', 0, 8)
# ('YOUKAPI . com', 0, 4)
# ('YOUR PLUS', 0, 1)
# ('Die-Bücherfrau', 0, 2)
# ('JUEGABIEN', 0, 1)
# ('GOLDEN OUTLET', 0, 3)
# ('Omer O Store', 0, 2)
# ('Wisol24', 0, 6)
# ('Jouería-Relojería Mínguez', 0, 1)
# ('Winter - der Familienladen', 0, 1)
# ('Bonsaglio', 0, 8)
# ('WebShopArea', 0, 2)
# ('P&P Shoes', 0, 3)
# ('Weichhold GmbH', 0, 9)
# ('FScommerce', 0, 2)
# ('Weit & Breit Handelsgesellschaft mbH', 0, 1)
# ("Bradley's Printer Inks", 0, 1)
# ('Werkzeug- und Gartenfachmarkt', 0, 2)
# ('Werkzeug-Eylert', 0, 1)
# ('OutdoorSports24', 0, 2)
# ('Outdoor24 - Outdoor&Freizeitartikel', 0, 1)
# ('Juwelier Gabriel', 0, 1)
# ('GIANTEX', 0, 1)
# ('Ordnung und mehr', 0, 1)
# ('WestcoastComputer', 0, 3)
# ('Optik_Reinhardt_Shop', 0, 1)
# ('Juwelier & Zeitladen Simon', 0, 1)
# ('Westland GmbH', 0, 9)
# ('Bouticasa', 0, 2)
# ('Wiegand Wohnen & Sparen', 0, 1)
# ('Wiemann Lehrmittel', 0, 1)
# ('Juma_4u', 0, 1)
# ('JuKaMa', 0, 10)
# ('WilTec Wildanger Technik GmbH', 0, 1)
# ('PHOTO-UNIVERS', 0, 7)
# ('VSR Spielwaren', 0, 4)
# ('KLIKITALIA', 0, 1)
# ('Klavierplus.shop', 0, 1)
# ('Technikprimus', 0, 26)
# ('Freizeitprofi.eu', 0, 1)
# ('Technowelt Lindbüchl GmbH Co. KG Elektrofachhandel', 0, 3)
# ('Tecnoaffare', 0, 1)
# ('Casagift', 0, 1)
# ('Knirps/doppler Official Store', 0, 1)
# ('Kleinmetall', 0, 1)
# ('Patrick Design', 0, 1)
# ('Parts4Care', 0, 2)
# ('Cargo Travelshop', 0, 1)
# ('ERRESSE-SHOP.IT', 0, 2)
# ('Thalia Bücher GmbH', 0, 4)
# ('Fuer-Haus-und-Hof', 0, 1)
# ('Thaller OHG - Fachgeschäft', 0, 3)
# ('Camera-online', 0, 2)
# ('The Idea for Life', 0, 1)
# ('Papyrus', 0, 3)
# ('ThiesMediCenter GmbH', 0, 2)
# ('MARY ZOE', 0, 4)
# ('TiWi-Shop', 0, 1)
# ('KinneKanne', 0, 2)
# ('CYBERIEN', 0, 1)
# ('Papier-Schneider', 0, 1)
# ('CT COOL TIME', 0, 7)
# ('Freizeit-Wittke GmbH', 0, 1)
# ('Patrick Privatanbieter', 0, 1)
# ('Technic4Life', 0, 1)
# ('Paul und Pauline Shop', 0, 1)
# ('TR-Vip', 0, 6)
# ('Philipp Dase', 0, 1)
# ('Pferd und Kleintierbude            „Preise inkl. MwSt.“', 0, 1)
# ('TREPKE', 0, 6)
# ('TRIKON', 0, 2)
# ('Pezziprezzi', 0, 1)
# ('TRONYQ', 0, 3)
# ('FaSt Handel', 0, 1)
# ('Ciscoauction', 0, 1)
# ('Petingros', 0, 1)
# ('TYPECRO', 0, 1)
# ('Ciccimarra Gioielli', 0, 1)
# ('Peters Modellgarage', 0, 5)
# ('Koi- und Goldfischcenter Schneidewind', 0, 1)
# ('Pet Mate Ltd.', 0, 1)
# ('Taschenfreund Werl', 0, 2)
# ('Check Point Stores', 0, 1)
# ('Peer Online Shop', 0, 1)
# ('Kofferworld', 0, 5)
# ('Taschenvertrieb (Preise inkl. MwSt.)', 0, 1)
# ('Chatydo', 0, 2)
# ('Koffermarkt', 0, 1)
# ('PcPerformanceStore', 0, 2)
# ('KingOfBricks.', 0, 1)
# ('Fritzz', 0, 3)
# ('Kinderreigen', 0, 1)
# ('Bürowelt-Blank', 0, 6)
# ('KiddiesStore', 0, 1)
# ('Tritschler - Ihr Fachhändler', 0, 2)
# ('Tropic-Shop Preise inkl. MwSt', 0, 5)
# ('Kia121', 0, 1)
# ('PLAYMYGROUP', 0, 1)
# ('Büroservice Hübner GmbH', 0, 2)
# ('UKSoftwaretech ltd', 0, 1)
# ('ULRICH WEIGEL (alle Preise inkl. MwSt)', 0, 4)
# ('UME Union Musical', 0, 7)
# ('UNICOBRES', 0, 1)
# ('Keggol srl', 0, 3)
# ('UNOLD AG', 0, 2)
# ('US international service', 0, 2)
# ('BÜRO-ORGANISATION', 0, 1)
# ('Uhrendealer', 0, 1)
# ('Uhrzeit', 0, 1)
# ('PIXZON', 0, 1)
# ('Buy-Wisely', 0, 1)
# ('Burgenstern GmbH', 0, 1)
# ('Unterwegs Outdoor Shop', 0, 2)
# ('Fuchs123', 0, 1)
# ('KONKE SRL', 0, 6)
# ('Buffalo-shop', 0, 1)
# ('Trend-Time', 0, 1)
# ('C.R. Nordhoff Haus der Geschenke', 0, 2)
# ('Tintenklecksversand', 0, 1)
# ('Fa. Strien', 0, 1)
# ('MBS Online BV', 0, 1)
# ('MEDIACASH', 0, 3)
# ('Toms Bike Corner', 0, 1)
# ('COIL "Preise inkl. MwSt."', 0, 1)
# ('Toner.shop', 0, 1)
# ('Tonerdumping - Berlin', 0, 2)
# ('ETOH24', 0, 19)
# ('Tooler-de', 0, 1)
# ('Tools Pro Store Global Solutions', 0, 1)
# ('Top Price Shop', 0, 1)
# ('Top-Bikershop', 0, 1)
# ('Top-Preis-Shop', 0, 1)
# ('PRODO Shop', 0, 7)
# ('MERCAPOOL', 0, 1)
# ('Toyboxx', 0, 1)
# ('Toykids', 0, 1)
# ('CHICCO TRADING', 0, 1)
# ('Toys World Spielwaren (Preise inkl. MwSt.)', 0, 22)
# ('PRAXER', 0, 2)
# ('Kinder&Co', 0, 4)
# ('Kindadraum', 0, 1)
# ('CASO International GmbH', 0, 6)
# ('Kidylusion', 0, 2)
# ('🌟 LahnSteine 🌟', 0, 1)

# %% [markdown]
# ## Calculation comes Now

# %%
import pandas as pd
import numpy as np

# Assuming result_by_seller is the list containing sellerName, price changes, and unique products

# Convert the list to a DataFrame
seller_df = pd.DataFrame(result_by_seller, columns=['sellerName', 'price_changes', 'unique_products'])

# Calculate the average number of price changes per product for each seller
seller_df['price_changes_per_product'] = seller_df['price_changes'] / seller_df['unique_products']

# Calculate the mean and standard deviation of the price changes per product
mean_changes_per_product = seller_df['price_changes_per_product'].mean()
std_changes_per_product = seller_df['price_changes_per_product'].std()

# Calculate the z-scores for each seller
seller_df['z_score'] = (seller_df['price_changes_per_product'] - mean_changes_per_product) / std_changes_per_product

# Define a manually adjustable threshold for the z-score
z_score_threshold = 1

# Classify sellers as algorithmic if their z-score is above the threshold
seller_df['is_algorithmic'] = seller_df['z_score'] > z_score_threshold

# Print the z-score threshold
print('Z-score Threshold:', z_score_threshold)

# Print the DataFrame with the algorithmic sellers
algorithmic_sellers_grouped = seller_df[seller_df['is_algorithmic']]
# Out:
# Z-score Threshold: 1

# %%
import pandas as pd
import numpy as np

# Assuming result_by_seller is the list containing sellerName, price changes, and unique products

# Convert the list to a DataFrame
seller_df = pd.DataFrame(result_by_seller, columns=['sellerName', 'price_changes', 'unique_products'])

# Calculate the percentiles for price_changes and unique_products
seller_df['price_changes_percentile'] = seller_df['price_changes'].rank(pct=True)
seller_df['unique_products_percentile'] = seller_df['unique_products'].rank(pct=True)

# Calculate the z-scores for the percentiles
seller_df['z_score_price_changes'] = (seller_df['price_changes_percentile'] - seller_df['price_changes_percentile'].mean()) / seller_df['price_changes_percentile'].std()
seller_df['z_score_unique_products'] = (seller_df['unique_products_percentile'] - seller_df['unique_products_percentile'].mean()) / seller_df['unique_products_percentile'].std()

# Define weights for the z-scores of price_changes and unique_products
weight_price_changes = 1.5
weight_unique_products = 0.5

# Combine the z-scores to create a combined score
seller_df['combined_z_score'] = (weight_price_changes * seller_df['z_score_price_changes']) + (weight_unique_products * seller_df['z_score_unique_products'])

# Define a manually adjustable threshold for the combined z-score
combined_z_score_threshold = 2.5  # Increase the threshold to reduce the number of algorithmic sellers

# Classify sellers as algorithmic if their combined z-score is above the threshold
seller_df['is_algorithmic'] = seller_df['combined_z_score'] > combined_z_score_threshold

# Print the combined z-score threshold
print('Combined Z-score Threshold:', combined_z_score_threshold)

# Print the DataFrame with the algorithmic sellers
algorithmic_sellers_grouped = seller_df[seller_df['is_algorithmic']]
# Out:
# Combined Z-score Threshold: 2.5

# %% [markdown]
# ## Chen Method with simple numberic Treshhold

# %%
algo_seller_chen = []

for tup in result:
    number_of_price_changes = tup[2]
    sellerName = tup[1]
    if number_of_price_changes > 20:
        #print(tup)
        algo_seller_chen.append(sellerName)

# Remove duplicates by converting the list to a set and then back to a list
algo_seller_chen = list(set(algo_seller_chen))
# Transform the list into a DataFrame
df_algo_seller_chen = pd.DataFrame(algo_seller_chen, columns=['sellerName'])

print("Length of algo_seller_chen list (without duplicates):", len(df_algo_seller_chen))
# Out:
# Length of algo_seller_chen list (without duplicates): 491

# %% [markdown]
# ## Comparing how many Algorithmic Sellers both Ways have in Common

# %%
import pandas as pd

# Remove duplicate sellerName entries from algorithmic_sellers
unique_algorithmic_sellers = algorithmic_sellers.drop_duplicates(subset='sellerName')

# Calculate the length of the unique_algorithmic_sellers DataFrame and the algorithmic_sellers_grouped DataFrame
len_unique_algorithmic_sellers = len(unique_algorithmic_sellers)
len_algorithmic_sellers_grouped = len(algorithmic_sellers_grouped)
len_algorithmic_seller_chen = len(df_algo_seller_chen)

# Merge the DataFrames using an inner join, keeping only the common rows
common_sellers_df = unique_algorithmic_sellers.merge(algorithmic_sellers_grouped, on='sellerName', how='inner')
common_sellers_chen_unique = unique_algorithmic_sellers.merge(df_algo_seller_chen, on='sellerName', how='inner')

# Calculate the percentage of common sellers
percentage_common_sellers = (len(common_sellers_df) / min(len_unique_algorithmic_sellers, len_algorithmic_sellers_grouped)) * 100
percentage_common_seller_chen_unique = (len(common_sellers_chen_unique) / min(len_unique_algorithmic_sellers, len_algorithmic_seller_chen)) * 100
percentage_on_all_sellers = (len_unique_algorithmic_sellers / distinct_values_verkäufer) *100
print(distinct_values_verkäufer)
print(len_unique_algorithmic_sellers)

# Print the lengths of the DataFrames and the percentage of common sellers
print("Length of unique_algorithmic_sellers:", len_unique_algorithmic_sellers)
print("Length of algorithmic_sellers_grouped:", len_algorithmic_sellers_grouped)
print("Length of algortihmic_seller_chen:", len(algo_seller_chen))
print("Length of Sellers in Common:", len(common_sellers_df))
print("Percentage of common sellers:", percentage_common_sellers)
print("Percentage of common sellers Chen and Unique:", percentage_common_seller_chen_unique)
print("Percentage on all Sellers: ", percentage_on_all_sellers )
# Print the common SellerNames as a list
common_sellers_list = common_sellers_df['sellerName'].tolist()
print("\nCommon SellerNames:")
print(common_sellers_list)

# Convert the list to a pandas DataFrame
df_algorithmic_seller_names = pd.DataFrame(common_sellers_list, columns=['AlgorithmicSellerNames'])
df_algorithmic_seller_names.to_csv('df_algorithmic_seller_names.csv', index=False)
# Out:
# 2060
# 473
# Length of unique_algorithmic_sellers: 473
# Length of algorithmic_sellers_grouped: 244
# Length of algortihmic_seller_chen: 491
# Length of Sellers in Common: 188
# Percentage of common sellers: 77.04918032786885
# Percentage of common sellers Chen and Unique: 89.64059196617336
# Percentage on all Sellers:  22.961165048543688
#
# Common SellerNames:
# ['ZOXS  GmbH', 'Amazon Warehouse ', 'Solution 4YOU', 'Koffer-to-go', 'computeruniverse', 'Electronic_System', 'ACE-Deutschland', 'Happy Home Srl', 'To B To C', 'MusicScout', 'MegaMobile', 'Music and More Store', 'CW-SHOPPING', 'Kommerzpunkt', 'amazon', 'shop-lang', 'Toynova', 'WE LOVE BAGS', 'ddplus GmbH', 'Musikhaus Kirstein GmbH', 'Casa Haushalt', 'cw-mobile', 'Spiele-und-Abenteuer', 'Fashion-Home-Trend', 'Home Automation EU', 'BestArtikel GmbH', 'Modefreund', 'nox divendo', 'Amazon', 'Bambini Factory Deals', 'SIA Solution', 'REITSPORT24', 'HOH GmbH IHR FACHGESCHÄFT seit 1894 - Gratis Versand ab 29 € Deutschland', 'Arlambo', 'Expert AGD', 'Pro Lighting e.K.', 'e-joker', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 'GETIC', 'jomodo', 'Elektro4000de', 'AS-Discount', 'GetMarket', 'okluge', 'Tradomi', 'Modellauto18', 'price-guard', '4yourcar', 'LULUBUY S.A.R.L', 'Arcobaleno Centro Musicale', 'velora-shop', 'SCHREIBER + WEINERT GmbH', 'LOTT-AUTOTEILE', 'LessPaid ✅', 'ITCHECK24  --  alle Preise inkl. MwSt. - Widerrufsbelehrung + AGB unter Verkäuferhilfe', 'Miller Rock', 'Fexyshop', 'aquaristicnet Babenhausen', 'Genialpix', 'nierlecom', 'Musik Produktiv', 'Breezy Returns', 'BIT-electronix', 'inandout', 'Kaleido.Shop GmbH', 'FOTO KOESTER MUENSTER', 'Computerhandlung', 'Felex Lederwaren Gmbh  (inkl. hauseig. Reparaturservice)', 'MIOGA Warenhandel & Service GmbH', 'Cstore.', 'Bambelaa!', "Neuert's", 'GREINER GROSSHANDEL', 'Cycletronic', 'TechPoint1111', 'KsiegarniaInternetowa-de :: Spielzeug & Bücher', 'RHEINSTEIN', 'uShoppy', 'Trekking Star', 'ZOOM ICI', 'Lederoase', 'Bilvary', 'SKYLINE MEDIA', 'Computerxtreme', 'Stortle', 'Dittmeier', 'Culinaris Küchenaccessoires', 'Amitaly', 'ZAR Systems', 'Leder Heinz', 'Masskas', 'TINKERER', 'X1 Shop', 'CSL-Computer', 'InstaSpares', 'druckdichaus', 'Future-X DE', 'Kurfurst GmbH', 'E-stock Electronics', 'nrsolutions', 'geniuzcom', 'Best of Electronic', 'my mosaik', 'Batna_24', 'Toys for Fun GmbH', 'arstecnica', 'trendmile', 'ProComponentes', 'wlan-discount24', 'MiS Toys - Preise inkl. Mwst. -', 'Lieblingstasche', 'TIBERION-SHOP', 'Rasppishop', 'alyou', 'fanszone', 'GozinFur', 'Elektro Sonderposten', 'Boulevard Online', 'STILORD Leder', 'CheapSell', 'ComputerPirates DE', 'La dolce vita & World of coffee', 'Shopping Factory', 'Metall Depot', 'Dönges', 'ATP Autoteile', 'EFI Global Store DE', 'Musikbaum "Preise inkl. Mwst."', 'JTC Computer Store', 'Music-Town', 'Graphodruck', 'JACOB ⭐⭐⭐⭐⭐', 'TierXXL', 'music world brilon_', 'SD-Werkzeug', 'Löchel_Industriebedarf', 'MARKETTIAMO', 'Design Stoodio', 'bzoptical', 'hbh24online', 'DaJa-Computer GbR', 'Teknoraks GmbH', 'schulranzenwelt', 'Taschengelddieb', 'Alegree', 'spexact', 'YOURGAMES', 'RAREWAVES-DE', 'CALENDA', 'kfzteile24', 'Mai Lifestyle', 'Lapi Retail', 'BIBCASA', 'VISO TRADE', 'Ponera', 'Electro-Center', 'inkcompany', 'TOPOS', 'ai-Trading24', 'Smart Distribution Technologies', 'Pressstart', 'City Juwelier', 'Starlabels', 'MACSERVICE COMERCIO PRODUTOS INFORMATICOS LDA', 'BlumenbeckerIndustriebedarf GmbH', 'FotoBravo', 'tiendainformatica-de', 'racket-sports', 'Deltatecc GmbH', 'Nils Traumfabrik', 'TZS First E Commerce', 'Cartridge King Jersey Ltd', 'Babypower24', 'spassamdrucken', 'D-Edition e.K. (Alle Preise inkl. Mwst.)', 'MiniPrice Express SL', 'keepdrum', 'Power & Handel Vertriebs-GmbH', "Hossi's Wholesale ⭐⭐⭐⭐⭐ 100% positiv", 'IMAGEN FOTOCOLOR', 'Das älteste Spielwarengeschäft Deutschlands gegr. 1685', 'Spielwaren Schmied GmbH', 'Koberger GmbH', 'Vermegreen', 'FS Onlinehandel UG', 'edelsoft', 'nasenfahrrad24', 'füllermaus-  büchermaus']

# %% [markdown]
# ## Sellers only present in the first version or the second version

# %%
import pandas as pd

# Merge the DataFrames using an outer join, keeping the origin information in the _merge column
merged_df = algorithmic_sellers.merge(algorithmic_sellers_grouped, on='sellerName', how='outer', indicator=True)

# Filter the merged DataFrame to find sellers unique to each DataFrame
unique_sellers_algorithmic_sellers = merged_df[merged_df['_merge'] == 'left_only']
unique_sellers_algorithmic_sellers_grouped = merged_df[merged_df['_merge'] == 'right_only']

# Convert the filtered Series to lists without index
unique_sellers_list_algorithmic_sellers = unique_sellers_algorithmic_sellers['sellerName'].tolist()
unique_sellers_list_algorithmic_sellers_grouped = unique_sellers_algorithmic_sellers_grouped['sellerName'].tolist()

# Print the sellers unique to each DataFrame as lists without index
print("Sellers only present in algorithmic_sellers:")
print(unique_sellers_list_algorithmic_sellers)
print(len(unique_sellers_list_algorithmic_sellers))

print("\nSellers only present in algorithmic_sellers_grouped:")
print(unique_sellers_list_algorithmic_sellers_grouped)
print(len(unique_sellers_algorithmic_sellers_grouped))
# Out:
# Sellers only present in algorithmic_sellers:
# ['lobigo', 'Hardware-Best', 'Hardware-Best', 'Hardware-Best', 'Hardware-Best', 'Hardware-Best', 'BULUTTECH', 'CALCANEUS', 'Bauschmeisser', 'yoused  GmbH', 'yoused  GmbH', 'yoused  GmbH', 'Topbaer', 'BagsOnline', 'BagsOnline', 'BagsOnline', 'Rad & Sportkönig', 'REDIALING', 'Online-Versand-Grafenau GmbH', 'moebel-und-lifestyle', 'moebel-und-lifestyle', 'PodiumProdej', 'FINEST OF BEAUTY', 'FINEST OF BEAUTY', 'Sasaf IT', 'Sasaf IT', 'DIGITLIFE SRLS', 'DuronicEU', 'baumarktdiscount', 'baumarktdiscount', 'WEIZHI-DE', 'TechnologyONE Germany', 'TechnologyONE Germany', 'Reitsport Iris Schwarz', 'Reitsport Iris Schwarz', 'Preiswert&Gut', 'BOSSPRODUCTS', 'Dragon Kite UG', 'YESEATIS', 'sl-auktion', 'GlobalHair', 'GlobalHair', 'All-4-Baby', 'All-4-Baby', 'nice-price-webshop', 'nice-price-webshop', 'TAROMIO', 'NaturSchatulle', 'Grancei', 'Wohnkult Deko', 'Wohnkult Deko', 'SportFits', 'SportFits', 'T&T NORTH', 'TOPNET', 'TOPNET', 'TOPNET', 'TOPNET', 'RICOO-Medientechnik. Preise inkl. MwSt.', 'Medpets', 'CORTEXPOWER', 'CORTEXPOWER', 'LEICKE - Leipzig', 'Groß / Einzelhändler Rafal Otto', 'Dealzonu', 'Body & Fit Nutrition', 'Modo La e.K', 'Modo La e.K', 'nicePriceIT', 'SIDCO GmbH', 'SIDCO GmbH', 'docsmagic', 'GoodSupps', 'GoodSupps', 'extenso24', 'Meiguoduizhang', 'ricambi auto', 'ricambi auto', 'Tierzubehör Cordes', 'Tierzubehör Cordes', 'Thats Shopping GmbH', 'Thats Shopping GmbH', 'Thats Shopping GmbH', 'RaiffeisenBAUMARKT24', 'Sporting-Gifts', 'Sporting-Gifts', 'apohealth - Gesundheit aus der Apotheke', 'apohealth - Gesundheit aus der Apotheke', 'DIGITLIFE SRL', 'Sticker-und-co-de', 'ivy-electro', 'Cartvil', 'LUBA GmbH', 'LUBA GmbH', 'amzbitrage', 'amzbitrage', 'D2C ReCommerce GmbH', 'D2C ReCommerce GmbH', 'D2C ReCommerce GmbH', 'Elcom Online', 'weqsavcsdjuyh', 'Ephesus Juwelier Demirel', 'Bekureta mobile', '-uniqueplace-de-', 'RUBART GmbH', 'shanxifanjiank', 'UV-Fashions. Protectstore & JUJA', 'gomazing - bis 14:00 Versand am gleichen Tag!', 'Inateck', 'Inateck', 'Leuchten-Trends', 'Leuchten-Trends', 'Casa Due pur GmbH', 'DIES&DAS', 'MMF ENTERPRISE LTD', 'MMF ENTERPRISE LTD', 'CHENGCHUANGA', 'Looping-Lu', 'Teile-Online24', 'SCHMUCK SOTOGRANDE', 'SCHMUCK SOTOGRANDE', 'CUETO SCHMUCK (Offizieller händler)', 'BRAUN BÜFFEL', 'Organic Bargains EU', 'Heimtierbedarf Online', 'ZAIDOO - Hier zählst Du!', 'Caffè Musetti', 'Teddy Toys Kinderwelt', 'Teddy Toys Kinderwelt', 'Teddy Toys Kinderwelt', 'MYL Milano Prime 🥇', 'VOS-CONSOMMABLES 🥇🥇', 'Recordcase', 'Mipuu', 'Mipuu', 'ecanis.shop', 'ecanis.shop', 'Willer-Schuhe', 'KADAX', 'ProTrade Home&Office', 'wolfonlineshop', 'cybernerds', 'cybernerds', 'allesfurprofide', 'Oehlbach Kabel GmbH - Hersteller-Shop', 'gama-bhp', 'big-mike', 'big-mike', 'Bedsure EU', 'KW-Commerce', 'CPU Global Sales', 'avantrado.shop', 'Merkkur', 'naturzeit - kostbare Momente unter freiem Himmel. Preise inkl. MwSt.', 'FUNN-EU', 'GOK GROUPE', 'Technik-Zirkus', 'Mezken GmbH DE', 'Bilutza Shop', 'Franken-Best-Shop', 'megaprime', 'shop-tiptop', 'apominga - Die Online Apotheke in München', 'Loupas', 'RedZilla (Preise inkl. MwSt.) Impressum und AGB finden Sie unter Verkäufer-Hilfe', 'RedZilla (Preise inkl. MwSt.) Impressum und AGB finden Sie unter Verkäufer-Hilfe', 'GG Geschenke-Galerie GmbH', 'GG Geschenke-Galerie GmbH', 'teleropa', 'GreenCellPro', 'QParts24', 'QParts24', 'fairmarkt24', 'Cristallerie Locatelli', 'Totaldiscount', 'Zyxel Networks ®', 'Mediashoponline', 'Splendid Time', 'BauChemie24', 'Trend Sportiv', 'Trend Sportiv', 'Gotec Service', 'DOMO EXPERT', 'Bärendeals', 'Neuesland Preise inkl. MwSt', 'Neuesland Preise inkl. MwSt', 'favorio', 'WIMBA', 'haupteingang1', 'haupteingang1', 'Neuhaus Brillen + Hörgeräte', 'WSK-Internetservice', 'Ferreira Marques', 'Crystal4ever', 'ebg', 'Joola Tischtennis GmbH', 'Songmics', 'Songmics', 'Lens2Lens', 'Lens2Lens', 'Plutosport', 'Plutosport', 'Plutosport', 'Globsport 24', '\n                 ', 'DirectfromStarTech', 'LSE Commerce', 'KAQITEY', 'Smart7 Europe', 'Trinity ecom', 'Nesatec', 'Nesa ...
# 349
#
# Sellers only present in algorithmic_sellers_grouped:
# ['Happy Home Italia', 'Elektronik-Versand', 'Bittner Warenhandel - Preise inkl. Mwst.', 'sporttrend24', 'TM Safety Zone', 'PEARL Versandhaus', 'STILE IMMAGINE DIGITAL HD', 'Sagenta GmbH', 'Klarstein Deutschland', 'Ralf Hummel GmbH & Co. KG', 'mobilblitz', 'Reiterladen24', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 'Marken-Kaufhaus Preise inkl. MwSt.', 'DoremiStore', 'Friseurbedarf-Peters', 'Service_Windhorn', 'vollfarbdrucker-de Ihre Office Experten', 'Whooki GmbH', 'Electropolis_Online', 'kustom-kult', 'PCSPEZIALIST-BONN (AGB/Widerruf)', 'UEBilliger', 'Biffidì', 'Schwanthaler Computer', 'Olano GmbH', 'SVH Handels-GmbH', 'Montearenas', 'kiddy-hits', '1Deins Computer GmbH', 'technikbilliger', 'Voelkner', 'officeservicesrl', 'SNOGARD Computer GmbH', 'BREAKITDOWN', 'Store-Jet Elektrohandel', 'egenta', 'Foto Erhardt GmbH', 'LCD & Plasma Service GmbH', 'SPIELZEUGRIESE', 'priz24', 'Tintenwunsch', 'DASTRO ® --- Einfach. Genial. Günstig.', 'Nicotel-DE - Internet & Festnetz', 'Mickslädchen " Preis inkl. MwSt. "', 'Kraina Zabawy', 'Musik Center', 'GALADOR', 'Warenhaus Ebeling', 'tecedo', 'ELECTRONIS', 'toystoystoys', 'get goods', 'Traumpreisfabrik', 'OnlyStoresk', 'Amazon UK']
# 56
