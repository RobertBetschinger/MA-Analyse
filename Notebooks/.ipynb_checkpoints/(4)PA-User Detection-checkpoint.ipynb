# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../Grunddatein/Zwischendatein/CleanedDataCompleteNoNulls.csv')
df.info()
# Out:
# C:\Users\Robert Betschinger\AppData\Local\Temp\ipykernel_7384\1313368320.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Grunddatein/Zwischendatein/CleanedDataCompleteNoNulls.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6591111 entries, 0 to 6591110
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   id                float64
#  1   asin              object
#  2   price             float64
#  3   currency          object
#  4   time              object
#  5   crawlTime         object
#  6   condition         object
#  7   sellerName        object
#  8   sellerId          object
#  9   sellerbewertung   int64
#  10  seller_sterne     float64
#  11  lieferdatum       object
#  12  lieferpreis       float64
#  13  lieferung_durch   object
#  14  ranking           float64
#  15  buyBoxWinner      bool
#  16  numberOfSellers   float64
#  17  trigByReactive    object
#  18  Fulfillment_type  object
#  19  date_diff         float64
# dtypes: bool(1), float64(7), int64(1), object(11)
# memory usage: 961.7+ MB

# %%
## Print Basic Information about Dataframe.
#TimeFrame
df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M:%S")
# Find the max and min values for the 'time' column
max_time = df['time'].max()
min_time = df['time'].min()

print("Min value for the 'time' column:", min_time)
print("Max value for the 'time' column:", max_time)


distinct_values_verkäufer = df['sellerName'].nunique()
print(f"Es gibt insgesamt {distinct_values_verkäufer} verschiedene Verkäufer")
# Out:
# Min value for the 'time' column: 2023-03-22 16:00:00
# Max value for the 'time' column: 2023-04-23 23:00:00
# Es gibt insgesamt 2377 verschiedene Verkäufer

# %% [markdown]
# ## Generating List of asin Seller/Pairs and the Corresponding Price Changes/Observation Time

# %%
import pandas as pd
from datetime import timedelta

# Assuming your DataFrame is called df
df["time"] = pd.to_datetime(df["time"], format="%Y-%m-%d %H:%M:%S")

# First, sort the DataFrame by 'asin', 'sellerName', 'condition', 'time', and 'price'
df = df.sort_values(by=['asin', 'sellerName','condition', 'time','price'])

# Reset the index after sorting
df.reset_index(drop=True, inplace=True)

# Compute the price changes by checking if the price in the current row is different from the previous row,
# and if the sellerName is the same as in the previous row and if the condition is the same as in the previous row
# and if the time difference is exactly one hour and if there is no offer one hour earlier with the same condition and the same price from the same seller
df['price_change'] = (
    (df['price'] != df['price'].shift(1)) &
    (df['condition'] == df['condition'].shift(1)) &
    (df['sellerName'] == df['sellerName'].shift(1)) &
    (df['asin'] == df['asin'].shift(1)) &
    ((df['time'] - df['time'].shift(1)) == timedelta(hours=1)) &
    (~(
        ((df['condition'] == df['condition'].shift(1)) & (df['price'] == df['price'].shift(1)) & ((df['time'] - df['time'].shift(1)) == timedelta(hours=1)) & (df['sellerName'] == df['sellerName'].shift(1))) |
        ((df['condition'] == df['condition'].shift(2)) & (df['price'] == df['price'].shift(2)) & ((df['time'] - df['time'].shift(2)) == timedelta(hours=1)) & (df['sellerName'] == df['sellerName'].shift(2)))
    ))
).astype(int)

# Calculate the observation time for each seller-asin combination
observation_time = df.groupby(['asin', 'sellerName'])['time'].agg(['min', 'max']).reset_index()
observation_time['observation_time'] = observation_time['max'] - observation_time['min']

# Add a new column with the observation time in seconds
observation_time['observation_time_seconds'] = observation_time['observation_time'].dt.total_seconds()

# Now, group by 'asin' and 'sellerName' and sum the 'price_change' column to get the number of price changes
price_changes = df.groupby(['asin', 'sellerName'])['price_change'].sum().reset_index()

# Merge the price_changes and observation_time DataFrames
result_df = pd.merge(price_changes, observation_time[['asin', 'sellerName', 'observation_time', 'observation_time_seconds']], on=['asin', 'sellerName'])

# Convert the result to a list of tuples
result = list(result_df.itertuples(index=False, name=None))

# Print the result
for x in result:
    print(x)
# Out:
# ('B00000JD6K', 'Kidia', 139, Timedelta('25 days 17:00:00'), 2221200.0)
# ('B00000JD6K', 'STILE IMMAGINE DIGITAL HD', 0, Timedelta('29 days 02:00:00'), 2512800.0)
# ('B00005KIRS', 'Amazon Warehouse ', 191, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00005KIRS', 'Arlambo', 144, Timedelta('13 days 19:00:00'), 1191600.0)
# ('B00005KIRS', 'Cernovia', 0, Timedelta('31 days 15:00:00'), 2732400.0)
# ('B00005KIRS', 'ComSternde', 0, Timedelta('22 days 18:00:00'), 1965600.0)
# ('B00005KIRS', 'Crystal4ever', 118, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00005KIRS', 'DASTRO ® --- Einfach. Genial. Günstig.', 0, Timedelta('31 days 15:00:00'), 2732400.0)
# ('B00005KIRS', 'Electronic XXL Sachsen', 0, Timedelta('30 days 05:00:00'), 2610000.0)
# ('B00005KIRS', 'GREINER GROSSHANDEL', 168, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00005KIRS', 'Kaleido.Shop GmbH', 180, Timedelta('31 days 19:00:00'), 2746800.0)
# ('B00005KIRS', 'Technikprimus', 0, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00005KIRS', 'amazon', 198, Timedelta('32 days 02:00:00'), 2772000.0)
# ('B00005KIRS', 'e-joker', 117, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00005KIRS', 'eibabo Deutschland', 0, Timedelta('20 days 07:00:00'), 1753200.0)
# ('B00005KIRS', 'eibmarkt', 0, Timedelta('0 days 01:00:00'), 3600.0)
# ('B00005KIRS', 'inandout', 169, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00008K61M', '1A-Elektronik', 0, Timedelta('29 days 22:00:00'), 2584800.0)
# ('B00008K61M', 'ABC-Schnäppchenmarkt GmbH', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61M', 'ARDEBO', 0, Timedelta('21 days 08:00:00'), 1843200.0)
# ('B00008K61M', 'AS-Discount', 43, Timedelta('26 days 00:00:00'), 2246400.0)
# ('B00008K61M', 'CW-SHOPPING', 93, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B00008K61M', 'Casa Haushalt', 109, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B00008K61M', 'Cernovia', 0, Timedelta('17 days 03:00:00'), 1479600.0)
# ('B00008K61M', 'DaJa-Computer GbR', 8, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00008K61M', 'Deltatecc GmbH', 6, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61M', 'EFI Global Store DE', 2, Timedelta('31 days 04:00:00'), 2692800.0)
# ('B00008K61M', 'ETOH24', 0, Timedelta('31 days 17:00:00'), 2739600.0)
# ('B00008K61M', 'EURONICS XXL Vilshofen', 0, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00008K61M', 'Elektro4000de', 236, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B00008K61M', 'Elektronik-Versand', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61M', 'EliXito', 2, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B00008K61M', 'GREINER GROSSHANDEL', 151, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B00008K61M', "GlobaPlex | Produkte für's Herz", 5, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B00008K61M', 'Happy Home Srl', 0, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B
 'Sotel (AGB und Garantiebestimmungen siehe hier)', 4, Timedelta('26 days 22:00:00'), 2325600.0)
# ('B00008K61N', 'Spiele-und-Abenteuer', 0, Timedelta('22 days 01:00:00'), 1904400.0)
# ('B00008K61N', 'Stortle', 67, Timedelta('13 days 16:00:00'), 1180800.0)
# ('B00008K61N', 'TECMONDO', 0, Timedelta('26 days 20:00:00'), 2318400.0)
# ('B00008K61N', 'TRIPPODO EU', 0, Timedelta('0 days 21:00:00'), 75600.0)
# ('B00008K61N', 'UEBilliger', 1, Timedelta('30 days 21:00:00'), 2667600.0)
# ('B00008K61N', 'Yeppon', 0, Timedelta('27 days 03:00:00'), 2343600.0)
# ('B00008K61N', 'ZOOM ICI', 6, Timedelta('26 days 21:00:00'), 2322000.0)
# ('B00008K61N', 'amazon', 202, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'computeruniverse', 239, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'e-joker', 123, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'elektrotresen', 0, Timedelta('19 days 21:00:00'), 1717200.0)
# ('B00008K61N', 'inandout', 49, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B00008K61N', 'kaijott', 6, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 105, Timedelta('26 days 09:00:00'), 2278800.0)
# ('B00008K61N', 'nox divendo', 121, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'petdear', 0, Timedelta('5 days 18:00:00'), 496800.0)
# ('B00008K61N', 'price-guard', 2, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B00008K61N', 'priz24', 0, Timedelta('18 days 03:00:00'), 1566000.0)
# ('B00008K61N', 'technikgross', 0, Timedelta('30 days 21:00:00'), 2667600.0)
# ('B000095Z2Z', 'Best of Electronic', 25, Timedelta('3 days 06:00:00'), 280800.0)
# ('B000095Z2Z', 'Sellixx. Preise inkl. MwSt', 0, Timedelta('0 days 18:00:00'), 64800.0)
# ('B0000C72GD', 'STILE IMMAGINE DIGITAL HD', 4, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000D85OD', 'Happy Home Italia', 0, Timedelta('30 days 12:00:00'), 2635200.0)
# ('B0000D85OD', 'Happy Home Srl', 147, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B0000D85OD', 'KupZarovky', 8, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B0000D85OD', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 3, Timedelta('22 days 19:00:00'), 1969200.0)
# ('B0000D85OD', 'Walwes Europe', 0, Timedelta('0 days 01:00:00'), 3600.0)
# ('B0000D85OD', 'amazon', 155, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B0000WOK04', 'AS-Discount', 170, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK04', 'BWBahn', 0, Timedelta('15 days 20:00:00'), 1368000.0)
# ('B0000WOK04', 'Conrad Electronic SE', 1, Timedelta('31 days 12:00:00'), 2721600.0)
# ('B0000WOK04', 'JACOB ⭐⭐⭐⭐⭐', 28, Timedelta('4 days 14:00:00'), 396000.0)
# ('B0000WOK04', 'Modellbau-Braeuer', 0, Timedelta('31 days 12:00:00'), 2721600.0)
# ('B0000WOK04', 'Neuesland Preise inkl. MwSt', 190, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK04', 'Railroad 2000', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK04', 'SMDV', 0, Timedelta('31 days 12:00:00'), 2721600.0)
# ('B0000WOK04', 'amazon', 191, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK04', 'get goods', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK04', 'muddukaufen_Sammelwelt', 0, Timedelta('28 days 10:00:00'), 2455200.0)
# ('B0000WOK9A', 'AS-Discount', 89, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0000WOK9A', 'Amazon Warehouse ', 41, Timedelta('19 days 12:00:00'), 1684800.0)
# ('B0000WOK9A', 'BWBahn', 2, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B
 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'ARDEBO', 39, Timedelta('32 days 05:00:00'), 2782800.0)
# ('B0002HOS7M', 'Belion-World', 22, Timedelta('31 days 15:00:00'), 2732400.0)
# ('B0002HOS7M', 'Casa Haushalt', 357, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'Deltatecc GmbH', 8, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'ETOH24', 0, Timedelta('31 days 15:00:00'), 2732400.0)
# ('B0002HOS7M', 'EURONICS XXL Vilshofen', 0, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'Electro-Center', 188, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'Elektronik-Versand', 12, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'EliXito', 2, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'Fashion-Home-Trend', 515, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'GREINER GROSSHANDEL', 170, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'Happy Home Srl', 17, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'Kaleido.Shop GmbH', 200, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'Kommerzpunkt', 11, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HOS7M', 'MIOGA Warenhandel & Service GmbH', 29, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'MassaMarkt B.V.', 27, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'Masskas', 22, Timedelta('32 days 05:00:00'), 2782800.0)
# ('B0002HOS7M', 'Power & Handel Vertriebs-GmbH', 85, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'SchönerDaheim', 0, Timedelta('25 days 13:00:00'), 2206800.0)
# ('B0002HOS7M', 'Spiele-und-Abenteuer', 3, Timedelta('31 days 19:00:00'), 2746800.0)
# ('B0002HOS7M', 'UEBilliger', 1, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HOS7M', 'Wohn-Idee24', 2, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HOS7M', 'amazon', 200, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'computeruniverse', 378, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'deine-traumfabrik', 3, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HOS7M', 'elektrotresen', 0, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HOS7M', 'inandout', 73, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'ksw-shop', 0, Timedelta('30 days 00:00:00'), 2592000.0)
# ('B0002HOS7M', 'price-guard', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HOS7M', 'tecedo', 0, Timedelta('32 days 06:00:00'), 2786400.0)
# ('B0002HOS7M', 'technikgross', 0, Timedelta('31 days 13:00:00'), 2725200.0)
# ('B0002HP91Q', '1Deins Computer GmbH', 0, Timedelta('29 days 04:00:00'), 2520000.0)
# ('B0002HP91Q', 'AS-Discount', 3, Timedelta('32 days 00:00:00'), 2764800.0)
# ('B0002HP91Q', 'Casa Haushalt', 57, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'Cernovia', 0, Timedelta('30 days 18:00:00'), 2656800.0)
# ('B0002HP91Q', 'Culinaris Küchenaccessoires', 46, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'DASTRO ® --- Einfach. Genial. Günstig.', 0, Timedelta('31 days 14:00:00'), 2728800.0)
# ('B0002HP91Q', 'DaJa-Computer GbR', 11, Timedelta('30 days 14:00:00'), 2642400.0)
# ('B0002HP91Q', 'Deltatecc GmbH', 1, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'E-Mistero', 5, Timedelta('25 days 00:00:00'), 2160000.0)
# ('B0002HP91Q', 'ETOH24', 0, Timedelta('31 days 14:00:00'), 2728800.0)
# ('B0002HP91Q', 'EURONICS XXL Vilshofen', 0, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'Elektro4000de', 48, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'Elektronik-Versand', 0, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'EliXito', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'GREINER GROSSHANDEL', 14, Timedelta('32 days 00:00:00'), 2764800.0)
# ('B0002HP91Q', 'Graphodruck', 50, Timedelta('23 days 10:00:00'), 2023200.0)
# ('B0002HP91Q', 'Happy Home Srl', 73, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'Hitech Online', 0, Timedelta('10 days 22:00:00'), 943200.0)
# ('B0002HP91Q', 'JACOB ⭐⭐⭐⭐⭐', 2, Timedelta('1 days 10:00:00'), 122400.0)
# ('B0002HP91Q', 'Kaleido.Shop GmbH', 9, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'Kommerzpunkt', 3, Timedelta('31 days 18:00:00'), 2743200.0)
# ('B0002HP91Q', 'Kurfurst GmbH', 4, Timedelta('24 days 23:00:00'), 2156400.0)
# ('B0002HP91Q', 'MIOGA Warenhandel & Service GmbH', 38, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'Millennium Star', 0, Timedelta('0 days 00:00:00'), 0.0)
# ('B0002HP91Q', 'Olano GmbH', 8, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'Shopping4u-24', 1, Timedelta('7 days 02:00:00'), 612000.0)
# ('B0002HP91Q', 'Sotel (AGB und Garantiebestimmungen siehe hier)', 1, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'Stortle', 28, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0002HP91Q', 'Technikprimus', 1, Timedelta('32 days 00:00:00'), 2764800.0)
# ('B0002HP91Q', 'Traumpreisfabrik', 0, Timedelta('31 days 18:00:00'), 2743200.0)
# ('B0002HP91Q', 'UEBilliger', 1, Timedelta('31 days 05:00:00'), 2696400.0)
# ('B0002HP91Q', 'Voelkner', 0, Timedelta('28 days 05:00:00'), 2437200.0)
# ('B0002HP91Q', 'Wohn-Idee24', 0, Timedelta('31 days 14:00:00'), 2728800.0)
# ('B0002HP91Q', 'Yeppon', 0, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'amazon', 131, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'computeruniverse', 611, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'deine-traumfabrik', 1, Timedelta('31 days 14:00:00'), 2728800.0)
# ('B0002HP91Q', 'e-joker', 27, Timedelta('7 days 13:00:00'), 651600.0)
# ('B0002HP91Q', 'elektricworld24', 0, Timedelta('9 days 09:00:00'), 810000.0)
# ('B0002HP91Q', 'get goods', 38, Timedelta('29 days 11:00:00'), 2545200.0)
# ('B0002HP91Q', 'hbh24online', 0, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'inandout', 7, Timedelta('32 days 00:00:00'), 2764800.0)
# ('B0002HP91Q', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 56, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'nierlecom', 29, Timedelta('20 days 22:00:00'), 1807200.0)
# ('B0002HP91Q', 'nox divendo', 10, Timedelta('1 days 12:00:00'), 129600.0)
# ('B0002HP91Q', 'price-guard', 0, Timedelta('32 days 03:00:00'), 2775600.0)
# ('B0002HP91Q', 'priz24', 0, Timedelta('31 days 05:00:00'), 2696400.0)
# ('B0002HP91Q', 'shoppingpoint24', 67, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'spiessxxl', 0, Timedelta('31 days 05:00:00'), 2696400.0)
# ('B0002HP91Q', 'tecedo', 0, Timedelta('31 days 23:00:00'), 2761200.0)
# ('B0002HP91Q', 'technikgross', 0, Timedelta('31 days 02:00:00'), 2685600.0)
Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC5SFDH', 'Marken-Koffer', 1, Timedelta('6 days 01:00:00'), 522000.0)
# ('B0BLC5SFDH', 'Nils Traumfabrik', 103, Timedelta('15 days 10:00:00'), 1332000.0)
# ('B0BLC5SFDH', 'Picher Spiel und Sport', 0, Timedelta('13 days 13:00:00'), 1170000.0)
# ('B0BLC5SFDH', 'Pippi-Lotta-Kinderschuhe', 0, Timedelta('28 days 21:00:00'), 2494800.0)
# ('B0BLC5SFDH', 'Ranzenfee & Koffertroll GmbH', 0, Timedelta('31 days 20:00:00'), 2750400.0)
# ('B0BLC5SFDH', 'Ranzenlager', 0, Timedelta('30 days 21:00:00'), 2667600.0)
# ('B0BLC5SFDH', 'Schreibdesign', 0, Timedelta('30 days 09:00:00'), 2624400.0)
# ('B0BLC5SFDH', 'Schuhe24', 3, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC5SFDH', 'Schulsachen-de', 1, Timedelta('4 days 08:00:00'), 374400.0)
# ('B0BLC5SFDH', 'Southbag - Schulranzen | Rucksäcke | Koffer', 0, Timedelta('30 days 23:00:00'), 2674800.0)
# ('B0BLC5SFDH', 'TOP TWO GmbH', 0, Timedelta('31 days 20:00:00'), 2750400.0)
# ('B0BLC5SFDH', 'Taschenfreund Werl', 0, Timedelta('30 days 09:00:00'), 2624400.0)
# ('B0BLC5SFDH', 'Taschenjuwel', 13, Timedelta('5 days 02:00:00'), 439200.0)
# ('B0BLC5SFDH', 'Toys for Fun GmbH', 31, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B0BLC5SFDH', 'WE LOVE BAGS', 65, Timedelta('13 days 02:00:00'), 1130400.0)
# ('B0BLC5SFDH', 'Zierleyn GmbH & Co. KG', 0, Timedelta('29 days 11:00:00'), 2545200.0)
# ('B0BLC5SFDH', 'duo schreib & spiel Markenshop', 3, Timedelta('31 days 17:00:00'), 2739600.0)
# ('B0BLC5SFDH', 'flac Shop', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC5SFDH', 'kiddy-hits', 76, Timedelta('32 days 04:00:00'), 2779200.0)
# ('B0BLC5SFDH', 'kieskemper1928', 0, Timedelta('29 days 11:00:00'), 2545200.0)
# ('B0BLC5SFDH', 'modeherz \'Alle Preise inkl. Mwst.\'""', 4, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC5SFDH', 'myToys-de GmbH', 4, Timedelta('4 days 19:00:00'), 414000.0)
# ('B0BLC5SFDH', 'schulranzenwelt', 4, Timedelta('31 days 03:00:00'), 2689200.0)
# ('B0BLC72XV3', 'BagsOnline', 98, Timedelta('32 days 05:00:00'), 2782800.0)
# ('B0BLC72XV3', 'City Kauf GmbH', 5, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC72XV3', 'DER BREU', 14, Timedelta('24 days 21:00:00'), 2149200.0)
# ('B0BLC72XV3', 'DSBO', 7, Timedelta('8 days 09:00:00'), 723600.0)
# ('B0BLC72XV3', 'FOND OF', 0, Timedelta('32 days 07:00:00'), 2790000.0)
# ('B0BLC72XV3', 'HAUSFELDER accessoires + reise', 48, Timedelta('26 days 18:00:00'), 2311200.0)
# ('B0BLC72XV3', 'Ideen von A - Z', 8, Timedelta('25 days 01:00:00'), 2163600.0)
# ('B0BLC72XV3', 'K-Line Taschendesign', 0, Timedelta('1 days 22:00:00'), 165600.0)
# ('B0BLC72XV3', 'Koffer-to-go', 135, Timedelta('19 days 08:00:00'), 1670400.0)
# ('B0BLC72XV3', 'Kofferworld', 5, Timedelta('12 days 01:00:00'), 1040400.0)
# ('B0BLC72XV3', 'Leder Heinz', 143, Timedelta('27 days 00:00:00'), 2332800.0)
Timedelta('32 days 05:00:00'), 2782800.0)
# ('B0BNC8RXH1', 'bücher-de', 0, Timedelta('12 days 12:00:00'), 1080000.0)
# ('B0BNC8RXH1', 'e-joker', 86, Timedelta('28 days 15:00:00'), 2473200.0)
# ('B0BNC8RXH1', 'easy-shop-express', 25, Timedelta('32 days 00:00:00'), 2764800.0)
# ('B0BNC8RXH1', 'hugendubel-de', 0, Timedelta('2 days 00:00:00'), 172800.0)
# ('B0BNC8RXH1', 'ms-plueth', 0, Timedelta('32 days 05:00:00'), 2782800.0)
# ('B0BNC8RXH1', 'myHobby24 | Ihr Freizeitspezialist für Deutschland', 30, Timedelta('21 days 15:00:00'), 1868400.0)
# ('B0BNC8RXH1', 'trendmile', 211, Timedelta('32 days 04:00:00'), 2779200.0)

# %% [markdown]
# ## Actual Calculation if a seller is algorithmic

# %%
print(len(result))
# Out:
# 14738

# %%
multiply_factor = 1.0

# %%
# Convert the result list to a DataFrame
result_df = pd.DataFrame(result, columns=['asin', 'sellerName', 'num_price_changes', 'observation_time','observation_time_seconds'])

# Convert observation time from seconds to hours
result_df['observation_time_hours'] = result_df['observation_time_seconds'] / 3600

# Calculate the price changes per hour
result_df['price_changes_per_hour'] = result_df['num_price_changes'] / result_df['observation_time_hours']

# Replace infinite values with NaN
result_df['price_changes_per_hour'] = result_df['price_changes_per_hour'].replace([np.inf, -np.inf], np.nan)

# Calculate the median of non-infinite and non-missing values
median_price_changes = result_df['price_changes_per_hour'].dropna().median()

# Replace missing and infinite values with the median
result_df['price_changes_per_hour'] = result_df['price_changes_per_hour'].fillna(median_price_changes)

# Calculate the mean and standard deviation
mean_price_changes = result_df['price_changes_per_hour'].mean()
std_price_changes = result_df['price_changes_per_hour'].std()

print("Mean price changes per hour:", mean_price_changes)
print("Standard deviation of price changes per hour:", std_price_changes)

# Set a threshold for classifying sellers as algorithmic
# For example, we can set the threshold as mean + 2 * std, which will classify approximately 2.5% of sellers as algorithmic
threshold = mean_price_changes + multiply_factor * std_price_changes
print("Threshold:", threshold)

# Add a column to the result DataFrame indicating whether the seller is algorithmic
result_df['is_algorithmic'] = result_df['price_changes_per_hour'] > threshold

# Sort the algorithmic seller pairs by price changes per hour
algorithmic_seller_pairs = result_df[result_df['is_algorithmic']].sort_values(by='price_changes_per_hour', ascending=False)

# Get the names of algorithmic sellers
algorithmic_seller_names = algorithmic_seller_pairs['sellerName'].unique()

# Filter the result DataFrame to include only non-algorithmic sellers
non_algorithmic_seller_pairs = result_df[~result_df['sellerName'].isin(algorithmic_seller_names)]

# Combine the algorithmic and non-algorithmic seller pairs
final_result = pd.concat([algorithmic_seller_pairs, non_algorithmic_seller_pairs], ignore_index=True)


###########################################################################################################
# Get the names of algorithmic sellers
algorithmic_seller_names = result_df[result_df['is_algorithmic']]['sellerName'].unique()

# Add a new column 'algorithmic_second' and set its default value to False
result_df['algorithmic_second'] = False

# Identify the seller pairs which are not algorithmic yet but their seller names are in the algorithmic seller names list
second_algorithmic_condition = (~result_df['is_algorithmic']) & (result_df['sellerName'].isin(algorithmic_seller_names))

# Mark these pairs as 'algorithmic_second'
result_df.loc[second_algorithmic_condition, 'algorithmic_second'] = True
# Out:
# Mean price changes per hour: 0.06790070152020158
# Standard deviation of price changes per hour: 0.11614839993296
# Threshold: 0.18404910145316158

# %%
# Count the number of entries where algorithmic_second is true
algorithmic_second_true_count = result_df[result_df['algorithmic_second'] == True].shape[0]

# Count the number of entries where is_algorithmic is true
is_algorithmic_true_count = result_df[result_df['is_algorithmic'] == True].shape[0]

# Count the number of entries where is_algorithmic is false
is_algorithmic_false_count = result_df[result_df['is_algorithmic'] == False].shape[0]

# Print the counts
print(multiply_factor)
print("Number of entries where algorithmic_second is true:", algorithmic_second_true_count + is_algorithmic_true_count)
print("Number of entries where is_algorithmic is true:", is_algorithmic_true_count)
print("Number of entries where is_algorithmic is false:", is_algorithmic_false_count)
print("Summe",is_algorithmic_false_count+is_algorithmic_true_count == 14738)
# Out:
# 1.0
# Number of entries where algorithmic_second is true: 5874
# Number of entries where is_algorithmic is true: 2582
# Number of entries where is_algorithmic is false: 12156
# Summe True

# %%
# Filter the DataFrame to include only the algorithmic sellers
algorithmic_sellers = final_result[final_result['is_algorithmic']]

# Get the unique seller names
unique_algorithmic_sellers = algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_algorithmic_sellers = len(unique_algorithmic_sellers)

# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers)
#print("Unique algorithmic seller names:")
#for seller_name in unique_algorithmic_sellers:
    #print(seller_name)
# Filter the DataFrame to include only the non-algorithmic sellers
non_algorithmic_sellers = final_result[~final_result['is_algorithmic']]

# Get the unique seller names
unique_non_algorithmic_sellers = non_algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_non_algorithmic_sellers = len(unique_non_algorithmic_sellers)
# Print the result
print("Number of unique non algorithmic sellers:", num_non_algorithmic_sellers,"of a total of ",distinct_values_verkäufer)
# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers,"of a total of ",distinct_values_verkäufer)
# Out:
# Number of unique algorithmic sellers: 628
# Number of unique non algorithmic sellers: 1749 of a total of  2377
# Number of unique algorithmic sellers: 628 of a total of  2377

# %%
# Filter the DataFrame to include only the algorithmic sellers
algorithmic_sellers = final_result[final_result['is_algorithmic']]

# Get the unique seller names
unique_algorithmic_sellers = algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_algorithmic_sellers = len(unique_algorithmic_sellers)

# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers)
#print("Unique algorithmic seller names:")
#for seller_name in unique_algorithmic_sellers:
    #print(seller_name)
# Filter the DataFrame to include only the non-algorithmic sellers
non_algorithmic_sellers = final_result[~final_result['is_algorithmic']]

# Get the unique seller names
unique_non_algorithmic_sellers = non_algorithmic_sellers['sellerName'].unique()

# Count the number of unique sellers by seller name
num_non_algorithmic_sellers = len(unique_non_algorithmic_sellers)
# Print the result
print("Number of unique non algorithmic sellers:", num_non_algorithmic_sellers,"of a total of ",distinct_values_verkäufer)
# Print the result
print("Number of unique algorithmic sellers:", num_algorithmic_sellers,"of a total of",distinct_values_verkäufer)
# Out:
# Number of unique algorithmic sellers: 628
# Number of unique non algorithmic sellers: 1749 of a total of  2377
# Number of unique algorithmic sellers: 628 of a total of 2377

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.hist(result_df['num_price_changes'], bins=30, density=True, alpha=0.6, color='g')
plt.axvline(x=mean_price_changes, color='red', linestyle='--')  # mean
plt.axvline(x=mean_price_changes + std_price_changes, color='blue', linestyle='--')  # 1 SD
plt.axvline(x=mean_price_changes - std_price_changes, color='blue', linestyle='--')  # -1 SD
plt.show()


plt.boxplot(result_df['num_price_changes'])
plt.show()

sns.violinplot(x=result_df['num_price_changes'])
plt.show()

sns.kdeplot(result_df['num_price_changes'])
plt.axvline(x=mean_price_changes, color='red', linestyle='--')  # mean
plt.axvline(x=mean_price_changes + std_price_changes, color='blue', linestyle='--')  # 1 SD
plt.axvline(x=mean_price_changes + 1.5*std_price_changes, color='red', linestyle='--')  # -1 SD
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# CDF of the number of total price changes
sns.ecdfplot(data=result_df, x='num_price_changes')
plt.axvline(x=mean_price_changes, color='red', linestyle='--')  # 1 SD
plt.axvline(x=mean_price_changes + std_price_changes, color='red', linestyle='-.')  # 2 SD
plt.axvline(x=mean_price_changes + 2*std_price_changes, color='red')  # 3 SD
plt.title('CDF of Number of Total Price Changes')
plt.show()

# %%
import matplotlib.patches as mpatches

# CDF of the number of total price changes
sns.ecdfplot(data=result_df, x="price_changes_per_hour")

mean_line = plt.axvline(x=mean_price_changes, color='red')
sd1_line = plt.axvline(x=mean_price_changes + std_price_changes, color='blue', linestyle='-.')
sd15_line = plt.axvline(x=mean_price_changes + 1.5*std_price_changes, color='green', linestyle='-.')  # 1.5 SD
sd2_line = plt.axvline(x=mean_price_changes + 2*std_price_changes, color='red', linestyle='-.')  # 2 SD
sd3_line = plt.axvline(x=mean_price_changes + 3*std_price_changes, color='red',linestyle='--')  # 3 SD

# Create a legend
red_patch = mpatches.Patch(color='red', label='Mean')
blue_patch = mpatches.Patch(color='blue', label='+1 SD')
green_patch = mpatches.Patch(color='green', label='+1.5 SD')
red_dashed_patch = mpatches.Patch(color='red', linestyle='-.', label='+2 SD')
red_solid_patch = mpatches.Patch(color='red', label='+3 SD')

plt.legend(handles=[red_patch, blue_patch, green_patch, red_dashed_patch, red_solid_patch])

plt.title('CDF of Number of Total Price Changes')

# Save the plot
plt.savefig('cdf_price_changes.png')

plt.show()

###Gradienten Berechnung

# %% [markdown]
# ## Chen Method with simple numberic Treshhold

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14738 entries, 0 to 14737
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   asin                      14738 non-null  object
#  1   sellerName                14738 non-null  object
#  2   num_price_changes         14738 non-null  int64
#  3   observation_time          14738 non-null  timedelta64[ns]
#  4   observation_time_seconds  14738 non-null  float64
#  5   observation_time_hours    14738 non-null  float64
#  6   price_changes_per_hour    14738 non-null  float64
#  7   is_algorithmic            14738 non-null  bool
#  8   algorithmic_second        14738 non-null  bool
# dtypes: bool(2), float64(3), int64(1), object(2), timedelta64[ns](1)
# memory usage: 834.9+ KB

# %%
threshold_exceeded_count = 0
seller_names_list = []
treshhold_second_count = 0
for tup in result:
    number_of_price_changes = tup[2]
    if number_of_price_changes > 64:
        threshold_exceeded_count += 1
        seller_names_list.append(tup[1])
        
for tup in result:
    if tup[1] in seller_names_list:
         treshhold_second_count += 1
        

print("Number of rows where the threshold is exceeded:", threshold_exceeded_count)
print("Length of the seller names List", len(seller_names_list))
print("Number of ASIN/Seller Pairs where the treshold is exceeded or for an other Pair of the Seller is exceeded",treshhold_second_count)
print("Non Algo Pairs", len(result)-len(seller_names_list))
# Out:
# Number of rows where the threshold is exceeded: 3539
# Length of the seller names List 3539
# Number of ASIN/Seller Pairs where the treshold is exceeded or for an other Pair of the Seller is exceeded 6718
# Non Algo Pairs 11199

# %%
algo_seller_chen = []

for tup in result:
    number_of_price_changes = tup[2]
    sellerName = tup[1]
    if number_of_price_changes > 64:
        #print(tup)
        algo_seller_chen.append(sellerName)

# Remove duplicates by converting the list to a set and then back to a list
algo_seller_chen = list(set(algo_seller_chen))
# Transform the list into a DataFrame
df_algo_seller_chen = pd.DataFrame(algo_seller_chen, columns=['sellerName'])

print("Length of algo_seller_chen list (without duplicates):", len(df_algo_seller_chen))
# Out:
# Length of algo_seller_chen list (without duplicates): 709

# %% [markdown]
# ## Comparing how many Algorithmic Sellers both Ways have in Common

# %%
import pandas as pd

# Remove duplicate sellerName entries from algorithmic_sellers
unique_algorithmic_sellers = algorithmic_sellers.drop_duplicates(subset='sellerName')

# Calculate the length of the unique_algorithmic_sellers DataFrame and the algorithmic_sellers_grouped DataFrame
len_unique_algorithmic_sellers = len(unique_algorithmic_sellers)
len_algorithmic_seller_chen = len(df_algo_seller_chen)

# Merge the DataFrames using an inner join, keeping only the common rows

common_sellers_chen_unique = unique_algorithmic_sellers.merge(df_algo_seller_chen, on='sellerName', how='inner')

# Calculate the percentage of common sellers
percentage_common_seller_chen_unique = (len(common_sellers_chen_unique) / min(len_unique_algorithmic_sellers, len_algorithmic_seller_chen)) * 100
percentage_on_all_sellers = (len(common_sellers_chen_unique) / distinct_values_verkäufer) *100
print(f"Total Number of Sellers:", distinct_values_verkäufer)


# Print the lengths of the DataFrames and the percentage of common sellers
print("1: Length of unique_algorithmic_sellers:", len_unique_algorithmic_sellers)
print("3: Length of algortihmic_seller_chen:", len(algo_seller_chen))
print("Percentage of common sellers 1 and 3:", percentage_common_seller_chen_unique)
print("Percentage on all Sellers: ", percentage_on_all_sellers )


# Print the common SellerNames as a list
common_sellers_list = common_sellers_chen_unique['sellerName'].tolist()
#print("\nCommon SellerNames:")
#print(common_sellers_list)
print("Common Sellers Count",len(common_sellers_list))

# Convert the list to a pandas DataFrame
df_algorithmic_seller_names = pd.DataFrame(common_sellers_list, columns=['AlgorithmicSellerNames'])
df_algorithmic_seller_names.to_csv('../Grunddatein/Zwischendatein/PA-Adopters.csv', index=False)
# Out:
# Total Number of Sellers: 2377
# 1: Length of unique_algorithmic_sellers: 628
# 3: Length of algortihmic_seller_chen: 709
# Percentage of common sellers 1 and 3: 92.35668789808918
# Percentage on all Sellers:  24.400504838031132
# Common Sellers Count 580

# %% [markdown]
# ###
