# %% [markdown]
# ## Buy Box Datenanalyse

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../Grunddatein/Zwischendatein/CleanedDataComplete.csv')
# Out:
# C:\Users\Robert Betschinger\AppData\Local\Temp\ipykernel_13156\3459770669.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Grunddatein/Zwischendatein/CleanedDataComplete.csv')

# %%
df.head()
# Out:
#          id        asin   price currency                 time  \
# 0  341698.0  B001R4BR1O   52.43        €  2023-03-22 16:00:00
# 1  341712.0  B0062VH4NM   40.84        €  2023-03-22 16:00:00
# 2  341803.0  B07T9MTJHM   57.12        €  2023-03-22 16:00:00
# 3  341833.0  B00SWI2UK0   70.71        €  2023-03-22 16:00:00
# 4  341851.0  B01LXFCIGP  153.94        €  2023-03-22 16:00:00
#
#                     crawlTime condition                    sellerName  \
# 0  2023-03-22 16:54:19.532185       New                        amazon
# 1  2023-03-22 16:54:19.541368       New           WSK-Internetservice
# 2  2023-03-22 16:54:19.592193       New                  BOSSPRODUCTS
# 3  2023-03-22 16:54:19.610406       New  PRIVIX® (Preise inkl. MwSt.)
# 4  2023-03-22 16:54:19.620842       New                        amazon
#
#          sellerId  sellerbewertung  seller_sterne         lieferdatum  \
# 0          amazon          4211.00            5.0  Saturday. March 25
# 1  A3ORTHHJUBAXI7           404.74            5.0  Saturday. March 25
# 2   A1FKQ4E0L7V4I           704.00            5.0  Saturday. March 25
# 3  A26GYXB1OSGPR3          1413.12            5.0  Saturday. March 25
# 4          amazon              NaN            NaN  Saturday. March 25
#
#    lieferpreis lieferung_durch  ranking  buyBoxWinner  numberOfSellers  \
# 0          0.0          Amazon      0.0          True             11.0
# 1          0.0          Amazon      0.0          True              3.0
# 2          0.0          Amazon      0.0          True              3.0
# 3          0.0          Amazon      0.0          True             40.0
# 4          0.0          Amazon      0.0          True             18.0
#
#   trigByReactive Fulfillment_type  date_diff
# 0              f              FBA        2.0
# 1              f              FBA        7.0
# 2              f              FBA        4.0
# 3              f              FBA        2.0
# 4              f              FBA        2.0

# %%
df.rename(columns={
    'lieferpreis': 'delivery_price',
    'seller_sterne': 'seller_stars',
    'sellerbewertung': 'seller_rating',
    'date_diff': 'delivery_time',
    'numberOfSellers': 'number_of_competing_offers'
}, inplace=True)

# %%
boxplot_columns = ['price', 'seller_stars', 'seller_rating', 'number_of_competing_offers','delivery_price','delivery_time']
import seaborn as sns

def plot_boxplots_2_columns(df, columns, save_path, figsize=(14, 14)):
    nrows = (len(columns) + 1) // 2
    fig, axs = plt.subplots(nrows=nrows, ncols=2, figsize=figsize)
    
    for ax, column in zip(axs.flatten(), columns):
        sns.boxplot(data=df, y=column, ax=ax)
        ax.set_title(f'Box Plot of {column}')
    
    # Remove any unused subplots
    for i in range(len(columns), nrows * 2):
        fig.delaxes(axs.flatten()[i])

    plt.tight_layout()
    plt.savefig(save_path, dpi=300)
    plt.show()

# Call the plot_boxplots_2_columns function with the specified columns
plot_boxplots_2_columns(df, boxplot_columns, save_path='boxplots_2_columns.png')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def plot_histograms(df, columns, bins=10, figsize=(20, 20), log_scale=False, save_path='histograms.png'):
    fig, axs = plt.subplots(nrows=len(columns), figsize=figsize)
    for ax, column in zip(axs, columns):
        if log_scale:
            df[column].plot(ax=ax, kind='hist', bins=bins, log=True)
        else:
            df[column].plot(ax=ax, kind='hist', bins=bins)
        ax.set_title(f'Histogram of {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)  # Save the plot as an image file
    plt.show()

# List the columns you want to plot histograms for
columns = ['price', 'delivery_price', 'seller_stars', 'seller_rating', 'delivery_time', 'number_of_competing_offers', 'ranking']

# Call the function with the desired columns and specify the file name for the image output
plot_histograms(df, columns, bins=50, log_scale=True, save_path='histogramsAsuwahl.png')

# %%
def plot_combined_histograms_dual_axes(df, columns, bins=50, figsize=(14, 7), save_path='combined_histograms_dual_axes.png', filter_condition=None, custom_titles=None, custom_colors=None):
    if filter_condition is not None:
        df = df[filter_condition]

    nrows = len(columns)

    fig, axs = plt.subplots(nrows=nrows, figsize=figsize)

    for ax, column in zip(axs, columns):
        ax2 = ax.twinx()
        fulfillment_types = list(custom_colors.keys())
        for i, (fulfillment_type, color) in enumerate(custom_colors.items()):
            filtered_df = df[df['Fulfillment_type'] == fulfillment_type]
            if fulfillment_type == 'FBM' and column == 'delivery_price':
                filtered_df = filtered_df[filtered_df['delivery_price'] <= 200]
            if i == 0:
                filtered_df[column].plot(ax=ax, kind='hist', bins=bins, log=True, alpha=0.5, color=color, edgecolor=color, label=f'{fulfillment_type}')
            else:
                filtered_df[column].plot(ax=ax2, kind='hist', bins=bins, log=True, alpha=0.5, color=color, edgecolor=color, label=f'{fulfillment_type}')

        if custom_titles is not None:
            title = custom_titles.get(column)
        else:
            title = f'Combined Histogram of {column}'

        ax.set_title(title)
        ax.set_xlabel(column)
        ax.set_ylabel(f'Frequency ({fulfillment_types[0]})')
        ax2.set_ylabel(f'Frequency ({fulfillment_types[1]})')
        ax.legend(loc='upper left')
        ax2.legend(loc='upper right')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)  # Save the plot as an image file
    plt.show()

custom_titles_combined_dual_axes = {
    'delivery_price': 'Combined Distribution of Delivery Price for FBA and FBM (Dual Axes, FBM Outliers > 200 Excluded)',
    'delivery_time': 'Combined Distribution of Delivery Time for FBA and FBM'
}
custom_colors = {'FBA': 'blue', 'FBM': 'orange'}

plot_combined_histograms_dual_axes(df, columns=['delivery_price', 'delivery_time'], bins=50, save_path='combined_delivery_price_date_diff_histogram_dual_axes.png', custom_titles=custom_titles_combined_dual_axes, custom_colors=custom_colors)

# %%
def plot_combined_histogram(df1, df2, column, bins=50, figsize=(7, 7), log_scale=False, save_path='combined_histogram.png'):
    fig, ax = plt.subplots(figsize=figsize)
    
    if log_scale:
        df1[column].plot(ax=ax, kind='hist', bins=bins, log=True, alpha=0.5, label='All Prices')
        df2[column].plot(ax=ax, kind='hist', bins=bins, log=True, alpha=0.5, label='BuyBox Prices')
    else:
        df1[column].plot(ax=ax, kind='hist', bins=bins, alpha=0.5, label='All Prices')
        df2[column].plot(ax=ax, kind='hist', bins=bins, alpha=0.5, label='BuyBox Prices')
    
    ax.set_title(f'Combined Histogram of {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    ax.legend()
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)  # Save the plot as an image file
    plt.show()

# Call the combined histogram function with the normal price distribution and buyBox price distribution
all_prices_df = df
buybox_prices_df = df[df['buyBoxWinner'] == True]

plot_combined_histogram(all_prices_df, buybox_prices_df, column='price', bins=50, log_scale=True, save_path='combined_histogram.png')

# %%
print("Length of the DataFrame:", df.shape[0])
num_true = (df['buyBoxWinner'] == True).sum()
print(f"The Number of Offers winning the BuyBox is {num_true}")
# Out:
# Length of the DataFrame: 6591111
# The Number of Offers winning the BuyBox is 610468

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def plot_histograms(df, columns, bins=10, figsize=(14, 14), log_scale=False, save_path='histograms.png', filter_condition=None, custom_titles=None):
    if filter_condition is not None:
        df = df[filter_condition]
    
    nrows = len(columns)
    
    if nrows == 1:
        fig, axs = plt.subplots(figsize=figsize)
        axs = [axs]
    else:
        fig, axs = plt.subplots(nrows=nrows, figsize=figsize)

    for ax, column in zip(axs, columns):
        if log_scale:
            df[column].plot(ax=ax, kind='hist', bins=bins, log=True)
        else:
            df[column].plot(ax=ax, kind='hist', bins=bins)
        
        if custom_titles is not None:
            title = custom_titles.get(column)
        else:
            title = f'Histogram of {column}'
        
        ax.set_title(title)
        ax.set_xlabel(column)
        ax.set_ylabel('Frequency')
    plt.tight_layout()
    plt.savefig(save_path, dpi=300)  # Save the plot as an image file
    plt.show()

# Rename the columns
df = df.rename(columns={'sellerbewertung': 'seller_rating', 'lieferpreis': 'delivery_price'})

# List the columns you want to plot histograms for
columns = ['price', 'delivery_price', 'seller_sterne', 'seller_rating', 'date_diff', 'numberOfSellers', 'ranking']

# Call the function with the desired columns and specify the file name for the image output
plot_histograms(df, columns, bins=50, log_scale=True, save_path='histograms.png')

# Additional histograms

# Histogram for delivery price and date_diff for rows where the Fulfillment_type is FBM and FBA
custom_titles_fbm = {
    'delivery_price': 'Delivery Price Distribution for FBM',
    'date_diff': 'Delivery Time Distribution for FBM'
}
custom_titles_fba = {
    'delivery_price': 'Delivery Price Distribution for FBA',
    'date_diff': 'Delivery Time Distribution for FBA'
}
plot_histograms(df, columns=['delivery_price', 'date_diff'], bins=50, log_scale=True, save_path='fbm_delivery_price_date_diff_histogram.png', filter_condition=df['Fulfillment_type'] == 'FBM', figsize=(14, 7), custom_titles=custom_titles_fbm)
plot_histograms(df, columns=['delivery_price', 'date_diff'], bins=50, log_scale=True, save_path='fba_delivery_price_date_diff_histogram.png', filter_condition=df['Fulfillment_type'] == 'FBA', figsize=(14, 7), custom_titles=custom_titles_fba)

# %%
buy_box_counts = df['buyBoxWinner'].value_counts()
buy_box_counts
# Out:
# False    5981045
# True      610066
# Name: buyBoxWinner, dtype: int64

# %%
# Group the DataFrame by 'asin' and calculate the mean of the 'numberOfSellers' column
mean_sellers_by_asin = df.groupby('asin')['numberOfSellers'].mean().reset_index()

# Save the resulting DataFrame to a CSV file
mean_sellers_by_asin.to_csv('../Grunddatein/Zwischendatein/Asins_with_mean_competitors.csv', index=False)

# Round the 'numberOfSellers' mean values to full integers
mean_sellers_by_asin['numberOfSellers'] = mean_sellers_by_asin['numberOfSellers'].round().astype(int)

# Count the occurrences of each number in the 'numberOfSellers' column
occurrences = mean_sellers_by_asin['numberOfSellers'].value_counts()

# Print the occurrences
len(occurrences)
# Out:
# 94

# %% [markdown]
# ## Generating Lists Of Asins Where Amazon is Present as a Seller and where Not

# %%
# Count the number of rows where the 'sellerName' is 'amazon'
amazon_offers_count = len(df[df['sellerName'] == 'amazon'])

print(f"Anzahl der Angebote, die von Amazon verkauft werden: {amazon_offers_count}")

# Count the number of rows where the 'sellerName' is not 'amazon'
non_amazon_offers_count = len(df[df['sellerName'] != 'amazon'])

print(f"Anzahl der Angebote, die nicht von Amazon verkauft werden: {non_amazon_offers_count}")
print(f"Insgesamt gibt es {len(df)} Angebote.")
# Out:
# Anzahl der Angebote, die von Amazon verkauft werden: 405036
# Anzahl der Angebote, die nicht von Amazon verkauft werden: 6186075
# Insgesamt gibt es 6591111 Angebote.

# %%
# Define the Amazon variations
amazon_variations = ['amazon', 'Amazon Warehouse ', 'Amazon US', 'Amazon UK','Amazon']

# Count the number of rows where the 'sellerName' is in the list of Amazon variations
amazon_offers_count = len(df[df['sellerName'].isin(amazon_variations)])

print(f"Anzahl der Angebote, die von Amazon oder einer Amazon-Variante verkauft werden: {amazon_offers_count}")

# Count the number of rows where the 'sellerName' is not in the list of Amazon variations
non_amazon_offers_count = len(df[~df['sellerName'].isin(amazon_variations)])

print(f"Anzahl der Angebote, die nicht von Amazon oder einer Amazon-Variante verkauft werden: {non_amazon_offers_count}")
print(f"Insgesamt gibt es {len(df)} Angebote.")
# Out:
# Anzahl der Angebote, die von Amazon oder einer Amazon-Variante verkauft werden: 1585854
# Anzahl der Angebote, die nicht von Amazon oder einer Amazon-Variante verkauft werden: 5005257
# Insgesamt gibt es 6591111 Angebote.

# %%
amazon_asin_values = df.loc[df['sellerName'].isin(['amazon']), 'asin'].unique()
print(f"An so vielen Asins ist Amazon als Verkäufer eingetragen:{len(amazon_asin_values)}")

# Assuming the DataFrame is named 'df'
all_asin_values = df['asin'].unique()

# Subtract the values that exist in the 'amazon_asin_values' list
non_amazon_asin_values = set(all_asin_values) - set(amazon_asin_values)
print(f"An so vielen Asins ist Amazon nicht als Verkäufer eingetragen:{len(non_amazon_asin_values)}")
print(f"So Viele unterschiedliche Asins gibt es maximal {len(all_asin_values)}")
# Out:
# An so vielen Asins ist Amazon als Verkäufer eingetragen:672
# An so vielen Asins ist Amazon nicht als Verkäufer eingetragen:322
# So Viele unterschiedliche Asins gibt es maximal 994

# %%
amazon_asin_values = df.loc[df['sellerName'].isin(['amazon', 'Amazon Warehouse ', 'Amazon US', 'Amazon UK','Amazon']), 'asin'].unique()
print(f"An so vielen Asins ist Amazon als Verkäufer eingetragen:{len(amazon_asin_values)}")

# Assuming the DataFrame is named 'df'
all_asin_values = df['asin'].unique()

# Subtract the values that exist in the 'amazon_asin_values' list
non_amazon_asin_values = set(all_asin_values) - set(amazon_asin_values)
print(f"An so vielen Asins ist Amazon nicht als Verkäufer eingetragen:{len(non_amazon_asin_values)}")
print(f"So Viele unterschiedliche Asins gibt es maximal {len(all_asin_values)}")
# Out:
# An so vielen Asins ist Amazon als Verkäufer eingetragen:747
# An so vielen Asins ist Amazon nicht als Verkäufer eingetragen:247
# So Viele unterschiedliche Asins gibt es maximal 994

# %%
# Define the Amazon variations
amazon_variations = ['amazon', 'Amazon Warehouse', 'Amazon US', 'Amazon UK','Amazon']

# Filter the DataFrame to get rows with non-Amazon sellers
non_amazon_sellers_df = df[~df['sellerName'].isin(amazon_variations)]

# Get the unique ASINs from the filtered DataFrame
non_amazon_seller_asin_values = non_amazon_sellers_df['asin'].unique()

print(f"Anzahl der verschiedenen ASINs, die von Verkäufern verkauft werden, die keine Amazon-Variante sind: {len(non_amazon_seller_asin_values)}")
# Out:
# Anzahl der verschiedenen ASINs, die von Verkäufern verkauft werden, die keine Amazon-Variante sind: 988

# %%
# List of Amazon variations
amazon_variations = ['amazon', 'Amazon Warehouse', 'Amazon US', 'Amazon UK','Amazon']

# Filter rows where the sellerName is in the Amazon variations list
amazon_sellers_df = df[df['sellerName'].isin(amazon_variations)]

# Group by ASIN and count the number of unique sellers for each ASIN
unique_seller_counts = df.groupby('asin')['sellerName'].nunique().reset_index()

# Filter the unique seller counts to only include ASINs with a single unique seller
single_seller_asins = unique_seller_counts[unique_seller_counts['sellerName'] == 1]

# Get the list of ASINs exclusively sold by Amazon variations
amazon_only_asins = single_seller_asins[single_seller_asins['asin'].isin(amazon_sellers_df['asin'].unique())]['asin']

# Print the number of ASINs exclusively sold by Amazon and its variations
print(f"Number of ASINs exclusively sold by Amazon and its variations: {len(amazon_only_asins)}")
# Out:
# Number of ASINs exclusively sold by Amazon and its variations: 6

# %% [markdown]
# ## Vergleich wie Oft die Seller die BuyBox gewinnen wenn Amazon nicht dabei ist.

# %%
## Vergleich wie Oft die Seller die BuyBox gewinnen wenn Amazon dabei ist, nicht dabei ist.
##Wie oft Seller unter Sich gewinnen
# Get the rows where the asin is in 'non_amazon_asin_values' and the 'buyBoxWinner' column is True
df_non_amazon_buy_box_winners = df.loc[(df['asin'].isin(non_amazon_asin_values)) & (df['buyBoxWinner'] == True )]
amazon_seller_names = ['amazon', 'Amazon Warehouse', 'Amazon US', 'Amazon UK']

# Get the total count of rows where the asin is in 'non_amazon_asin_values' and the 'buyBoxWinner' column is True
total_count = len(df_non_amazon_buy_box_winners)

# Get the count of rows where the value in the 'sellerName' column is not in the 'amazon_seller_names' list
seller_count = len(df_non_amazon_buy_box_winners.loc[~df_non_amazon_buy_box_winners['sellerName'].isin(amazon_seller_names)])

# Calculate the percentage
if total_count > 0:
    percentage = (seller_count / total_count) * 100
else:
    percentage = 0

# Print the percentage
print(percentage)
# Out:
# 100.0

# %% [markdown]
# ## Wie oft FremdSeller die BuyBox gewinnen wenn Amazon dabei ist

# %%
#Wie oft Seller mit Amazon gewinnen
# Get the rows where the asin is in 'amazon_asin_values' and the 'buyBoxWinner' column is True
df_amazon_buy_box_winners = df.loc[(df['asin'].isin(amazon_asin_values)) & (df['buyBoxWinner'] == True)]

# Get the total count of rows where the asin is in 'amazon_asin_values' and the 'buyBoxWinner' column is True
total_count = len(df_amazon_buy_box_winners)
print(f"The Number of BuyBoxWinning Rows for products where Amazon as a seller is present {total_count}")

# Get the count of rows where the value in the 'sellerName' column is not 'amazon' or 'Amazon Warehouse'
offer_without_amazon = df_amazon_buy_box_winners.loc[(df_amazon_buy_box_winners['sellerName'] != 'amazon') & (df_amazon_buy_box_winners['sellerName'] != 'Amazon Warehouse')]
#print(offer_without_amazon)
seller_count = len(offer_without_amazon)
print(f"The Number of BuyBoxWinning Rows where Amazon is not the winner is {seller_count}")

offer_without_amazon = df_amazon_buy_box_winners.loc[(df_amazon_buy_box_winners['sellerName'] == 'amazon') | (df_amazon_buy_box_winners['sellerName'] == 'Amazon Warehouse')]
print(f"The Number of BuyBoxWinning Rows where Amazon is the winner is {len(offer_without_amazon)}")
# Calculate the percentage
if total_count > 0:
    percentage = (seller_count / total_count) * 100
else:
    percentage = 0

# Print the percentage
print(percentage)
# Out:
# The Number of BuyBoxWinning Rows for products where Amazon as a seller is present 472534
# The Number of BuyBoxWinning Rows where Amazon is not the winner is 122254
# The Number of BuyBoxWinning Rows where Amazon is the winner is 350280
# 25.872000744919944

# %% [markdown]
# ## Wie oft ist der niedrigste Preis auch der Gewinner?

# %%
df.tail()
# Out:
#                 id        asin   price currency                 time  \
# 6591106  6944946.0  B09V7ZTP7T  168.72        €  2023-04-23 23:00:00
# 6591107  6944947.0  B09V7ZTP7T  168.72        €  2023-04-23 23:00:00
# 6591108  6944948.0  B09V7ZTP7T  168.72        €  2023-04-23 23:00:00
# 6591109  6944949.0  B09V7ZTP7T  168.72        €  2023-04-23 23:00:00
# 6591110  6944950.0  B09V7ZTP7T  168.72        €  2023-04-23 23:00:00
#
#                           crawlTime         condition         sellerName  \
# 6591106  2023-04-23 23:55:40.056150  Gebraucht-Wieneu  Amazon Warehouse
# 6591107  2023-04-23 23:55:40.056395  Gebraucht-Wieneu  Amazon Warehouse
# 6591108  2023-04-23 23:55:40.056683  Gebraucht-Wieneu  Amazon Warehouse
# 6591109  2023-04-23 23:55:40.056951  Gebraucht-Wieneu  Amazon Warehouse
# 6591110  2023-04-23 23:55:40.057218  Gebraucht-Wieneu  Amazon Warehouse
#
#                  sellerId  sellerbewertung  seller_sterne  \
# 6591106  Amazon-Warehouse              NaN            5.0
# 6591107  Amazon-Warehouse              NaN            5.0
# 6591108  Amazon-Warehouse              NaN            5.0
# 6591109  Amazon-Warehouse              NaN            5.0
# 6591110  Amazon-Warehouse              NaN            5.0
#
#                  lieferdatum  lieferpreis lieferung_durch  ranking  \
# 6591106  Mittwoch. 26. April          0.0          Amazon     23.0
# 6591107  Mittwoch. 26. April          0.0          Amazon     24.0
# 6591108  Mittwoch. 26. April          0.0          Amazon     25.0
# 6591109  Mittwoch. 26. April          0.0          Amazon     26.0
# 6591110  Mittwoch. 26. April          0.0          Amazon     27.0
#
#          buyBoxWinner  numberOfSellers trigByReactive Fulfillment_type  \
# 6591106         False             30.0              f              FBA
# 6591107         False             30.0              f              FBA
# 6591108         False             30.0              f              FBA
# 6591109         False             30.0              f              FBA
# 6591110         False             30.0              f              FBA
#
#          date_diff
# 6591106        3.0
# 6591107        3.0
# 6591108        3.0
# 6591109        3.0
# 6591110        3.0

# %%
df['time'] = pd.to_datetime(df['time'], format="%Y-%m-%d %H:%M:%S")

# Filter rows with 'New' or 'Neu' condition and ranking less than or equal to 4
selected_rows = df[df['condition'].isin(['Neu', 'New']) & (df['ranking'] <= 4)]

# Group the DataFrame by 'asin' and time slot (hour)
grouped_df = selected_rows.groupby(['asin', pd.Grouper(key='time', freq='H')])

# Define a custom function to check if the cheapest row wins the Buy Box
def cheapest_wins_buy_box(group):
    cheapest_row = group.loc[group['price'] == group['price'].min()]
    return cheapest_row['buyBoxWinner'].any()

# Apply the custom function to each group and store the results in a list
cheapest_wins_list = grouped_df.apply(cheapest_wins_buy_box)

# Calculate the overall percentage
total_groups = len(cheapest_wins_list)
cheapest_buy_box_winners = sum(cheapest_wins_list)
percentage = (cheapest_buy_box_winners / total_groups) * 100

# Print the overall percentage with a descriptive message
print(f"Percentage of times the cheapest price wins the Buy Box across all groups: {percentage:.2f}%")
# Out:
# Percentage of times the cheapest price wins the Buy Box across all groups: 67.51%

# %% [markdown]
# ## Wie oft ist der niedrigste Preis nicht der Gewinner?

# %%
val = 100 - percentage
print(f"Percentage of times the cheapest price wins not the Buy Box: {val:.2f}%")
# Out:
# Percentage of times the cheapest price wins not the Buy Box: 32.49%

# %% [markdown]
# ## Exclude Not New Offers and Reactive Offers

# %%
## Exclude all Rows where condition isnt New and which where a reactive Crawl
df = df[df['trigByReactive'] != True]
df = df[df['condition'].isin(['Neu', 'New'])]

# %% [markdown]
# # Wie hoch ist der Unterschied zwischen Maximalen Offerpreis und Minimalen Offerpreis. Absolut

# %%
import pandas as pd

# Group the DataFrame by 'asin' and time slot (hour)
# Only use New Offers, because used objects are not obligated to win the buyBox
selected_rows = df[df['condition'].isin(['Neu', 'New'])]
grouped_df = selected_rows.groupby(['asin', pd.Grouper(key='time', freq='H')])

# Define a custom function to calculate the difference between the highest and cheapest price
def difference_between_highest_and_cheapest(group):
    # Get the row with the cheapest price
    cheapest_row = group.loc[group['price'] == group['price'].min()]
    # Get the row with the highest price
    highest_row = group.loc[group['price'] == group['price'].max()]
    
    # Calculate the difference between the highest price and the cheapest price
    highest_price = highest_row.iloc[0]['price']
    cheapest_price = cheapest_row.iloc[0]['price']
    difference = highest_price - cheapest_price
    
    # Calculate the percentage difference
    percentage_difference = (difference / highest_price) * 100
    
    # Return the difference and percentage difference as a tuple
    return (difference, percentage_difference)

# Apply the custom function to each group
results = grouped_df.apply(difference_between_highest_and_cheapest)

# Find the row/asin with the highest difference
highest_difference = results.apply(lambda x: x[0]).max()
highest_difference_row = results.apply(lambda x: x[0]).idxmax()

# Find the row/asin with the highest percentage difference
highest_percentage_difference = results.apply(lambda x: x[1]).max()
highest_percentage_difference_row = results.apply(lambda x: x[1]).idxmax()

# Print the results
print("Highest Difference:", highest_difference)
print("Highest Difference Row/Asin:", highest_difference_row)
print("Highest Percentage Difference:", highest_percentage_difference)
print("Highest Percentage Difference Row/Asin:", highest_percentage_difference_row)
# Out:
# Highest Difference: 1677.62
# Highest Difference Row/Asin: ('B07KSBWFZS', Timestamp('2023-04-21 21:00:00', freq='H'))
# Highest Percentage Difference: 95.63878912262697
# Highest Percentage Difference Row/Asin: ('B0B9GJLV2D', Timestamp('2023-04-03 03:00:00', freq='H'))

# %%
# Assuming your 'time' column is already in datetime format
filtered_df = df[(df['asin'] == 'B07KSBWFZS') & (df['time'] == pd.Timestamp('2023-04-21 21:00:00'))]

# If your 'time' column is a string, you can use this line instead:
# filtered_df = df[(df['asin'] == 'B07KSBWFZS') & (df['time'] == '2023-04-21 21:00:00')]

min_price = filtered_df['price'].min()
max_price = filtered_df['price'].max()

print(f"Minimum price: {min_price}")
print(f"Maximum price: {max_price}")
percentage_difference = ((max_price - min_price) / max_price) * 100

print(f"Percentage difference: {percentage_difference:.2f}%")
# Out:
# Minimum price: 259.38
# Maximum price: 1937.0
# Percentage difference: 86.61%

# %%
#This One isnt mentioned in the Paper as the absolut value is higher in the other case.
# Assuming your 'time' column is already in datetime format
filtered_df = df[(df['asin'] == 'B0B9GJLV2D') & (df['time'] == pd.Timestamp('2023-04-03 03:00:00'))]

# If your 'time' column is a string, you can use this line instead:
# filtered_df = df[(df['asin'] == 'B07KSBWFZS') & (df['time'] == '2023-04-21 21:00:00')]

min_price = filtered_df['price'].min()
max_price = filtered_df['price'].max()

print(f"Minimum price: {min_price}")
print(f"Maximum price: {max_price}")
# Out:
# Minimum price: 6.8
# Maximum price: 155.92

# %%
# Print the results
print("Highest Difference:", highest_difference)
print("Highest Difference Row/Asin:", highest_difference_row)
# Out:
# Highest Difference: 1677.62
# Highest Difference Row/Asin: ('B07KSBWFZS', Timestamp('2023-04-21 21:00:00', freq='H'))

# %% [markdown]
# # Prozentualer Unterschied zwischen BuyBoxPreis und maximalen Preis über alle Produkte hinweg

# %%
import pandas as pd

# Convert the 'time' column to a DatetimeIndex
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%d-%H:%M:%S')

# Group the DataFrame by 'asin' and time slot (hour)
selected_rows = df[df['condition'].isin(['Neu', 'New'])]
grouped_df = selected_rows.groupby(['asin', pd.Grouper(key='time', freq='H')])

# Define a custom function to calculate the average absolute and percentage differences
def avg_diff(group):
    # Get the row with the highest price
    highest_price_idx = group['price'].idxmax()
    highest_price_row = group.loc[highest_price_idx]
    highest_price = highest_price_row['price']
    
    # Get the row with the buyBox winning offer
    buyBox_winner_row = group.loc[group['buyBoxWinner'] == True]
    
    # Check if there is a buyBox winner for the group
    if buyBox_winner_row.empty:
        return None
    
    # Get the price of the buyBox winning offer
    buyBox_winner_price = buyBox_winner_row.iloc[0]['price']
    
    # Calculate the absolute difference between the highest price and the buyBox winning price
    abs_diff = highest_price - buyBox_winner_price
    
    # Calculate the percentage difference between the highest price and the buyBox winning price
    diff_percent = (abs_diff / highest_price) * 100
    
    # Return both differences as a tuple
    return (abs_diff, diff_percent)

# Apply the custom function to each group
diffs = grouped_df.apply(avg_diff)

# Drop the groups where there is no buyBox winner
diffs = diffs.dropna()

# Separate the absolute and percentage differences into separate DataFrames
abs_diffs = diffs.apply(lambda x: x[0])
percent_diffs = diffs.apply(lambda x: x[1])

# Calculate the overall average absolute and percentage differences
overall_avg_abs_diff = abs_diffs.mean()
overall_avg_percent_diff = percent_diffs.mean()

# Print the overall average absolute and percentage differences
print(f"Overall average absolute difference between the highest price and the Buy Box-winning price: {overall_avg_abs_diff:.2f}")
print(f"Overall average percentage difference between the highest price and the Buy Box-winning price: {overall_avg_percent_diff:.2f}%")
# Out:
# Overall average absolute difference between the highest price and the Buy Box-winning price: 50.83
# Overall average percentage difference between the highest price and the Buy Box-winning price: 23.32%

# %% [markdown]
# # Prozentualer Unterschied zwischen BuyBoxPreis und minimalem Preis über alle Produkte hinweg

# %%
# Convert the 'time' column to a DatetimeIndex
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%d-%H:%M:%S')

# Group the DataFrame by 'asin' and time slot (hour)
selected_rows = df[df['condition'].isin(['Neu', 'New'])]
grouped_df = selected_rows.groupby(['asin', pd.Grouper(key='time', freq='H')])

# Define a custom function to calculate the average absolute and percentage differences
def avg_diff(group):
    # Get the row with the lowest price
    lowest_price_idx = group['price'].idxmin()
    lowest_price_row = group.loc[lowest_price_idx]
    lowest_price = lowest_price_row['price']
    
    # Get the row with the buyBox winning offer
    buyBox_winner_row = group.loc[group['buyBoxWinner'] == True]
    
    # Check if there is a buyBox winner for the group
    if buyBox_winner_row.empty:
        return None
    
    # Get the price of the buyBox winning offer
    buyBox_winner_price = buyBox_winner_row.iloc[0]['price']

    # Calculate the absolute difference between the lowest price and the buyBox winning price
    abs_diff = buyBox_winner_price - lowest_price

    # Calculate the percentage difference between the lowest price and the buyBox winning price
    diff_percent = (abs_diff / lowest_price) * 100

    # Return both differences as a tuple
    return (abs_diff, diff_percent)

# Apply the custom function to each group
diffs = grouped_df.apply(avg_diff)

# Drop the groups where there is no buyBox winner
diffs = diffs.dropna()

# Separate the absolute and percentage differences into separate DataFrames
abs_diffs = diffs.apply(lambda x: x[0])
percent_diffs = diffs.apply(lambda x: x[1])

# Calculate the overall average absolute and percentage differences
overall_avg_abs_diff = abs_diffs.mean()
overall_avg_percent_diff = percent_diffs.mean()

# Print the overall average absolute and percentage differences
print(f"Overall average absolute difference between the Buy Box-winning price and the lowest price: {overall_avg_abs_diff:.2f}")
print(f"Overall average percentage difference between the Buy Box-winning price and the lowest price: {overall_avg_percent_diff:.2f}%")
# Out:
# Overall average absolute difference between the Buy Box-winning price and the lowest price: 1.46
# Overall average percentage difference between the Buy Box-winning price and the lowest price: 1.77%

# %% [markdown]
# # Prozentualer Unterschied zwischen Minimalen Preis und maximalen Preis über alle Produkte hinweg

# %%
import pandas as pd

# Convert the 'time' column to a DatetimeIndex
df['time'] = pd.to_datetime(df['time'], format='%Y-%m-%d-%H:%M:%S')

# Group the DataFrame by 'asin' and time slot (hour)
selected_rows = df[df['condition'].isin(['Neu', 'New'])]
grouped_df = selected_rows.groupby(['asin', pd.Grouper(key='time', freq='H')])

# Define a custom function to calculate the average absolute and percentage differences
def avg_diff(group):
    # Get the row with the highest price
    highest_price_idx = group['price'].idxmax()
    highest_price_row = group.loc[highest_price_idx]
    highest_price = highest_price_row['price']

    # Get the row with the lowest price
    lowest_price_idx = group['price'].idxmin()
    lowest_price_row = group.loc[lowest_price_idx]
    lowest_price = lowest_price_row['price']

    # Calculate the absolute difference between the highest price and the lowest price
    abs_diff = highest_price - lowest_price

    # Calculate the percentage difference between the highest price and the lowest price
    diff_percent = (abs_diff / highest_price) * 100

    # Return both differences as a tuple
    return (abs_diff, diff_percent)

# Apply the custom function to each group
diffs = grouped_df.apply(avg_diff)

# Drop the groups where there is no data
diffs = diffs.dropna()

# Separate the absolute and percentage differences into separate DataFrames
abs_diffs = diffs.apply(lambda x: x[0])
percent_diffs = diffs.apply(lambda x: x[1])

# Calculate the overall average absolute and percentage differences
overall_avg_abs_diff = abs_diffs.mean()
overall_avg_percent_diff = percent_diffs.mean()

# Print the overall average absolute and percentage differences
print(f"Overall average absolute difference between the highest price and the lowest price: {overall_avg_abs_diff:.2f}")
print(f"Overall average percentage difference between the highest price and the lowest price: {overall_avg_percent_diff:.2f}%")
# Out:
# Overall average absolute difference between the highest price and the lowest price: 50.28
# Overall average percentage difference between the highest price and the lowest price: 23.32%

# %% [markdown]
# # Wie lange hält ein Verkäufer die BuyBox im Schnitt

# %%
# Group the dataframe by 'asin' and sort the rows within each group by the 'time' column
df_grouped = df.groupby('asin', group_keys=False).apply(lambda x: x.sort_values('time'))

# If you want to reset the index of the resulting dataframe, you can use the reset_index method
df_grouped = df_grouped.reset_index(drop=True)

# Print the sorted dataframe
df_grouped.head()
# Out:
#          id        asin  price currency                time  \
# 0  343568.0  B00000JD6K   95.8        € 2023-03-22 16:00:00
# 1  344038.0  B00000JD6K   86.9        € 2023-03-22 16:00:00
# 2  352772.0  B00000JD6K   95.8        € 2023-03-22 18:00:00
# 3  353250.0  B00000JD6K   86.9        € 2023-03-22 18:00:00
# 4  361969.0  B00000JD6K   86.9        € 2023-03-22 19:00:00
#
#                     crawlTime condition                 sellerName  \
# 0  2023-03-22 16:55:20.125842       Neu                      Kidia
# 1  2023-03-22 16:55:20.315580       Neu  STILE IMMAGINE DIGITAL HD
# 2  2023-03-22 18:00:22.914723       Neu                      Kidia
# 3  2023-03-22 18:00:23.106664       Neu  STILE IMMAGINE DIGITAL HD
# 4  2023-03-22 19:05:33.089028       Neu  STILE IMMAGINE DIGITAL HD
#
#          sellerId  sellerbewertung  seller_sterne          lieferdatum  \
# 0  A2XUKJNGI8V9XU            46.56            5.0    Samstag. 25. März
# 1  A16E8RFMSALSSB            28.13            5.0  30. März - 6. April
# 2  A2XUKJNGI8V9XU            46.56            5.0    Samstag. 25. März
# 3  A16E8RFMSALSSB            28.13            5.0  30. März - 6. April
# 4  A16E8RFMSALSSB            28.13            5.0  29. März - 4. April
#
#    lieferpreis            lieferung_durch  ranking  buyBoxWinner  \
# 0          0.0                     Amazon      0.0          True
# 1          9.9  STILE IMMAGINE DIGITAL HD      1.0         False
# 2          0.0                     Amazon      0.0          True
# 3          9.9  STILE IMMAGINE DIGITAL HD      1.0         False
# 4          9.9  STILE IMMAGINE DIGITAL HD      0.0          True
#
#    numberOfSellers trigByReactive Fulfillment_type  date_diff
# 0              2.0              f              FBA        3.0
# 1              1.0              f              FBM       27.0
# 2              2.0              f              FBA        3.0
# 3              1.0              f              FBM       27.0
# 4              2.0              f              FBM       25.0

# %%
import pandas as pd

# Filter the rows where 'buyBoxWinner' is True
winning_rows = df[df['buyBoxWinner']]

# Convert the 'time' column to a datetime object
winning_rows['time'] = pd.to_datetime(winning_rows['time'], format='%Y-%m-%d %H:%M:%S')

# Sort the winning rows by 'asin' and 'time'
winning_rows = winning_rows.sort_values(['asin', 'time'])

# Calculate the time difference between consecutive winning rows for each ASIN
winning_rows['time_diff'] = winning_rows.groupby('asin')['time'].diff()

# Only include time differences greater than 0
winning_rows = winning_rows[winning_rows['time_diff'].dt.total_seconds() > 0]

# Aggregate the time differences by ASIN and by 'sellerName'
time_agg = winning_rows.groupby(['asin', 'sellerName'])['time_diff'].sum().reset_index()

# Calculate the average winning time across all sellers who win the BuyBox
average_winning_time = time_agg['time_diff'].mean()

# Calculate the minimum, and maximum winning time across all groups
min_winning_time = time_agg['time_diff'].min()
max_winning_time = time_agg['time_diff'].max()

# Find the seller(s) with the longest BuyBox holding time
longest_buybox_holders = time_agg[time_agg['time_diff'] == max_winning_time]

# Count the number of sellers tied for the longest holding time
num_longest_holders = len(longest_buybox_holders)

# Filter sellers with winning time longer than 9 hours
sellers_longer_than_xx = time_agg[time_agg['time_diff'] > pd.Timedelta(hours=100)]

# Find the minimum and maximum time in the dataset
min_time = df['time'].min()
max_time = df['time'].max()

# Count the number of 'amazon' or 'Amazon Warehouse' sellers tied for the longest holding time
num_amazon_longest_holders = len(longest_buybox_holders[longest_buybox_holders['sellerName'].isin(['amazon', 'Amazon Warehouse '])])

# Create a new DataFrame with ASINs tied for the longest holding time
AsinWithStaticBuxBoxWinner = longest_buybox_holders[['asin']].drop_duplicates()

# Save the DataFrame to a CSV file
AsinWithStaticBuxBoxWinner.to_csv('../Grunddatein/Zwischendatein/AsinWithStaticBuxBoxWinner.csv', index=False)

print("Minimum time in the dataset:", min_time)
print("Maximum time in the dataset:", max_time)
print("Average winning time:", average_winning_time)
print("Minimum winning time:", min_winning_time)
print("Maximum winning time:", max_winning_time)
print(f"\nNumber of sellers tied for the longest holding time: {num_longest_holders}")
print(f"Number of 'amazon' or 'Amazon Warehouse' sellers tied for the longest holding time: {num_amazon_longest_holders}")

print("\nSellers with winning time longer than 100 hours:")
for index, row in sellers_longer_than_xx.iterrows():
    print(f"ASIN: {row['asin']}, Seller: {row['sellerName']}, Winning Time: {row['time_diff']}")

print("\nSellers tied for the longest holding time:")
for index, row in longest_buybox_holders.iterrows():
    print(f"ASIN: {row['asin']}, Seller: {row['sellerName']}, Winning Time: {row['time_diff']}")
# Out:
# C:\Users\Robert Betschinger\AppData\Local\Temp\ipykernel_17292\2867258733.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winning_rows['time'] = pd.to_datetime(winning_rows['time'], format='%Y-%m-%d %H:%M:%S')
# Minimum time in the dataset: 2023-03-22 16:00:00
# Maximum time in the dataset: 2023-04-23 23:00:00
# Average winning time: 13 days 00:14:05.679548415
# Minimum winning time: 0 days 01:00:00
# Maximum winning time: 32 days 07:00:00
#
# Number of sellers tied for the longest holding time: 318
# Number of 'amazon' or 'Amazon Warehouse' sellers tied for the longest holding time: 225
#
# Sellers with winning time longer than 100 hours:
# ASIN: B00000JD6K, Seller: Kidia, Winning Time: 23 days 03:00:00
# ASIN: B00000JD6K, Seller: STILE IMMAGINE DIGITAL HD, Winning Time: 5 days 23:00:00
# ASIN: B00005KIRS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00008K61M, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00008K61N, Seller: amazon, Winning Time: 32 days 02:00:00
# ASIN: B0000C72GD, Seller: STILE IMMAGINE DIGITAL HD, Winning Time: 32 days 07:00:00
# ASIN: B0000D85OD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0000WOK04, Seller: amazon, Winning Time: 29 days 08:00:00
# ASIN: B0000WOK9A, Seller: BWBahn, Winning Time: 8 days 18:00:00
# ASIN: B0000WOK9A, Seller: amazon, Winning Time: 23 days 12:00:00
# ASIN: B0001GRVJQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00022749Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0002CZU1U, Seller: Musikhaus Kirstein GmbH, Winning Time: 32 days 03:00:00
# ASIN: B0002CZYW0, Seller: HeBa - Sound & Music, Winning Time: 31 days 14:00:00
# ASIN: B0002E1O68, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0002HOS7M, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0002HP91Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0002MRCLQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0006HXHEI, Seller: ZAIDOO - Hier zählst Du!, Winning Time: 7 days 07:00:00
# ASIN: B0006HXHEI, Seller: amazon, Winning Time: 20 days 18:00:00
# ASIN: B0009NPOL8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0009V6N1U, Seller: CW-SHOPPING, Winning Time: 14 days 21:00:00
# ASIN: B0009V6N1U, Seller: amazon, Winning Time: 16 days 19:00:00
# ASIN: B000A89EEU, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000B2Q2MC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000CRF7M2, Seller: amazon, Winning Time: 31 days 13:00:00
# ASIN: B000EEJH9C, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000EELCB8, Seller: Musik Produktiv, Winning Time: 24 days 14:00:00
# ASIN: B000EELCB8, Seller: amazon, Winning Time: 7 days 17:00:00
# ASIN: B000EENFIG, Seller: Coloretta, Winning Time: 4 days 14:00:00
# ASIN: B000EENFIG, Seller: amazon, Winning Time: 27 days 17:00:00
# ASIN: B000GISU1M, Seller: Body & Fit Nutrition, Winning Time: 25 days 23:00:00
# ASIN: B000IUQRXQ, Seller: amazon, Winning Time: 30 days 04:00:00
# ASIN: B000IYEMYI, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000KTBF8C, Seller: priz24, Winning Time: 32 days 05:00:00
# ASIN: B000KZBD4M, Seller: XXL-Phones, Winning Time: 32 days 01:00:00
# ASIN: B000LPSNRQ, Seller: MUSIC STORE Professional, Winning Time: 15 days 23:00:00
# ASIN: B000LPSNRQ, Seller: amazon, Winning Time: 8 days 16:00:00
# ASIN: B000MJR8UO, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B000MQG3US, Seller: amazon, Winning Time: 31 days 08:00:00
# ASIN: B000NC8ETE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000ONLUHA, Seller: amazon, Winning Time: 28 days 08:00:00
# ASIN: B000RVZU20, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000SIR14M, Seller: nox divendo, Winning Time: 32 days 03:00:00
# ASIN: B000T10P6O, Seller: Pro Lighting e.K., Winning Time: 8 days 00:00:00
# ASIN: B000T10P6O, Seller: amazon, Winning Time: 22 days 18:00:00
# ASIN: B000TGHVGQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B000VDNZ1M, Seller: amazon, Winning Time: 24 days 22:00:00
# ASIN: B000WH2TH8, Seller: amazon, Winning Time: 29 days 09:00:00
# ASIN: B000WWHOUK, Seller: Musikhaus Kirstein GmbH, Winning Time: 14 days 16:00:00
# ASIN: B000WWHOUK, Seller: amazon, Winning Time: 6 days 21:00:00
# ASIN: B000WZ7FT2, Seller: amazon, Winning Time: 30 days 02:00:00
# ASIN: B000XFG40W, Seller: amazon, Winning Time: 32 days 03:00:00
# ASIN: B000XZ5XJ0, Seller: Pro Lighting e.K., Winning Time: 32 days 06:00:00
# ASIN: B000YK5W18, Seller: amazon, Winning Time: 31 days 17:00:00
# ASIN: B000Z222L8, Seller: MusicScout, Winning Time: 23 days 09:00:00
# ASIN: B000Z222L8, Seller: Zoundhouse - Dresden, Winning Time: 8 days 22:00:00
# ASIN: B0010M6XBW, Seller: get goods, Winning Time: 4 days 20:00:00
# ASIN: B0010M6XBW, Seller: haupteingang1, Winning Time: 19 days 21:00:00
# ASIN: B0011IFT24, Seller: modeherz 'Alle Preise inkl. Mwst.'"", Winning Time: 27 days 11:00:00
# ASIN: B00123DQT6, Seller: Musikhaus Kirstein GmbH, Winning Time: 9 days 14:00:00
# ASIN: B00123DQT6, Seller: amazon, Winning Time: 15 days 17:00:00
# ASIN: B0012QJZTI, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0012QP0P6, Seller: amazon, Winning Time: 31 days 20:00:00
# ASIN: B0013NSJT2, Seller: amazon, Winning Time: 29 days 07:00:00
# ASIN: B00144EEBM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0014DPPH0, Seller: CoolSound-Superstore, Winning Time: 10 days 14:00:00
# ASIN: B0014DPPH0, Seller: Elektronik-Versand, Winning Time: 12 days 04:00:00
# ASIN: B0014DPPH0, Seller: Voelkner, Winning Time: 6 days 03:00:00
# ASIN: B0019DACQY, Seller: Music and More Store, Winning Time: 30 days 05:00:00
# ASIN: B001AZH3B8, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B001DZVU64, Seller: Cornilleau, Winning Time: 14 days 19:00:00
# ASIN: B001DZVU64, Seller: Sportsmadison, Winning Time: 13 days 23:00:00
# ASIN: B001E7SVE0, Seller: amazon, Winning Time: 31 days 05:00:00
# ASIN: B001EPF9WO, Seller: amazon, Winning Time: 17 days 18:00:00
# ASIN: B001EPF9WO, Seller: shop_moll, Winning Time: 11 days 20:00:00
# ASIN: B001IL99I4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B001K9AHKI, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B001MESZBO, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B001R4BR1O, Seller: amazon, Winning Time: 29 days 17:00:00
# ASIN: B001RIESZC, Seller: BWBahn, Winning Time: 30 days 23:00:00
# ASIN: B001RIFQOO, Seller: Kreativity-World, Winning Time: 32 days 06:00:00
# ASIN: B001TODD96, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B001U3ZXTY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0028KN2BY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0029M5CZA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0029M92U6, Seller: amazon, Winning Time: 6 days 22:00:00
# ASIN: B002BA58TA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B002DYGX7K, Seller: BWBahn, Winning Time: 10 days 15:00:00
# ASIN: B002DYGX7K, Seller: Modellbau Fischer, Winning Time: 6 days 07:00:00
# ASIN: B002DYGX7K, Seller: amazon, Winning Time: 15 days 09:00:00
# ASIN: B002NFR0HQ, Seller: amazon, Winning Time: 27 days 09:00:00
# ASIN: B002NFR0HQ, Seller: zooundgarten-de, Winning Time: 4 days 22:00:00
# ASIN: B002QZW85W, Seller: amazon, Winning Time: 31 days 19:00:00
# ASIN: B002RII5SW, Seller: amazon, Winning Time: 30 days 19:00:00
# ASIN: B002SG6PPS, Seller: amazon, Winning Time: 32 days 02:00:00
# ASIN: B002Y0SID0, Seller: amazon, Winning Time: 30 days 05:00:00
# ASIN: B0037LGH1K, Seller: amazon, Winning Time: 30 days 00:00:00
# ASIN: B0037LIMOA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00389KMQM, Seller: amazon, Winning Time: 28 days 16:00:00
# ASIN: B003AVPV0U, Seller: DirectfromStarTech, Winning Time: 32 days 07:00:00
# ASIN: B003BF8L70, Seller: CHRIST Juweliere und Uhrmacher, Winning Time: 12 days 04:00:00
# ASIN: B003BF8L70, Seller: Marken-Koffer, Winning Time: 5 days 04:00:00
# ASIN: B003BF8L70, Seller: modeherz 'Alle Preise inkl. Mwst.'"", Winning Time: 7 days 15:00:00
# ASIN: B003DDWI0Q, Seller: amazon, Winning Time: 31 days 18:00:00
# ASIN: B003HLXNJO, Seller: Cartvil, Winning Time: 11 days 01:00:00
# ASIN: B003HLXNJO, Seller: amzbitrage, Winning Time: 12 days 17:00:00
# ASIN: B003I3MDCO, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B003NE992U, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B003OSUDOS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0041OBHSK, Seller: MUSIC STORE Professional, Winning Time: 26 days 04:00:00
# ASIN: B0041OBHSK, Seller: Musikhaus-Korn, Winning Time: 5 days 12:00:00
# ASIN: B0045FVO3S, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0045FYE3A, Seller: amazon, Winning Time: 31 days 15:00:00
# ASIN: B0049MELOQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B004IM7HXE, Seller: ZAPATERÍAS MARÍN, Winning Time: 4 days 14:00:00
# ASIN: B004IM7HXE, Seller: amazon, Winning Time: 8 days 22:00:00
# ASIN: B004PVUL7C, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B004QEZJWU, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B004RUB648, Seller: amazon, Winning Time: 30 days 12:00:00
# ASIN: B004THFJ3S, Seller: my mosaik, Winning Time: 28 days 12:00:00
# ASIN: B004V2VQUQ, Seller: WilTec Wildanger Technik GmbH, Winning Time: 32 days 07:00:00
# ASIN: B004V49C8W, Seller: MusicScout, Winning Time: 23 days 07:00:00
# ASIN: B004V49C8W, Seller: Musikhaus-Korn, Winning Time: 8 days 22:00:00
# ASIN: B004VRARQU, Seller: Cycletronic, Winning Time: 16 days 14:00:00
# ASIN: B004VRARQU, Seller: nicePriceIT, Winning Time: 5 days 10:00:00
# ASIN: B004VRARQU, Seller: youSmart, Winning Time: 4 days 13:00:00
# ASIN: B004VXT3XM, Seller: Amazon US, Winning Time: 32 days 07:00:00
# ASIN: B004YIU5P4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B004Z0W9KK, Seller: amazon, Winning Time: 28 days 05:00:00
# ASIN: B0050CK648, Seller: Bürowelt-Blank, Winning Time: 10 days 00:00:00
# ASIN: B0050CK648, Seller: Carta Mondo. Preise inkl. MwSt., Winning Time: 20 days 19:00:00
# ASIN: B005343HS0, Seller: MUSIC STORE Professional, Winning Time: 29 days 18:00:00
# ASIN: B005612OSE, Seller: 1Deins Computer GmbH, Winning Time: 4 days 18:00:00
# ASIN: B005612OSE, Seller: Elektro-Shop Köck GmbH, Winning Time: 27 days 01:00:00
# ASIN: B0059TLON4, Seller: amazon, Winning Time: 32 days 04:00:00
# ASIN: B005FLUS0Q, Seller: Sixone, Winning Time: 31 days 19:00:00
# ASIN: B005GUFLBW, Seller: Sagenta GmbH, Winning Time: 28 days 20:00:00
# ASIN: B005JZ4KDO, Seller: amazon, Winning Time: 32 days 06:00:00
# ASIN: B005KSYI32, Seller: DerWellnessshop, Winning Time: 5 days 21:00:00
# ASIN: B005KSYI32, Seller: time4wellness, Winning Time: 26 days 10:00:00
# ASIN: B005OSRLT6, Seller: amazon, Winning Time: 25 days 17:00:00
# ASIN: B005P6FNYW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B005XJTZ68, Seller: Fusselkopf, Winning Time: 4 days 20:00:00
# ASIN: B005XJTZ68, Seller: amazon, Winning Time: 27 days 11:00:00
# ASIN: B00605N1G4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00606058A, Seller: amazon, Winning Time: 31 days 09:00:00
# ASIN: B0061GL6LO, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0062VH4NM, Seller: WSK-Internetservice, Winning Time: 32 days 07:00:00
# ASIN: B0068MHWXW, Seller: Autodoc Shop, Winning Time: 25 days 05:00:00
# ASIN: B0068MLO7M, Seller: Autodoc Shop, Winning Time: 16 days 13:00:00
# ASIN: B0068MLO7M, Seller: AutoteileDirekt, Winning Time: 4 days 10:00:00
# ASIN: B0068MLO7M, Seller: X1 Shop, Winning Time: 6 days 05:00:00
# ASIN: B0068MMNXG, Seller: amazon, Winning Time: 29 days 18:00:00
# ASIN: B0068O0JTE, Seller: MROAUTO Autoparts, Winning Time: 24 days 23:00:00
# ASIN: B006AUOR1W, Seller: Fritz Berger GmbH, Winning Time: 11 days 18:00:00
# ASIN: B006AUOR1W, Seller: Outdoor24 - Outdoor&Freizeitartikel, Winning Time: 4 days 11:00:00
# ASIN: B006AUOR1W, Seller: amazon, Winning Time: 16 days 02:00:00
# ASIN: B006DHOIBG, Seller: MROAUTO Autoparts, Winning Time: 24 days 01:00:00
# ASIN: B006DHOIBG, Seller: amazon, Winning Time: 6 days 11:00:00
# ASIN: B006HL9CDW, Seller: ÖKO Planet GmbH, Winning Time: 27 days 22:00:00
# ASIN: B006R9OP1S, Seller: Löchel_Industriebedarf, Winning Time: 32 days 03:00:00
# ASIN: B006TF4S3U, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B006VD910U, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B006YPTWZ4, Seller: time4wellness, Winning Time: 32 days 07:00:00
# ASIN: B0071M60UY, Seller: STILE IMMAGINE DIGITAL HD, Winning Time: 32 days 07:00:00
# ASIN: B007BYOQRG, Seller: VersandLager, Winning Time: 32 days 02:00:00
# ASIN: B007EUF4U0, Seller: Horse Shop, Winning Time: 11 days 05:00:00
# ASIN: B007EUF4U0, Seller: Reitsport Iris Schwarz, Winning Time: 17 days 15:00:00
# ASIN: B007IRTDQ0, Seller: FINEST OF BEAUTY, Winning Time: 15 days 18:00:00
# ASIN: B007IRTDQ0, Seller: GlobalHair, Winning Time: 6 days 03:00:00
# ASIN: B007IRTDQ0, Seller: Haarboutique, Winning Time: 4 days 21:00:00
# ASIN: B007MP7OP0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B007PC6JRY, Seller: amazon, Winning Time: 31 days 19:00:00
# ASIN: B007WQJSGM, Seller: amazon, Winning Time: 26 days 04:00:00
# ASIN: B007Y341L0, Seller: Lemodo_GmbH, Winning Time: 12 days 06:00:00
# ASIN: B007ZXWQ8E, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B0081R34J8, Seller: UvV-Shop (ES-Team Consult GmbH), Winning Time: 32 days 05:00:00
# ASIN: B0089E5VLC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B008BH59BO, Seller: amazon, Winning Time: 12 days 09:00:00
# ASIN: B008BH6634, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B008F7WGCK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B008F8DT8O, Seller: amazon, Winning Time: 31 days 23:00:00
# ASIN: B008F8DTAM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B008FT05C6, Seller: amazon, Winning Time: 32 days 04:00:00
# ASIN: B008LUK10A, Seller: Whooki GmbH, Winning Time: 10 days 15:00:00
# ASIN: B008LUK10A, Seller: amazon, Winning Time: 13 days 02:00:00
# ASIN: B008U4NBE0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0094DZUDG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B009BEO81I, Seller: MERULA TRADE, Winning Time: 5 days 06:00:00
# ASIN: B009BEO81I, Seller: amazon, Winning Time: 27 days 01:00:00
# ASIN: B009H06WYW, Seller: SKYLINE MEDIA, Winning Time: 32 days 07:00:00
# ASIN: B009PM6UC6, Seller: amazon, Winning Time: 30 days 05:00:00
# ASIN: B009PM6VQG, Seller: SVH Handels-GmbH, Winning Time: 23 days 04:00:00
# ASIN: B009PM6VQG, Seller: amazon, Winning Time: 9 days 03:00:00
# ASIN: B009X5YX74, Seller: amazon, Winning Time: 28 days 22:00:00
# ASIN: B00A7IIR64, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00AEAQL4A, Seller: Zoundhouse - Dresden, Winning Time: 10 days 20:00:00
# ASIN: B00AEAQL4A, Seller: amazon, Winning Time: 21 days 08:00:00
# ASIN: B00AQ2BE4I, Seller: amazon, Winning Time: 29 days 06:00:00
# ASIN: B00AQ4U58W, Seller: amazon, Winning Time: 14 days 18:00:00
# ASIN: B00AYCXLM8, Seller: Modellbahnwelt 24 . Preise inkl. MwSt., Winning Time: 25 days 20:00:00
# ASIN: B00AYCXLM8, Seller: Modellbau-Quelle - ab 20.-€ Schnellversand, Winning Time: 6 days 11:00:00
# ASIN: B00B280810, Seller: Rig Expert, Winning Time: 22 days 10:00:00
# ASIN: B00B29GHTG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00B3203ME, Seller: amazon, Winning Time: 27 days 11:00:00
# ASIN: B00B7LV9QU, Seller: amazon, Winning Time: 32 days 03:00:00
# ASIN: B00B8D53IM, Seller: Amazon, Winning Time: 30 days 21:00:00
# ASIN: B00BAT8U16, Seller: amazon, Winning Time: 30 days 04:00:00
# ASIN: B00BBU3JJ2, Seller: Autopartner24, Winning Time: 23 days 12:00:00
# ASIN: B00BBXUGY0, Seller: amazon, Winning Time: 31 days 11:00:00
# ASIN: B00BPUA752, Seller: MROAUTO Autoparts, Winning Time: 27 days 11:00:00
# ASIN: B00BXFPMZE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00C2T1JIY, Seller: amazon, Winning Time: 32 days 03:00:00
# ASIN: B00C5A14ZS, Seller: W.I.R Handels-GmbH, Winning Time: 28 days 21:00:00
# ASIN: B00CL83JVQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00D1O12NG, Seller: Papiertiger-Berlin, Winning Time: 32 days 03:00:00
# ASIN: B00DDKUC0C, Seller: Musikhaus Kirstein GmbH, Winning Time: 4 days 23:00:00
# ASIN: B00DG89W0W, Seller: MUSIC STORE Professional, Winning Time: 25 days 09:00:00
# ASIN: B00DG89W0W, Seller: MusicScout, Winning Time: 6 days 22:00:00
# ASIN: B00DQSWB78, Seller: amazon, Winning Time: 25 days 11:00:00
# ASIN: B00DW5SR2I, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00E0LESGW, Seller: BlumenbeckerIndustriebedarf GmbH, Winning Time: 31 days 21:00:00
# ASIN: B00E4FO9TU, Seller: FOTO KOESTER MUENSTER, Winning Time: 29 days 06:00:00
# ASIN: B00E9WAZ0U, Seller: bzoptical, Winning Time: 32 days 04:00:00
# ASIN: B00EAA9ZK2, Seller: amazon, Winning Time: 5 days 16:00:00
# ASIN: B00ECEVGN0, Seller: amazon, Winning Time: 28 days 16:00:00
# ASIN: B00ED7A3FI, Seller: amazon, Winning Time: 32 days 06:00:00
# ASIN: B00ER2SSRO, Seller: Racketworld, Winning Time: 13 days 13:00:00
# ASIN: B00ER2SSRO, Seller: bellytime, Winning Time: 18 days 18:00:00
# ASIN: B00EYXKTDM, Seller: amazon, Winning Time: 31 days 23:00:00
# ASIN: B00FGEN4RG, Seller: MUSIC STORE Professional, Winning Time: 24 days 02:00:00
# ASIN: B00FGEN4RG, Seller: Musikhaus Kirstein GmbH, Winning Time: 5 days 13:00:00
# ASIN: B00FGKE4SI, Seller: ddplus GmbH, Winning Time: 31 days 17:00:00
# ASIN: B00FGVN6OK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00FWSRY7M, Seller: Klarstein Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B00FZ822Q2, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00FZ83O0A, Seller: amazon, Winning Time: 31 days 02:00:00
# ASIN: B00GC0ODBE, Seller: Schuhe24, Winning Time: 29 days 07:00:00
# ASIN: B00GGQIEYQ, Seller: MULTI-LITE GmbH, Winning Time: 8 days 07:00:00
# ASIN: B00GGQIEYQ, Seller: time4wellness, Winning Time: 24 days 00:00:00
# ASIN: B00GHS71B0, Seller: MROAUTO Autoparts, Winning Time: 17 days 08:00:00
# ASIN: B00GHS71B0, Seller: WS-Autoteile, Winning Time: 13 days 22:00:00
# ASIN: B00GY9127Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00I3TOXVM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00I64R77Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00I69NK9A, Seller: amazon, Winning Time: 30 days 14:00:00
# ASIN: B00I7TWSWE, Seller: amazon, Winning Time: 29 days 08:00:00
# ASIN: B00IO1NQHG, Seller: Musikhaus Kirstein GmbH, Winning Time: 27 days 19:00:00
# ASIN: B00IO1NQHG, Seller: Musikhaus-Korn, Winning Time: 4 days 12:00:00
# ASIN: B00IPUGJDE, Seller: MUSIC STORE Professional, Winning Time: 25 days 17:00:00
# ASIN: B00IPUGJDE, Seller: Musikbaum 'Preise inkl. Mwst.'"", Winning Time: 6 days 14:00:00
# ASIN: B00IVEGH2C, Seller: amazon, Winning Time: 28 days 06:00:00
# ASIN: B00J7GVPY8, Seller: amazon, Winning Time: 29 days 11:00:00
# ASIN: B00JBBSUHY, Seller: amazon, Winning Time: 31 days 01:00:00
# ASIN: B00JBMCY0M, Seller: Fitness2002, Winning Time: 14 days 21:00:00
# ASIN: B00JBMCY0M, Seller: PolleoSport, Winning Time: 6 days 09:00:00
# ASIN: B00JBMCY0M, Seller: SPORT INNOVATIONS, Winning Time: 10 days 15:00:00
# ASIN: B00JOLKMJK, Seller: SVH Handels-GmbH, Winning Time: 13 days 22:00:00
# ASIN: B00JOLKMJK, Seller: amazon, Winning Time: 18 days 09:00:00
# ASIN: B00JOLOZN4, Seller: amazon, Winning Time: 30 days 16:00:00
# ASIN: B00JVPLUS6, Seller: Hommel GbR - Preise inkl. MwSt, Winning Time: 31 days 06:00:00
# ASIN: B00JVQIWEA, Seller: BlumenbeckerIndustriebedarf GmbH, Winning Time: 6 days 12:00:00
# ASIN: B00JVQIWEA, Seller: WERKZEUGPROFI, Winning Time: 25 days 16:00:00
# ASIN: B00KH4SYRU, Seller: Fixversand, Winning Time: 32 days 04:00:00
# ASIN: B00KH4SZJW, Seller: Fixversand, Winning Time: 30 days 23:00:00
# ASIN: B00KIHXS7W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00L4XU430, Seller: heuergmbh, Winning Time: 8 days 12:00:00
# ASIN: B00LEI4QWK, Seller: Kreativity-World, Winning Time: 32 days 07:00:00
# ASIN: B00LFLAL98, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00LFSDBZC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00LX10YAQ, Seller: Amitaly, Winning Time: 6 days 10:00:00
# ASIN: B00LX10YAQ, Seller: Easysell2020, Winning Time: 4 days 21:00:00
# ASIN: B00LX10YAQ, Seller: VendiloOra, Winning Time: 9 days 18:00:00
# ASIN: B00M97VW1I, Seller: ShopHier, Winning Time: 9 days 18:00:00
# ASIN: B00M97VW1I, Seller: amazon, Winning Time: 22 days 09:00:00
# ASIN: B00MIKJ4MU, Seller: amazon, Winning Time: 15 days 08:00:00
# ASIN: B00MIKJ4MU, Seller: smartgoods-de, Winning Time: 10 days 04:00:00
# ASIN: B00MUQ5IEK, Seller: DEPICE Kampfsportartikel, Winning Time: 32 days 04:00:00
# ASIN: B00N1BXDFE, Seller: Home Automation EU, Winning Time: 32 days 07:00:00
# ASIN: B00N3EHVY8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00NIO9T8O, Seller: amazon, Winning Time: 30 days 12:00:00
# ASIN: B00NIOBGRQ, Seller: amazon, Winning Time: 30 days 08:00:00
# ASIN: B00NJXYP7Y, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00NTR1PTG, Seller: CW-SHOPPING, Winning Time: 25 days 03:00:00
# ASIN: B00NTR1PTG, Seller: amazon, Winning Time: 7 days 04:00:00
# ASIN: B00NVMIO02, Seller:
#                  , Winning Time: 31 days 22:00:00
# ASIN: B00O8CE8P4, Seller: Elektro-Shop Köck GmbH, Winning Time: 4 days 09:00:00
# ASIN: B00O8CE8P4, Seller: Monbeck GmbH & Co. KG, Winning Time: 4 days 22:00:00
# ASIN: B00O8CECSM, Seller: Cstore., Winning Time: 30 days 19:00:00
# ASIN: B00OBHPSSC, Seller: Bauportal24H, Winning Time: 29 days 03:00:00
# ASIN: B00OK6YSAS, Seller: Foto Erhardt GmbH, Winning Time: 31 days 08:00:00
# ASIN: B00ON9ZJCS, Seller: amazon, Winning Time: 32 days 06:00:00
# ASIN: B00ONA6L60, Seller: Elektro-Shop Köck GmbH, Winning Time: 23 days 17:00:00
# ASIN: B00ONA6L60, Seller: amazon, Winning Time: 8 days 14:00:00
# ASIN: B00ONA6O1W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00OV0DFAC, Seller: Modellbahnshop-Korn, Winning Time: 20 days 06:00:00
# ASIN: B00OV0DFAC, Seller: Rasppishop, Winning Time: 11 days 22:00:00
# ASIN: B00OYSOOEC, Seller: amazon, Winning Time: 30 days 14:00:00
# ASIN: B00P0ZY2K4, Seller: Blinksale. alle Preise inkl. MwSt., Winning Time: 9 days 05:00:00
# ASIN: B00P0ZY2K4, Seller: amazon, Winning Time: 12 days 09:00:00
# ASIN: B00P0ZY2K4, Seller: in und outdoor, Winning Time: 8 days 03:00:00
# ASIN: B00P8KS2D4, Seller: 2-flowerpower, Winning Time: 5 days 13:00:00
# ASIN: B00P8KS2D4, Seller: amazon, Winning Time: 26 days 18:00:00
# ASIN: B00P91LW9S, Seller: Homoeopathiefuchs Versand-Apotheke, Winning Time: 22 days 17:00:00
# ASIN: B00PBOLSTC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00PH4QNE6, Seller: amazon, Winning Time: 7 days 23:00:00
# ASIN: B00QDTTD2I, Seller: Elektro-Shop Köck GmbH, Winning Time: 4 days 05:00:00
# ASIN: B00QDTTD2I, Seller: amazon, Winning Time: 25 days 06:00:00
# ASIN: B00QMG609Q, Seller: TierXXL, Winning Time: 32 days 07:00:00
# ASIN: B00R86RIUE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00RECW47E, Seller: GlobalNetOnline, Winning Time: 32 days 07:00:00
# ASIN: B00SKXD8C6, Seller: amazon, Winning Time: 29 days 20:00:00
# ASIN: B00SWI2UK0, Seller: amazon, Winning Time: 28 days 04:00:00
# ASIN: B00T031DAE, Seller: Fa.BEST4FORST-EUROPE, Winning Time: 26 days 18:00:00
# ASIN: B00TQU7HCO, Seller: SamanthasShop, Winning Time: 8 days 00:00:00
# ASIN: B00V6IJ27C, Seller: amazon, Winning Time: 30 days 17:00:00
# ASIN: B00VA5HNL8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00VEF9YH0, Seller: DOMO SHOP, Winning Time: 20 days 10:00:00
# ASIN: B00VEF9YH0, Seller: Home Automation EU, Winning Time: 11 days 21:00:00
# ASIN: B00WS8QCP4, Seller: Astradis Elektronik, Winning Time: 6 days 05:00:00
# ASIN: B00WS8QCP4, Seller: PFU (EMEA) LIMITED, Winning Time: 6 days 02:00:00
# ASIN: B00WS8QCP4, Seller: Papyrus, Winning Time: 17 days 20:00:00
# ASIN: B00X3WBPEM, Seller: Lens2Lens, Winning Time: 29 days 10:00:00
# ASIN: B00X3WCICA, Seller: Contact Lenses, Winning Time: 22 days 23:00:00
# ASIN: B00X3WCICA, Seller: amazon, Winning Time: 4 days 19:00:00
# ASIN: B00X3WD6K8, Seller: amazon, Winning Time: 26 days 23:00:00
# ASIN: B00X4F8564, Seller: Arcobaleno Centro Musicale, Winning Time: 5 days 03:00:00
# ASIN: B00X4F8564, Seller: Musikhaus-Korn, Winning Time: 5 days 08:00:00
# ASIN: B00X4F8564, Seller: amazon, Winning Time: 18 days 02:00:00
# ASIN: B00XLFYP2U, Seller: Sixone, Winning Time: 32 days 07:00:00
# ASIN: B00XWLVDUU, Seller: amazon, Winning Time: 10 days 07:00:00
# ASIN: B00YNJGBL6, Seller: HeBa - Sound & Music, Winning Time: 6 days 16:00:00
# ASIN: B00YNJGBL6, Seller: Musikhaus Kirstein GmbH, Winning Time: 4 days 15:00:00
# ASIN: B00YR92T90, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00YUWGV5W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B00YYL14FG, Seller: Agrarking DE, Winning Time: 12 days 04:00:00
# ASIN: B00YYL14FG, Seller: AnimalZ-Online, Winning Time: 20 days 03:00:00
# ASIN: B00ZUWRON4, Seller: Deva-Natur, Winning Time: 25 days 22:00:00
# ASIN: B00ZUWRON4, Seller: Foster-natur, Winning Time: 6 days 09:00:00
# ASIN: B0101Y34TI, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0108LBQNK, Seller: DuronicEU, Winning Time: 32 days 07:00:00
# ASIN: B0116JXRU8, Seller: Travel in Style, Winning Time: 32 days 07:00:00
# ASIN: B0116X17JW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B011UDKH5I, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B012TCE1J2, Seller: Joola Tischtennis GmbH, Winning Time: 20 days 17:00:00
# ASIN: B012TCE1J2, Seller: amazon, Winning Time: 11 days 14:00:00
# ASIN: B0132ANU0Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B013DA46VC, Seller: Songmics, Winning Time: 31 days 08:00:00
# ASIN: B013WBIW3K, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B013WBIWEE, Seller: Amazon UK, Winning Time: 4 days 16:00:00
# ASIN: B013WBIWEE, Seller: amazon, Winning Time: 14 days 05:00:00
# ASIN: B013WBIWEE, Seller: foto24, Winning Time: 11 days 18:00:00
# ASIN: B014309K5S, Seller: WALSER - nur das Beste für Ihr Auto, Winning Time: 32 days 07:00:00
# ASIN: B01468WH34, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B014HNXYLC, Seller: Caffè Musetti, Winning Time: 32 days 03:00:00
# ASIN: B0157X3HFE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B015BFXII4, Seller: amazon, Winning Time: 29 days 00:00:00
# ASIN: B015CVT33G, Seller: Ponera, Winning Time: 29 days 11:00:00
# ASIN: B015CVZW90, Seller: Gege24, Winning Time: 5 days 22:00:00
# ASIN: B015CVZW90, Seller: Ponera, Winning Time: 26 days 07:00:00
# ASIN: B015OYKPYC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0160AZ198, Seller: amazon, Winning Time: 24 days 17:00:00
# ASIN: B016K4GQVG, Seller: TechPoint1111, Winning Time: 16 days 22:00:00
# ASIN: B016XYQ3WK, Seller: Batna_24, Winning Time: 4 days 21:00:00
# ASIN: B016XYQ3WK, Seller: amazon, Winning Time: 15 days 11:00:00
# ASIN: B017BDU62A, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B017KBLIPW, Seller: amazon, Winning Time: 31 days 23:00:00
# ASIN: B018XWLZ64, Seller: BWBahn, Winning Time: 9 days 02:00:00
# ASIN: B018XWLZ64, Seller: amazon, Winning Time: 23 days 05:00:00
# ASIN: B0196Q9PV8, Seller: Luckyberg, Winning Time: 5 days 12:00:00
# ASIN: B0196Q9PV8, Seller: ProTrade Home&Office, Winning Time: 26 days 04:00:00
# ASIN: B0196Q9PVS, Seller: ProTrade Home&Office, Winning Time: 26 days 20:00:00
# ASIN: B019WCXL2U, Seller: amazon, Winning Time: 28 days 20:00:00
# ASIN: B01AAGCB00, Seller: Musikhaus Kirstein GmbH, Winning Time: 5 days 11:00:00
# ASIN: B01AAGCB00, Seller: amazon, Winning Time: 25 days 19:00:00
# ASIN: B01ARNOGDG, Seller:
#                  , Winning Time: 31 days 13:00:00
# ASIN: B01ARRTHUE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01B3E87W4, Seller: keepdrum, Winning Time: 24 days 15:00:00
# ASIN: B01BCENVC6, Seller: HomeHome by A, Winning Time: 6 days 23:00:00
# ASIN: B01BCENVC6, Seller: amazon, Winning Time: 25 days 08:00:00
# ASIN: B01BJWF2VY, Seller: Morso, Winning Time: 31 days 23:00:00
# ASIN: B01C34UKNM, Seller: Bittner Warenhandel - Preise inkl. Mwst., Winning Time: 32 days 07:00:00
# ASIN: B01C3SCKI6, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01CEJHVBA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01CR246WG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01CSS8GCK, Seller: BWBahn, Winning Time: 23 days 07:00:00
# ASIN: B01CSS8GCK, Seller: amazon, Winning Time: 9 days 00:00:00
# ASIN: B01D3DM1RK, Seller: TZS First E Commerce, Winning Time: 29 days 04:00:00
# ASIN: B01EA3E46S, Seller: amazon, Winning Time: 10 days 00:00:00
# ASIN: B01EJAK2JK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01EQZA5M2, Seller: amazon, Winning Time: 31 days 14:00:00
# ASIN: B01F3AS0D0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01FBD7XYG, Seller: Amazon US, Winning Time: 26 days 08:00:00
# ASIN: B01FE7K184, Seller: Elektro-Shop Köck GmbH, Winning Time: 13 days 12:00:00
# ASIN: B01FE7K184, Seller: Home-Produkte, Winning Time: 4 days 15:00:00
# ASIN: B01FE7K184, Seller: Marsmedia, Winning Time: 6 days 09:00:00
# ASIN: B01G7QXYOE, Seller: Amazon US, Winning Time: 30 days 03:00:00
# ASIN: B01G9SYGLU, Seller: Astradis Elektronik, Winning Time: 31 days 23:00:00
# ASIN: B01GCVBALI, Seller: Amazon, Winning Time: 7 days 08:00:00
# ASIN: B01GCVBALI, Seller: Diktierportal, Winning Time: 6 days 18:00:00
# ASIN: B01GCVBALI, Seller: OfficeCom Solutions, Winning Time: 11 days 20:00:00
# ASIN: B01GCVBALI, Seller: Vedio-Tech, Winning Time: 6 days 09:00:00
# ASIN: B01GG8ZXDS, Seller: BWBahn, Winning Time: 30 days 13:00:00
# ASIN: B01GHZGENS, Seller: toennes24, Winning Time: 30 days 16:00:00
# ASIN: B01GI60G6C, Seller: BWBahn, Winning Time: 23 days 21:00:00
# ASIN: B01GI60G6C, Seller: amazon, Winning Time: 8 days 02:00:00
# ASIN: B01H73IAEA, Seller: Sagenta GmbH, Winning Time: 32 days 07:00:00
# ASIN: B01HBK5KPQ, Seller: Online-Versand-Grafenau GmbH, Winning Time: 9 days 03:00:00
# ASIN: B01HBK5KPQ, Seller: Reitsport Iris Schwarz, Winning Time: 18 days 22:00:00
# ASIN: B01HCSYRHY, Seller: Songmics, Winning Time: 32 days 07:00:00
# ASIN: B01IBM4G9E, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01ILWOIUG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01ITADB4E, Seller: Kinderhaus Blaubaer GmbH & Co. KG, Winning Time: 30 days 22:00:00
# ASIN: B01ITG2JEQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01IVDXF4K, Seller: amazon, Winning Time: 31 days 08:00:00
# ASIN: B01KG1O8UU, Seller: Wohnkult Deko, Winning Time: 26 days 23:00:00
# ASIN: B01KKJHSP0, Seller: amazon, Winning Time: 31 days 16:00:00
# ASIN: B01KYK5ORO, Seller: Baby-Direkt, Winning Time: 28 days 09:00:00
# ASIN: B01L15ZMVE, Seller: Musik Center, Winning Time: 25 days 15:00:00
# ASIN: B01L15ZMVE, Seller: amazon, Winning Time: 6 days 16:00:00
# ASIN: B01L27NNAI, Seller: Deltatecc GmbH, Winning Time: 5 days 00:00:00
# ASIN: B01L27NNAI, Seller: amazon, Winning Time: 20 days 18:00:00
# ASIN: B01L27NNAI, Seller: okluge, Winning Time: 5 days 17:00:00
# ASIN: B01L27QFSK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01LLAK1UG, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B01LOUJK6O, Seller: Stabilo-Fachmarkt, Winning Time: 7 days 19:00:00
# ASIN: B01LOUJK6O, Seller: hbh24online, Winning Time: 22 days 03:00:00
# ASIN: B01LXFCIGP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01LXLFF6H, Seller: amazon, Winning Time: 29 days 23:00:00
# ASIN: B01LYXBO8Y, Seller: amazon, Winning Time: 22 days 17:00:00
# ASIN: B01LYXBO8Y, Seller: aquaristicnet Babenhausen, Winning Time: 9 days 08:00:00
# ASIN: B01M0HC5DJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M1OYGOV, Seller: BWBahn, Winning Time: 31 days 14:00:00
# ASIN: B01M34E5G4, Seller: MUSIC STORE Professional, Winning Time: 32 days 03:00:00
# ASIN: B01M4OJP4B, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M4QU5CQ, Seller: amazon, Winning Time: 30 days 22:00:00
# ASIN: B01M5JJXFR, Seller: amazon, Winning Time: 32 days 01:00:00
# ASIN: B01M7QUU52, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M8JTMTO, Seller: amazon, Winning Time: 29 days 15:00:00
# ASIN: B01MA23UZG, Seller: TZS First E Commerce, Winning Time: 32 days 07:00:00
# ASIN: B01MA52IHY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MCUVMNV, Seller: amazon, Winning Time: 31 days 23:00:00
# ASIN: B01MFAYA83, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MRX73ML, Seller: amazon, Winning Time: 31 days 12:00:00
# ASIN: B01MS8EKO8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MSJBKWC, Seller: GoodSupps, Winning Time: 4 days 07:00:00
# ASIN: B01MSJBKWC, Seller: SIDCO GmbH, Winning Time: 21 days 17:00:00
# ASIN: B01MSJBKWC, Seller: Thats Shopping GmbH, Winning Time: 5 days 07:00:00
# ASIN: B01MSX991C, Seller: amazon, Winning Time: 29 days 02:00:00
# ASIN: B01MT8GPB0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MYPH5LD, Seller: SIDCO GmbH, Winning Time: 20 days 19:00:00
# ASIN: B01MYPH5LD, Seller: Thats Shopping GmbH, Winning Time: 7 days 02:00:00
# ASIN: B01MYSQLQF, Seller: amazon, Winning Time: 30 days 09:00:00
# ASIN: B01N109G8P, Seller: Musikhaus Kirstein GmbH, Winning Time: 25 days 12:00:00
# ASIN: B01N5QV0CA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01N6QA1CF, Seller: Meinl-Shop, Winning Time: 11 days 06:00:00
# ASIN: B01N6QA1CF, Seller: Musik Produktiv, Winning Time: 12 days 19:00:00
# ASIN: B01N6QA1CF, Seller: amazon, Winning Time: 6 days 20:00:00
# ASIN: B01N8P57XY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01N95580X, Seller: amazon, Winning Time: 17 days 16:00:00
# ASIN: B01N997C1B, Seller: amazon, Winning Time: 26 days 11:00:00
# ASIN: B01N99KXQQ, Seller: amazon, Winning Time: 23 days 07:00:00
# ASIN: B01NADWR3R, Seller: amazon, Winning Time: 27 days 07:00:00
# ASIN: B01NC2S2BD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01NCLZGCP, Seller: TierXXL, Winning Time: 28 days 14:00:00
# ASIN: B06VSLN4KP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B06VVDPFZ3, Seller: Ingane, Winning Time: 27 days 18:00:00
# ASIN: B06VVDPFZ3, Seller: KinderMax, Winning Time: 4 days 13:00:00
# ASIN: B06VY1D778, Seller: amazon, Winning Time: 31 days 15:00:00
# ASIN: B06XBZH1DZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B06XD4MDVY, Seller: amazon, Winning Time: 32 days 00:00:00
# ASIN: B06XDR4125, Seller: Ciccimarra Gioielli, Winning Time: 32 days 07:00:00
# ASIN: B06Y46JN9H, Seller: MUSIC STORE Professional, Winning Time: 32 days 05:00:00
# ASIN: B06Y8RTTQH, Seller: Musik Produktiv, Winning Time: 28 days 13:00:00
# ASIN: B06ZYZNDYF, Seller: MUSIC STORE Professional, Winning Time: 8 days 20:00:00
# ASIN: B06ZYZNDYF, Seller: Musik Produktiv, Winning Time: 23 days 00:00:00
# ASIN: B0713TH6BR, Seller: TZS First E Commerce, Winning Time: 32 days 07:00:00
# ASIN: B0718XR163, Seller: amazon, Winning Time: 31 days 15:00:00
# ASIN: B071DM6C5D, Seller: CT COOL TIME, Winning Time: 30 days 15:00:00
# ASIN: B071G4LG29, Seller: amazon, Winning Time: 28 days 06:00:00
# ASIN: B071HHX6VF, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B071W8R4PS, Seller: amazon, Winning Time: 28 days 08:00:00
# ASIN: B071WCDHZJ, Seller: BWBahn, Winning Time: 25 days 16:00:00
# ASIN: B071WCDHZJ, Seller: amazon, Winning Time: 6 days 03:00:00
# ASIN: B07378Y15Q, Seller: amazon, Winning Time: 4 days 10:00:00
# ASIN: B073LZY41Q, Seller: amazon, Winning Time: 32 days 06:00:00
# ASIN: B073RFMGLY, Seller: Schildkröt-Shop, Winning Time: 5 days 15:00:00
# ASIN: B073RFMGLY, Seller: Trend Sportiv, Winning Time: 8 days 01:00:00
# ASIN: B073RFMGLY, Seller: amazon, Winning Time: 12 days 09:00:00
# ASIN: B073RFV6KX, Seller: L-Parts, Winning Time: 15 days 18:00:00
# ASIN: B073RFV6KX, Seller: TierXXL, Winning Time: 16 days 13:00:00
# ASIN: B073WG2WCY, Seller: amazon, Winning Time: 7 days 02:00:00
# ASIN: B0741D7LRD, Seller: Eden Appliances, Winning Time: 21 days 13:00:00
# ASIN: B074MNJSWF, Seller: amazon, Winning Time: 32 days 02:00:00
# ASIN: B074PMVJJ8, Seller: amazon, Winning Time: 32 days 04:00:00
# ASIN: B074WBSJ9J, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0752V1XFG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0752XV66X, Seller: amazon, Winning Time: 32 days 01:00:00
# ASIN: B0756DRR6M, Seller: Tegrace Eur, Winning Time: 32 days 07:00:00
# ASIN: B075LG1P79, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B076CKHGKZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B076KZL9HH, Seller: Elektro-Shop Köck GmbH, Winning Time: 17 days 07:00:00
# ASIN: B076KZL9HH, Seller: Olano GmbH, Winning Time: 10 days 23:00:00
# ASIN: B076SV43NQ, Seller: Marken-Kaufhaus Preise inkl. MwSt., Winning Time: 4 days 06:00:00
# ASIN: B076SV43NQ, Seller: amazon, Winning Time: 22 days 03:00:00
# ASIN: B076TBCTTV, Seller: amazon, Winning Time: 28 days 15:00:00
# ASIN: B076WZCQ2B, Seller: amazon, Winning Time: 31 days 15:00:00
# ASIN: B076X28H9S, Seller: amazon, Winning Time: 24 days 12:00:00
# ASIN: B076X2L2QW, Seller: amazon, Winning Time: 32 days 06:00:00
# ASIN: B0771ND3VV, Seller: amazon, Winning Time: 32 days 04:00:00
# ASIN: B0771NNH66, Seller: Sport-Riegel, Winning Time: 4 days 14:00:00
# ASIN: B0771NNH66, Seller: amazon, Winning Time: 23 days 10:00:00
# ASIN: B077MNFH3S, Seller: amazon, Winning Time: 32 days 03:00:00
# ASIN: B077T3QZ1H, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B077TWTCY2, Seller: Miller Rock, Winning Time: 32 days 07:00:00
# ASIN: B078211KBB, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0784CDNZD, Seller: United Brands Online GmbH, Winning Time: 32 days 07:00:00
# ASIN: B0786QNLP1, Seller: MUSIC STORE Professional, Winning Time: 9 days 11:00:00
# ASIN: B0786QNLP1, Seller: Musikhaus Kirstein GmbH, Winning Time: 22 days 15:00:00
# ASIN: B078HV7PBP, Seller: Bauportal24H, Winning Time: 32 days 02:00:00
# ASIN: B078HYZJPR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078JSXDPL, Seller: amazon, Winning Time: 30 days 21:00:00
# ASIN: B078N9X7QL, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078VPM6WM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078XFKTKQ, Seller: belli-shop, Winning Time: 24 days 17:00:00
# ASIN: B078XXW215, Seller: amazon, Winning Time: 31 days 22:00:00
# ASIN: B078Y44MW3, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0793GS93Q, Seller: myToys-de GmbH, Winning Time: 28 days 02:00:00
# ASIN: B0797CV4TX, Seller: RoyalRapture, Winning Time: 12 days 03:00:00
# ASIN: B0797CV4TX, Seller: amazon, Winning Time: 20 days 04:00:00
# ASIN: B0797FYB3K, Seller: amazon, Winning Time: 21 days 12:00:00
# ASIN: B079GZY3RD, Seller: amazon, Winning Time: 4 days 10:00:00
# ASIN: B079KHBY2N, Seller: amazon, Winning Time: 31 days 13:00:00
# ASIN: B079KHS5S9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079N4MPFR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079QQ34RL, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079YSQGT2, Seller: amazon, Winning Time: 26 days 12:00:00
# ASIN: B07B2WQPR3, Seller: amazon, Winning Time: 31 days 23:00:00
# ASIN: B07B5D1YYC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07B6GNDLJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07B9453S5, Seller: Wünsch dir was, Winning Time: 4 days 20:00:00
# ASIN: B07B9453S5, Seller: amazon, Winning Time: 19 days 07:00:00
# ASIN: B07B9453S5, Seller: kaijott, Winning Time: 8 days 04:00:00
# ASIN: B07B9CP3ZK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07BBF4JWQ, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B07BV1S1S5, Seller: StonKraft EU, Winning Time: 31 days 23:00:00
# ASIN: B07BYT2WW8, Seller: We Will Shop You, Winning Time: 32 days 07:00:00
# ASIN: B07C97X6VK, Seller: Fluid_Onlinehandel, Winning Time: 23 days 20:00:00
# ASIN: B07C97X6VK, Seller: anndora_, Winning Time: 8 days 07:00:00
# ASIN: B07CPYYV9X, Seller: amazon, Winning Time: 11 days 00:00:00
# ASIN: B07CPYYV9X, Seller: edelsoft, Winning Time: 13 days 19:00:00
# ASIN: B07CTQ5TJM, Seller: FINEST OF BEAUTY, Winning Time: 15 days 10:00:00
# ASIN: B07CTQ5TJM, Seller: Haarboutique, Winning Time: 10 days 12:00:00
# ASIN: B07CTQ5TJM, Seller: Riemax GmbH & Co. KG, Winning Time: 4 days 05:00:00
# ASIN: B07CVK6S2W, Seller: Musikhaus Kirstein GmbH, Winning Time: 11 days 11:00:00
# ASIN: B07CVK6S2W, Seller: music world brilon_, Winning Time: 20 days 14:00:00
# ASIN: B07D6WMYMN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DLWCBKJ, Seller: DIGITLIFE SRLS, Winning Time: 30 days 09:00:00
# ASIN: B07DNWM62H, Seller: JMT-Direct Store, Winning Time: 11 days 13:00:00
# ASIN: B07DNWM62H, Seller: ShenStar, Winning Time: 20 days 18:00:00
# ASIN: B07DNZKWLS, Seller: amazon, Winning Time: 31 days 16:00:00
# ASIN: B07DPRG8RQ, Seller: Bilvary, Winning Time: 9 days 00:00:00
# ASIN: B07DPRG8RQ, Seller: GG Geschenke-Galerie GmbH, Winning Time: 16 days 06:00:00
# ASIN: B07DVNLHD9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DVSFCW1, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DWXBWB7, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DX2MV3X, Seller: amazon, Winning Time: 28 days 23:00:00
# ASIN: B07F2DTWN6, Seller: Inateck, Winning Time: 32 days 07:00:00
# ASIN: B07F69WW45, Seller: Heldenwerk® Einkaufswelt, Winning Time: 32 days 07:00:00
# ASIN: B07F748GDP, Seller: Musikhaus Freising, Winning Time: 23 days 07:00:00
# ASIN: B07FFNTLJD, Seller: Batna_24, Winning Time: 4 days 07:00:00
# ASIN: B07FFNTLJD, Seller: amazon, Winning Time: 22 days 04:00:00
# ASIN: B07FK64MMW, Seller: KLH Handelsgesellschaft mbH, Winning Time: 12 days 13:00:00
# ASIN: B07FK64MMW, Seller: Schwanthaler Computer, Winning Time: 15 days 23:00:00
# ASIN: B07G4YCCHK, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B07G9MQWJ6, Seller: amazon, Winning Time: 12 days 03:00:00
# ASIN: B07G9MQWJ6, Seller: e-joker, Winning Time: 15 days 02:00:00
# ASIN: B07G9MQWJ6, Seller: technikbilliger, Winning Time: 4 days 22:00:00
# ASIN: B07GB2GC62, Seller: amazon, Winning Time: 19 days 12:00:00
# ASIN: B07GBN64L4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07GBRMSTD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07GDTB24P, Seller: BestArtikel GmbH, Winning Time: 27 days 15:00:00
# ASIN: B07GGFXKJ2, Seller: amazon, Winning Time: 31 days 14:00:00
# ASIN: B07GKQXT29, Seller: amazon, Winning Time: 28 days 06:00:00
# ASIN: B07GR69N8S, Seller: DL-accessories, Winning Time: 32 days 07:00:00
# ASIN: B07GTS7SWK, Seller: CrazyKangaroo, Winning Time: 21 days 17:00:00
# ASIN: B07GTS7SWK, Seller: amazon, Winning Time: 8 days 18:00:00
# ASIN: B07GVRJTXP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07GWR7XRK, Seller: belli-shop, Winning Time: 16 days 07:00:00
# ASIN: B07GWR7XRK, Seller: modeherz 'Alle Preise inkl. Mwst.'"", Winning Time: 11 days 02:00:00
# ASIN: B07GX5SWV3, Seller: Kommerzpunkt, Winning Time: 9 days 16:00:00
# ASIN: B07GX5SWV3, Seller: amazon, Winning Time: 16 days 08:00:00
# ASIN: B07GYWBTN5, Seller: Fixversand, Winning Time: 31 days 02:00:00
# ASIN: B07H5NT6HZ, Seller: amazon, Winning Time: 31 days 19:00:00
# ASIN: B07H7DRX6Y, Seller: Starlabels, Winning Time: 5 days 06:00:00
# ASIN: B07H7DRX6Y, Seller: amazon, Winning Time: 26 days 01:00:00
# ASIN: B07H9YJHB4, Seller: CT COOL TIME, Winning Time: 21 days 14:00:00
# ASIN: B07H9YJHB4, Seller: amazon, Winning Time: 10 days 17:00:00
# ASIN: B07H9YXPNS, Seller: amazon, Winning Time: 30 days 17:00:00
# ASIN: B07HBCFMDW, Seller: Alpine Trading Mittenwald, Winning Time: 7 days 04:00:00
# ASIN: B07HBCFMDW, Seller: dieTechnik, Winning Time: 11 days 04:00:00
# ASIN: B07HBCFMDW, Seller: tonies®, Winning Time: 11 days 02:00:00
# ASIN: B07HFT541Y, Seller: Amazon UK, Winning Time: 17 days 19:00:00
# ASIN: B07HFT541Y, Seller: SKYLINE MEDIA, Winning Time: 10 days 20:00:00
# ASIN: B07HGQ4H18, Seller: amazon, Winning Time: 31 days 06:00:00
# ASIN: B07HLLC1TC, Seller: Batna_24, Winning Time: 16 days 20:00:00
# ASIN: B07HLLC1TC, Seller: GETIC, Winning Time: 12 days 21:00:00
# ASIN: B07HM5WM64, Seller: amazon, Winning Time: 25 days 13:00:00
# ASIN: B07HM5WM64, Seller: aquaristicnet Babenhausen, Winning Time: 6 days 18:00:00
# ASIN: B07HM711PK, Seller: aquaristicnet Babenhausen, Winning Time: 30 days 07:00:00
# ASIN: B07HMF1G57, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07HRW7DBC, Seller: Musikhaus-Korn, Winning Time: 6 days 21:00:00
# ASIN: B07HRW7DBC, Seller: Zoundhouse - Dresden, Winning Time: 25 days 10:00:00
# ASIN: B07JHHDZL3, Seller: RICOO-Medientechnik. Preise inkl. MwSt., Winning Time: 32 days 07:00:00
# ASIN: B07JJ9H978, Seller: amazon, Winning Time: 29 days 02:00:00
# ASIN: B07JJKV6JH, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07JK613K8, Seller: ebg, Winning Time: 32 days 07:00:00
# ASIN: B07JKS3HXS, Seller: RENPHO LIMITED, Winning Time: 32 days 07:00:00
# ASIN: B07JZVP6R8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07K2PKCP7, Seller: amazon, Winning Time: 26 days 02:00:00
# ASIN: B07K42LVW3, Seller: BRAUN BÜFFEL, Winning Time: 32 days 05:00:00
# ASIN: B07KBF9J7Y, Seller: Baby-Direkt, Winning Time: 32 days 04:00:00
# ASIN: B07KF9TC3J, Seller: Nine Ju, Winning Time: 32 days 07:00:00
# ASIN: B07KFCJPGN, Seller: amazon, Winning Time: 30 days 02:00:00
# ASIN: B07KFF3HBL, Seller: CT COOL TIME, Winning Time: 20 days 05:00:00
# ASIN: B07KFF3HBL, Seller: amazon, Winning Time: 12 days 02:00:00
# ASIN: B07KFL4QBZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KJ2TDMR, Seller: amazon, Winning Time: 25 days 15:00:00
# ASIN: B07KJ2TDMR, Seller: okluge, Winning Time: 5 days 01:00:00
# ASIN: B07KJWF5MB, Seller: ZHIPENG, Winning Time: 26 days 12:00:00
# ASIN: B07KN2SWCP, Seller: AOOBYSH, Winning Time: 28 days 04:00:00
# ASIN: B07KNLMYVQ, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B07KP9CW3F, Seller: Klarstein Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07KPMRKTN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KSBWFZS, Seller: Amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KY6QG4Z, Seller: amazon, Winning Time: 25 days 06:00:00
# ASIN: B07L6RCYZM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07L9T7R9M, Seller: amazon, Winning Time: 27 days 03:00:00
# ASIN: B07LH6FXWZ, Seller: KW-Commerce, Winning Time: 32 days 07:00:00
# ASIN: B07MBH6BPW, Seller: Ledger, Winning Time: 32 days 07:00:00
# ASIN: B07MGZD1X2, Seller: Redcar Service, Winning Time: 14 days 01:00:00
# ASIN: B07MKZ9VJ2, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07MTG5V14, Seller: xinxiamibu, Winning Time: 30 days 23:00:00
# ASIN: B07MVZG76S, Seller: MUSIC STORE Professional, Winning Time: 31 days 11:00:00
# ASIN: B07MVZX87Z, Seller: HeBa - Sound & Music, Winning Time: 5 days 05:00:00
# ASIN: B07MVZX87Z, Seller: MUSIC STORE Professional, Winning Time: 5 days 19:00:00
# ASIN: B07MVZX87Z, Seller: amazon, Winning Time: 21 days 07:00:00
# ASIN: B07N28Z5BN, Seller: XXL-Phones, Winning Time: 5 days 02:00:00
# ASIN: B07N28Z5BN, Seller: amazon, Winning Time: 27 days 05:00:00
# ASIN: B07N6TY5D7, Seller: amazon, Winning Time: 32 days 05:00:00
# ASIN: B07N6VZYD3, Seller: amazon, Winning Time: 27 days 15:00:00
# ASIN: B07N6VZYD3, Seller: hagelshop, Winning Time: 4 days 16:00:00
# ASIN: B07N7S4M4Z, Seller: WMF Direkt, Winning Time: 4 days 16:00:00
# ASIN: B07N7S4M4Z, Seller: amazon, Winning Time: 25 days 11:00:00
# ASIN: B07N8N6C85, Seller: amazon, Winning Time: 32 days 04:00:00
# ASIN: B07NC928FM, Seller: amazon, Winning Time: 29 days 19:00:00
# ASIN: B07NGV259P, Seller: amazon, Winning Time: 20 days 02:00:00
# ASIN: B07NGV259P, Seller: jomodo, Winning Time: 12 days 05:00:00
# ASIN: B07NJ5RQL7, Seller: MUSIC STORE Professional, Winning Time: 26 days 07:00:00
# ASIN: B07NJ5RQL7, Seller: Musikhaus-Korn, Winning Time: 6 days 00:00:00
# ASIN: B07NVQL19Q, Seller: ACE-Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07NVQZG71, Seller: ACE-Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07NZC5NZJ, Seller: amazon, Winning Time: 27 days 02:00:00
# ASIN: B07P296595, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07P495TQ4, Seller: amazon, Winning Time: 29 days 14:00:00
# ASIN: B07P581CK8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07P6M72DS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07PRCFDFB, Seller: RS-Versand, Winning Time: 31 days 09:00:00
# ASIN: B07PWXN3RG, Seller: amazon, Winning Time: 30 days 14:00:00
# ASIN: B07PZQ55PC, Seller: amazon, Winning Time: 23 days 09:00:00
# ASIN: B07PZQ55PC, Seller: priz24, Winning Time: 5 days 00:00:00
# ASIN: B07Q2RKC7D, Seller: Songmics, Winning Time: 32 days 03:00:00
# ASIN: B07QD9KW58, Seller: amazon, Winning Time: 31 days 22:00:00
# ASIN: B07QP8BKQW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RFS2K2X, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RM95YFC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RS7HM59, Seller: amazon, Winning Time: 32 days 07:00:00
# ...
# ASIN: B00YUWGV5W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0101Y34TI, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0108LBQNK, Seller: DuronicEU, Winning Time: 32 days 07:00:00
# ASIN: B0116JXRU8, Seller: Travel in Style, Winning Time: 32 days 07:00:00
# ASIN: B0116X17JW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B011UDKH5I, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0132ANU0Q, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B013WBIW3K, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B014309K5S, Seller: WALSER - nur das Beste für Ihr Auto, Winning Time: 32 days 07:00:00
# ASIN: B01468WH34, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0157X3HFE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B015OYKPYC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B017BDU62A, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01ARRTHUE, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01C34UKNM, Seller: Bittner Warenhandel - Preise inkl. Mwst., Winning Time: 32 days 07:00:00
# ASIN: B01C3SCKI6, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01CEJHVBA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01CR246WG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01EJAK2JK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01F3AS0D0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01H73IAEA, Seller: Sagenta GmbH, Winning Time: 32 days 07:00:00
# ASIN: B01HCSYRHY, Seller: Songmics, Winning Time: 32 days 07:00:00
# ASIN: B01IBM4G9E, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01ILWOIUG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01ITG2JEQ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01L27QFSK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01LXFCIGP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M0HC5DJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M4OJP4B, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01M7QUU52, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MA23UZG, Seller: TZS First E Commerce, Winning Time: 32 days 07:00:00
# ASIN: B01MA52IHY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MFAYA83, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MS8EKO8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01MT8GPB0, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01N5QV0CA, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01N8P57XY, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B01NC2S2BD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B06VSLN4KP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B06XBZH1DZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B06XDR4125, Seller: Ciccimarra Gioielli, Winning Time: 32 days 07:00:00
# ASIN: B0713TH6BR, Seller: TZS First E Commerce, Winning Time: 32 days 07:00:00
# ASIN: B071HHX6VF, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B074WBSJ9J, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0752V1XFG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0756DRR6M, Seller: Tegrace Eur, Winning Time: 32 days 07:00:00
# ASIN: B076CKHGKZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B077T3QZ1H, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B077TWTCY2, Seller: Miller Rock, Winning Time: 32 days 07:00:00
# ASIN: B078211KBB, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0784CDNZD, Seller: United Brands Online GmbH, Winning Time: 32 days 07:00:00
# ASIN: B078HYZJPR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078N9X7QL, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078VPM6WM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B078Y44MW3, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079KHS5S9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079N4MPFR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B079QQ34RL, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07B5D1YYC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07B6GNDLJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07B9CP3ZK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07BBF4JWQ, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B07BYT2WW8, Seller: We Will Shop You, Winning Time: 32 days 07:00:00
# ASIN: B07D6WMYMN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DVNLHD9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DVSFCW1, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07DWXBWB7, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07F2DTWN6, Seller: Inateck, Winning Time: 32 days 07:00:00
# ASIN: B07F69WW45, Seller: Heldenwerk® Einkaufswelt, Winning Time: 32 days 07:00:00
# ASIN: B07GBN64L4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07GBRMSTD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07GR69N8S, Seller: DL-accessories, Winning Time: 32 days 07:00:00
# ASIN: B07GVRJTXP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07HMF1G57, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07JHHDZL3, Seller: RICOO-Medientechnik. Preise inkl. MwSt., Winning Time: 32 days 07:00:00
# ASIN: B07JJKV6JH, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07JK613K8, Seller: ebg, Winning Time: 32 days 07:00:00
# ASIN: B07JKS3HXS, Seller: RENPHO LIMITED, Winning Time: 32 days 07:00:00
# ASIN: B07JZVP6R8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KF9TC3J, Seller: Nine Ju, Winning Time: 32 days 07:00:00
# ASIN: B07KFL4QBZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KNLMYVQ, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B07KP9CW3F, Seller: Klarstein Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07KPMRKTN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07KSBWFZS, Seller: Amazon, Winning Time: 32 days 07:00:00
# ASIN: B07L6RCYZM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07LH6FXWZ, Seller: KW-Commerce, Winning Time: 32 days 07:00:00
# ASIN: B07MBH6BPW, Seller: Ledger, Winning Time: 32 days 07:00:00
# ASIN: B07MKZ9VJ2, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07NVQL19Q, Seller: ACE-Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07NVQZG71, Seller: ACE-Deutschland, Winning Time: 32 days 07:00:00
# ASIN: B07P296595, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07P581CK8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07P6M72DS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07QP8BKQW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RFS2K2X, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RM95YFC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RS7HM59, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RWWL4RC, Seller: WanGLOBLE, Winning Time: 32 days 07:00:00
# ASIN: B07RY6RDV7, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07RY9QDDF, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B07TDDFY4T, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07TSLQDSZ, Seller: Bedsure EU, Winning Time: 32 days 07:00:00
# ASIN: B07TXLSLHW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07TYFTPBV, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07TZKHLHZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07VJBMLPX, Seller: Mezken GmbH DE, Winning Time: 32 days 07:00:00
# ASIN: B07VLGP33H, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07VS2BFBH, Seller: Frankberg Autoteile, Winning Time: 32 days 07:00:00
# ASIN: B07VTFXH7J, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07W7MY874, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07WZPZCNT, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07X4964DZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07XSFLBLP, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07YD579WM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07YLL9CJK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B07ZH9282J, Seller: Boulevard Online, Winning Time: 32 days 07:00:00
# ASIN: B07ZHBJRWF, Seller: Boulevard Online, Winning Time: 32 days 07:00:00
# ASIN: B07ZQDWJ4V, Seller: Sciencey, Winning Time: 32 days 07:00:00
# ASIN: B081VZQB1B, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B082J4H1RK, Seller: CSL-Computer, Winning Time: 32 days 07:00:00
# ASIN: B083M7JPR7, Seller: Brand Distribution GmbH, Winning Time: 32 days 07:00:00
# ASIN: B083XRY7YR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0844BKF4R, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B084866NXN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0849D8D2G, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B084L88BP8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0853WD8PK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B085DBCJTG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B085GJJ3KM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B085T2T93F, Seller: Niclous, Winning Time: 32 days 07:00:00
# ASIN: B0861B8JPQ, Seller: ANKUL, Winning Time: 32 days 07:00:00
# ASIN: B086K429XY, Seller: TZS First E Commerce, Winning Time: 32 days 07:00:00
# ASIN: B086R9L33H, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B088TSP9SN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B088TVGT7J, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B089NL2XT6, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B089SXQKGN, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08BTLTVMG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08BZMV8XP, Seller: BranMic Products, Winning Time: 32 days 07:00:00
# ASIN: B08C5F6JJ3, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08CXVP58W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08CY8BK45, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08D8QTNKG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08DGC7XQG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08DTHMBRG, Seller: hbh24online, Winning Time: 32 days 07:00:00
# ASIN: B08G8N2F9L, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08GX4SL9F, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08J4WVVYM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08J7G47T8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08JKGR7TB, Seller: motointegrator, Winning Time: 32 days 07:00:00
# ASIN: B08JQCJHN4, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08K3H5PXY, Seller: PEARL Versandhaus, Winning Time: 32 days 07:00:00
# ASIN: B08L8B4M9X, Seller: Zoundhouse - Dresden, Winning Time: 32 days 07:00:00
# ASIN: B08MTLYRWC, Seller: Sam Mills Inc, Winning Time: 32 days 07:00:00
# ASIN: B08N5R7XXZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08N5S64Z2, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08NWZXWD1, Seller: vidaXL DE, Winning Time: 32 days 07:00:00
# ASIN: B08NY4FLNB, Seller: Liekumm, Winning Time: 32 days 07:00:00
# ASIN: B08P6C41K5, Seller: vidaXL DE, Winning Time: 32 days 07:00:00
# ASIN: B08PNWWVLF, Seller: GIANTEX, Winning Time: 32 days 07:00:00
# ASIN: B08PZD4FXG, Seller: TIBERION-SHOP, Winning Time: 32 days 07:00:00
# ASIN: B08SHYBHGK, Seller: CSL-Computer, Winning Time: 32 days 07:00:00
# ASIN: B08T9D9N3N, Seller: DIYUCAR, Winning Time: 32 days 07:00:00
# ASIN: B08TBYDXZ5, Seller: KAQITEY, Winning Time: 32 days 07:00:00
# ASIN: B08TJ2649W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08TRFXW1C, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08VD6SRBZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08VN99G9B, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08WH9XQFS, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B08X5CK7DK, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08YF7PB14, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08YFD8QDT, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08YS19ZXG, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B08YYZZNJG, Seller: BWBahn, Winning Time: 32 days 07:00:00
# ASIN: B08YZ1R3S9, Seller: Modellbahn-Ecke Essen, Winning Time: 32 days 07:00:00
# ASIN: B091CZGDKF, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0924Q167F, Seller: yuyte, Winning Time: 32 days 07:00:00
# ASIN: B0936FGLQS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0943P3G8K, Seller: schneeschuhe de - Manfred Clarck, Winning Time: 32 days 07:00:00
# ASIN: B09533GQL2, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B095SQTCSM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B095X2TRV5, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B096KDR9ZH, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B098K3VCHC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B099KMPRTJ, Seller: BIBCASA, Winning Time: 32 days 07:00:00
# ASIN: B09B1MP655, Seller: Amazon US, Winning Time: 32 days 07:00:00
# ASIN: B09BD1XJPX, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09BFWGCBD, Seller: STILORD Leder, Winning Time: 32 days 07:00:00
# ASIN: B09BNW4F85, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09BV7YYG3, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09DFKLJMS, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09DQ3R5Y1, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09F3VDDHW, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09F9H2GN9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09F9ZFPXJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09G95W3S3, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09HKTXJZ6, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09KMLSXYL, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09L4Y2XJ4, Seller: LSE Commerce, Winning Time: 32 days 07:00:00
# ASIN: B09LRHF75R, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09MFCPQSZ, Seller: Li-start, Winning Time: 32 days 07:00:00
# ASIN: B09MKCXRRR, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09MNG1LZ3, Seller: Folanda, Winning Time: 32 days 07:00:00
# ASIN: B09MTV8FYZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09N4522VS, Seller: CSL-Computer, Winning Time: 32 days 07:00:00
# ASIN: B09N4SJLWM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09PNDCWC1, Seller: EuroElectronics DE, Winning Time: 32 days 07:00:00
# ASIN: B09QMP2TB9, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09QQMGHR8, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09R94GYNB, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09V1Q7LRM, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09V361ZC4, Seller: Atomstack Workshop, Winning Time: 32 days 07:00:00
# ASIN: B09V7ZTP7T, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09VPJTF4N, Seller: Technik-Trends, Winning Time: 32 days 07:00:00
# ASIN: B09VSZF1LZ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09W2ZB75P, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09W5G56D1, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09X93FQNP, Seller: Inateck, Winning Time: 32 days 07:00:00
# ASIN: B09Y5K3LHZ, Seller: langeu, Winning Time: 32 days 07:00:00
# ASIN: B09Z6X261D, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B09ZHZGM8Q, Seller: Merkkur, Winning Time: 32 days 07:00:00
# ASIN: B0B1QFL177, Seller: SpecialRecreationRoom, Winning Time: 32 days 07:00:00
# ASIN: B0B1ZKRYHX, Seller: BIBCASA, Winning Time: 32 days 07:00:00
# ASIN: B0B56M9SDK, Seller: Enjoy Home Shop, Winning Time: 32 days 07:00:00
# ASIN: B0B8DTVKPV, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0B8YXFP17, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0B94WLJP7, Seller: formbench GmbH, Winning Time: 32 days 07:00:00
# ASIN: B0BCG7437G, Seller: Terra Master, Winning Time: 32 days 07:00:00
# ASIN: B0BD8ZZLYC, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BDJJY92W, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BGYGJHQD, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BJMC5DBV, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BJMKYX88, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BJN4T6NJ, Seller: amazon, Winning Time: 32 days 07:00:00
# ASIN: B0BKQYYMLH, Seller: STILORD Leder, Winning Time: 32 days 07:00:00

# %% [markdown]
# ## Price changes while winning the BuyBox?

# %%
winning_buybox_df = df[df['buyBoxWinner'] == True]

# Sort the dataframe by 'asin', 'sellerName', and 'time' columns
winning_buybox_df = winning_buybox_df.sort_values(['asin', 'sellerName', 'time'])

# Create a new column 'PriceChange' to indicate if the price has changed from the previous hour
winning_buybox_df['PriceChange'] = winning_buybox_df.groupby(['asin', 'sellerName'])['price'].diff().ne(0).astype(int)

# Calculate the percentage price change between the current and previous hour's prices
winning_buybox_df['PercentagePriceChange'] = winning_buybox_df.groupby(['asin', 'sellerName'])['price'].pct_change()

# Group the dataframe by 'asin' and 'sellerName' and calculate the total number of price changes and the average percentage price change for each group
price_change_summary = winning_buybox_df.groupby(['asin', 'sellerName']).agg({'PriceChange': ['sum'], 'PercentagePriceChange': ['mean']}).reset_index()

# Find the seller with the most frequent price changes
max_price_changes_seller = price_change_summary.loc[price_change_summary[('PriceChange', 'sum')].idxmax()]

# Calculate the total number of price changes
total_price_changes = price_change_summary[('PriceChange', 'sum')].sum()

# Calculate the number of unique ASIN/Seller pairs
unique_asin_seller_pairs = len(price_change_summary)

# Calculate the average number of price changes per ASIN/Seller pair
average_price_changes = total_price_changes / unique_asin_seller_pairs

# Calculate the average percentage price change across all ASIN/seller pairs
average_percentage_price_change = price_change_summary[('PercentagePriceChange', 'mean')].mean()

print("Average number of price changes:", average_price_changes)
print("Seller with the most price changes:", max_price_changes_seller['sellerName'])
print("Number of price changes:", max_price_changes_seller[('PriceChange', 'sum')])
print("Average percentage value of price change across all ASIN/seller pairs:", average_percentage_price_change)
print("ASIN for the product where the seller has the most price changes:", max_price_changes_seller['asin'])
# Out:
# Average number of price changes: 59.35674035543997
# Seller with the most price changes:     MusicScout
# Name: 1705, dtype: object
# Number of price changes: 503
# Average percentage value of price change across all ASIN/seller pairs: -5.678350973240732e-05
# ASIN for the product where the seller has the most price changes:     B091PD782Y
# Name: 1705, dtype: object

# %%
max_seller_rows.to_csv('../Grunddatein/Zwischendatein/SellerWithMostPriceChanges.csv', index=False)
